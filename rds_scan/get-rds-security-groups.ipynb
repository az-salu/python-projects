# %%
import boto3
import os
import json
import csv
import pandas as pd 
import xlsxwriter

# %%
def get_home_dir():
    """Get home directory of the user based on OS."""

    if os.name == "nt":
        return os.path.expanduser("~\\.aws\\") # Windows
    else:
        return os.path.expanduser("~/.aws/") # Linux and MAC

# %%
def get_aws_credentials():
    """Read AWS credentials from session.json file."""
    home_dir = get_home_dir()
    full_path = os.path.join(home_dir, "session_token.json")

    with open(full_path) as f:
        credentials = json.load(f)["Credentials"]

    return credentials

# %%
# Read the AWS credentials from a local session.json file in home/user/.aws/ directory
credentials = get_aws_credentials()

# %%
# Connect to AWS Client
rds_client = boto3.client(
    "rds",
    aws_access_key_id=credentials["AccessKeyId"],
    aws_secret_access_key=credentials["SecretAccessKey"],
    aws_session_token=credentials["SessionToken"]
)

ec2_client = boto3.client(
    "ec2",
    aws_access_key_id=credentials["AccessKeyId"],
    aws_secret_access_key=credentials["SecretAccessKey"],
    aws_session_token=credentials["SessionToken"]
)

# %%
vpc_list = []
with open("vpc_ids.txt", "r") as f:
    vpc_list = [line.strip() for line in f.readlines()]

# %%
vpc_list
# Out:
# ['vpc-b50046d0',
#  'vpc-d50f49b0',
#  'vpc-959d26f1',
#  'vpc-840147e1',
#  'vpc-84a444e0',
#  'vpc-72df7917',
#  'vpc-6c7f9409',
#  'vpc-7a7f941f',
#  'vpc-c52bc0a0',
#  'vpc-0978b06c']

# %%
describe_rds_response = rds_client.describe_db_instances()

# %%
describe_rds_response
# Out:
# {'DBInstances': [{'DBInstanceIdentifier': 'appeals-preprod-caseflow-aurora-primary',
#    'DBInstanceClass': 'db.t3.medium',
#    'Engine': 'aurora-postgresql',
#    'DBInstanceStatus': 'available',
#    'MasterUsername': 'caseflow',
#    'DBName': 'caseflow_certification',
#    'Endpoint': {'Address': 'appeals-preprod-caseflow-aurora-primary.cdqbofmbcmtd.us-gov-west-1.rds.amazonaws.com',
#     'Port': 5432,
#     'HostedZoneId': 'Z2YROVNTF0QJSQ'},
#    'AllocatedStorage': 20,
#    'InstanceCreateTime': datetime.datetime(2021, 8, 20, 18, 46, 40, 813000, tzinfo=tzutc()),
#    'PreferredBackupWindow': '08:47-09:17',
#    'BackupRetentionPeriod': 7,
#    'DBSecurityGroups': [],
#    'VpcSecurityGroups': [{'VpcSecurityGroupId': 'sg-04a768d794318de67',
#      'Status': 'active'}],
#    'DBParameterGroups': [{'DBParameterGroupName': 'default.aurora-postgresql11',
#      'ParameterApplyStatus': 'in-sync'}],
#    'AvailabilityZone': 'us-gov-west-1b',
#    'DBSubnetGroup': {'DBSubnetGroupName': 'default-vpc-ef7cfa8a',
#     'DBSubnetGroupDescription': 'Database subnet group for staging',
#     'VpcId': 'vpc-ef7cfa8a',
#     'SubnetGroupStatus': 'Complete',
#     'Subnets': [{'SubnetIdentifier': 'subnet-1db98378',
#       'SubnetAvailabilityZone': {'Name': 'us-gov-west-1b'},
#       'SubnetOutpost': {},
#       'SubnetStatus': 'Active'},
#      {'SubnetIdentifier': 'subnet-ea22089d',
#       'SubnetAvailabilityZone': {'Name': 'us-gov-west-1a'},
#       'SubnetOutpost': {},
#       'SubnetStatus': 'Active'}]},
#    'PreferredMaintenanceWindow': 'sun:08:12-sun:08:42',
#    'PendingModifiedValues': {},
#    'MultiAZ': False,
#    'EngineVersion': '11.15',
#    'AutoMinorVersionUpgrade': False,
#    'ReadReplicaDBInstanceIdentifiers': [],
#    'LicenseModel': 'postgresql-license',
#    'OptionGroupMemberships': [{'OptionGroupName': 'default:aurora-postgresql-11',
#      'Status': 'in-sync'}],
#    'PubliclyAccessible': False,
#    'StorageType': 'aurora',
#    'DbInstancePort': 0,
#    'DBClusterIdentifier': 'appeals-preprod-caseflow-aurora-cluster',
#    'StorageEncrypted': True,
#    'KmsKeyId': 'arn:aws-us-gov:kms:us-gov-west-1:008577686731:key/41845171-61fd-43f1-9061-acedf9d6d823',
#    'DbiResourceId': 'db-SGDG5SMMXLMXOD7O6D5YFFJZQQ',
#    'CACertificateIdentifier': 'rds-ca-rsa4096-g1',
#    'DomainMemberships': [],
#    'CopyTagsToSnapshot': True,
#    'MonitoringInterval': 0,
#    'PromotionTier': 0,
#    'DBInstanceArn': 'arn:aws-us-gov:rds:us-gov-west-1:008577686731:db:appeals-preprod-caseflow-aurora-primary',
#    'IAMDatabaseAuthenticationEnabled': False,
#    'PerformanceInsightsEnabled': False,
#    'EnabledCloudwatchLogsExports': ['postgresql'],
#    'DeletionProtection': False,
#    'AssociatedRoles': [],
#    'TagList': [{'Key': 'ProjectName', 'Value': 'Caseflow'},
#     {'Key': 'project', 'Value': 'appeals'},
#     {'Key': 'office', 'Value': 'osva'},
#     {'Key': 'Name', 'Value': 'appeals-preprod-caseflow-aurora-primary'},
#     {'Key': 'VAECID', 'Value': 'AWG20180405001'},
#     {'Key': 'environment', 'Value': 'preprod'},
#     {'Key': 'Adminstration', 'Value': 'VBA'},
#     {'Key': 'provider', 'Value': 'aws'},
#     {'Key': 'managed', 'Value': 'terraform'},
#     {'Key': 'region', 'Value': 'govcloud'},
#     {'Key': 'suboffice', 'Value': 'cto'},
#     {'Key': 'ProjectShort', 'Value': 'Caseflow'},
#     {'Key': 'dsva_version', 'Value': 'v2'},
#     {'Key': 'group', 'Value': 'dsva'}],
#    'CustomerOwnedIpEnabled': False,
#    'BackupTarget': 'region'},
#   {'DBInstanceIdentifier': 'appeals-preprod-efolder-aurora-primary',
#    'DBInstanceClass': 'db.r4.xlarge',
#    'Engine': 'aurora-postgresql',
#    'DBInstanceStatus': 'available',
#    'MasterUsername': 'efolder_express',
#    'DBName': 'efolder_express',
#    'Endpoint': {'Address': 'appeals-preprod-efolder-aurora-primary.cdqbofmbcmtd.us-gov-west-1.rds.amazonaws.com',
#     'Port': 5432,
#     'HostedZoneId': 'Z2YROVNTF0QJSQ'},
#    'AllocatedStorage': 100,
#    'InstanceCreateTime': datetime.datetime(2021, 8, 25, 14, 37, 27, 414000, tzinfo=tzutc()),
#    'PreferredBackupWindow': '11:39-12:09',
#    'BackupRetentionPeriod': 7,
#    'DBSecurityGroups': [],
#    'VpcSecurityGroups': [{'VpcSecurityGroupId': 'sg-035a66de36ae41986',
#      'Status': 'active'}],
#    'DBParameterGroups': [{'DBParameterGroupName': 'default.aurora-postgresql11',
#      'ParameterApplyStatus': 'in-sync'}],
#    'AvailabilityZone': 'us-gov-west-1a',
#    'DBSubnetGroup': {'DBSubnetGroupName': 'default-vpc-ef7cfa8a',
#     'DBSubnetGroupDescription': 'Database subnet group for staging',
#     'VpcId': 'vpc-ef7cfa8a',
#     'SubnetGroupStatus': 'Complete',
#     'Subnets': [{'SubnetIdentifier': 'subnet-1db98378',
#       'SubnetAvailabilityZone': {'Name': 'us-gov-west-1b'},
#       'SubnetOutpost': {},
#       'SubnetStatus': 'Active'},
#      {'SubnetIdentifier': 'subnet-ea22089d',
#       'SubnetAvailabilityZone': {'Name': 'us-gov-west-1a'},
#       'SubnetOutpost': {},
#       'SubnetStatus': 'Active'}]},
#    'PreferredMaintenanceWindow': 'sat:11:16-sat:11:46',
#    'PendingModifiedValues': {},
#    'MultiAZ': False,
#    'EngineVersion': '11.15',
#    'AutoMinorVersionUpgrade': True,
#    'ReadReplicaDBInstanceIdentifiers': [],
#    'LicenseModel': 'postgresql-license',
#    'OptionGroupMemberships': [{'OptionGroupName': 'default:aurora-postgresql-11',
#      'Status': 'in-sync'}],
#    'PubliclyAccessible': False,
#    'StorageType': 'aurora',
#    'DbInstancePort': 0,
#    'DBClusterIdentifier': 'appeals-preprod-efolder-aurora-cluster',
#    'StorageEncrypted': True,
#    'KmsKeyId': 'arn:aws-us-gov:kms:us-gov-west-1:008577686731:key/b3fcaa93-eb3c-421a-9302-9da8cd3a30af',
#    'DbiResourceId': 'db-WQIQ25KVYDKTQWMJNAFO6PUDR4',
#    'CACertificateIdentifier': 'rds-ca-rsa4096-g1',
#    'DomainMemberships': [],
#    'CopyTagsToSnapshot': True,
#    'MonitoringInterval': 0,
#    'PromotionTier': 0,
#    'DBInstanceArn': 'arn:aws-us-gov:rds:us-gov-west-1:008577686731:db:appeals-preprod-efolder-aurora-primary',
#    'IAMDatabaseAuthenticationEnabled': False,
#    'PerformanceInsightsEnabled': False,
#    'EnabledCloudwatchLogsExports': ['postgresql'],
#    'DeletionProtection': False,
#    'AssociatedRoles': [],
#    'TagList': [{'Key': 'ProjectName', 'Value': 'Caseflow'},
#     {'Key': 'project', 'Value': 'appeals'},
#     {'Key': 'office', 'Value': 'osva'},
#     {'Key': 'Name', 'Value': 'appeals-preprod-efolder-aurora-primary'},
#     {'Key': 'VAECID', 'Value': 'AWG20180405001'},
#     {'Key': 'environment', 'Value': 'preprod'},
#     {'Key': 'Adminstration', 'Value': 'VBA'},
#     {'Key': 'provider', 'Value': 'aws'},
#     {'Key': 'managed', 'Value': 'terraform'},
#     {'Key': 'region', 'Value': 'govcloud'},
#     {'Key': 'suboffice', 'Value': 'cto'},
#     {'Key': 'ProjectShort', 'Value': 'Caseflow'},
#     {'Key': 'dsva_version', 'Value': 'v2'},
#     {'Key': 'group', 'Value': 'dsva'}],
#    'CustomerOwnedIpEnabled': False,
#    'BackupTarget': 'region'},
#   {'DBInstanceIdentifier': 'appeals-preprod-etl',
#    'DBInstanceClass': 'db.t2.medium',
#    'Engine': 'postgres',
#    'DBInstanceStatus': 'available',
#    'MasterUsername': 'caseflowetlpreprod',
#    'DBName': 'caseflow_etl',
#    'Endpoint': {'Address': 'appeals-preprod-etl.cdqbofmbcmtd.us-gov-west-1.rds.amazonaws.com',
#     'Port': 5432,
#     'HostedZoneId': 'Z2YROVNTF0QJSQ'},
#    'AllocatedStorage': 300,
#    'InstanceCreateTime': datetime.datetime(2021, 8, 30, 12, 46, 11, 894000, tzinfo=tzutc()),
#    'PreferredBackupWindow': '10:06-10:36',
#    'BackupRetentionPeriod': 10,
#    'DBSecurityGroups': [],
#    'VpcSecurityGroups': [{'VpcSecurityGroupId': 'sg-0ab53708fe340cee7',
#      'Status': 'active'}],
#    'DBParameterGroups': [{'DBParameterGroupName': 'default.postgres11',
#      'ParameterApplyStatus': 'in-sync'}],
#    'AvailabilityZone': 'us-gov-west-1a',
#    'DBSubnetGroup': {'DBSubnetGroupName': 'default-vpc-ef7cfa8a',
#     'DBSubnetGroupDescription': 'Database subnet group for staging',
#     'VpcId': 'vpc-ef7cfa8a',
#     'SubnetGroupStatus': 'Complete',
#     'Subnets': [{'SubnetIdentifier': 'subnet-1db98378',
#       'SubnetAvailabilityZone': {'Name': 'us-gov-west-1b'},
#       'SubnetOutpost': {},
#       'SubnetStatus': 'Active'},
#      {'SubnetIdentifier': 'subnet-ea22089d',
#       'SubnetAvailabilityZone': {'Name': 'us-gov-west-1a'},
#       'SubnetOutpost': {},
#       'SubnetStatus': 'Active'}]},
#    'PreferredMaintenanceWindow': 'sat:07:16-sat:07:46',
#    'PendingModifiedValues': {},
#    'LatestRestorableTime': datetime.datetime(2022, 5, 18, 2, 54, 36, tzinfo=tzutc()),
#    'MultiAZ': False,
#    'EngineVersion': '11.15',
#    'AutoMinorVersionUpgrade': False,
#    'ReadReplicaDBInstanceIdentifiers': [],
#    'LicenseModel': 'postgresql-license',
#    'OptionGroupMemberships': [{'OptionGroupName': 'default:postgres-11',
#      'Status': 'in-sync'}],
#    'PubliclyAccessible': False,
#    'StorageType': 'gp2',
#    'DbInstancePort': 0,
#    'StorageEncrypted': True,
#    'KmsKeyId': 'arn:aws-us-gov:kms:us-gov-west-1:008577686731:key/da52fa14-0ee7-4e02-bc43-e09d2e0638c9',
#    'DbiResourceId': 'db-J7DWOYUQEJCVRSINEMIZVDN65M',
#    'CACertificateIdentifier': 'rds-ca-rsa4096-g1',
#    'DomainMemberships': [],
#    'CopyTagsToSnapshot': True,
#    'MonitoringInterval': 0,
#    'DBInstanceArn': 'arn:aws-us-gov:rds:us-gov-west-1:008577686731:db:appeals-preprod-etl',
#    'IAMDatabaseAuthenticationEnabled': False,
#    'PerformanceInsightsEnabled': False,
#    'DeletionProtection': True,
#    'AssociatedRoles': [],
#    'MaxAllocatedStorage': 2000,
#    'TagList': [{'Key': 'ProjectName', 'Value': 'Caseflow'},
#     {'Key': 'project', 'Value': 'appeals'},
#     {'Key': 'office', 'Value': 'osva'},
#     {'Key': 'Name', 'Value': 'appeals-preprod-etl'},
#     {'Key': 'VAECID', 'Value': 'AWG20180405001'},
#     {'Key': 'environment', 'Value': 'preprod'},
#     {'Key': 'Adminstration', 'Value': 'VBA'},
#     {'Key': 'provider', 'Value': 'aws'},
#     {'Key': 'managed', 'Value': 'terraform'},
#     {'Key': 'region', 'Value': 'govcloud'},
#     {'Key': 'suboffice', 'Value': 'cto'},
#     {'Key': 'ProjectShort', 'Value': 'Caseflow'},
#     {'Key': 'dsva_version', 'Value': 'v2'},
#     {'Key': 'group', 'Value': 'dsva'}],
#    'CustomerOwnedIpEnabled': False,
#    'BackupTarget': 'region'},
#   {'DBInstanceIdentifier': 'appeals-prod-caseflow-aurora-primary',
#    'DBInstanceClass': 'db.r5.xlarge',
#    'Engine': 'aurora-postgresql',
#    'DBInstanceStatus': 'available',
#    'MasterUsername': 'caseflow',
#    'DBName': 'caseflow_certification',
#    'Endpoint': {'Address': 'appeals-prod-caseflow-aurora-primary.cdqbofmbcmtd.us-gov-west-1.rds.amazonaws.com',
#     'Port': 5432,
#     'HostedZoneId': 'Z2YROVNTF0QJSQ'},
#    'AllocatedStorage': 300,
#    'InstanceCreateTime': datetime.datetime(2021, 11, 20, 17, 45, 13, 450000, tzinfo=tzutc()),
#    'PreferredBackupWindow': '11:21-11:51',
#    'BackupRetentionPeriod': 35,
#    'DBSecurityGroups': [],
#    'VpcSecurityGroups': [{'VpcSecurityGroupId': 'sg-0df0e2159d72a5a10',
#      'Status': 'active'}],
#    'DBParameterGroups': [{'DBParameterGroupName': 'default.aurora-postgresql11',
#      'ParameterApplyStatus': 'in-sync'}],
#    'AvailabilityZone': 'us-gov-west-1b',
#    'DBSubnetGroup': {'DBSubnetGroupName': 'default-vpc-527dfb37',
#     'DBSubnetGroupDescription': 'Database subnet group for prod',
#     'VpcId': 'vpc-527dfb37',
#     'SubnetGroupStatus': 'Complete',
#     'Subnets': [{'SubnetIdentifier': 'subnet-7f220808',
#       'SubnetAvailabilityZone': {'Name': 'us-gov-west-1a'},
#       'SubnetOutpost': {},
#       'SubnetStatus': 'Active'},
#      {'SubnetIdentifier': 'subnet-5ab9833f',
#       'SubnetAvailabilityZone': {'Name': 'us-gov-west-1b'},
#       'SubnetOutpost': {},
#       'SubnetStatus': 'Active'}]},
#    'PreferredMaintenanceWindow': 'sat:04:12-sat:04:42',
#    'PendingModifiedValues': {},
#    'MultiAZ': False,
#    'EngineVersion': '11.15',
#    'AutoMinorVersionUpgrade': False,
#    'ReadReplicaDBInstanceIdentifiers': [],
#    'LicenseModel': 'postgresql-license',
#    'OptionGroupMemberships': [{'OptionGroupName': 'default:aurora-postgresql-11',
#      'Status': 'in-sync'}],
#    'PubliclyAccessible': False,
#    'StorageType': 'aurora',
#    'DbInstancePort': 0,
#    'DBClusterIdentifier': 'appeals-prod-caseflow-aurora-cluster',
#    'StorageEncrypted': True,
#    'KmsKeyId': 'arn:aws-us-gov:kms:us-gov-west-1:008577686731:key/fe091b47-2349-41f4-b5d0-06959e62ba12',
#    'DbiResourceId': 'db-3IMP2NQTEDS5RGLGEQD45WVOK4',
#    'CACertificateIdentifier': 'rds-ca-rsa4096-g1',
#    'DomainMemberships': [],
#    'CopyTagsToSnapshot': True,
#    'MonitoringInterval': 0,
#    'PromotionTier': 0,
#    'DBInstanceArn': 'arn:aws-us-gov:rds:us-gov-west-1:008577686731:db:appeals-prod-caseflow-aurora-primary',
#    'IAMDatabaseAuthenticationEnabled': False,
#    'PerformanceInsightsEnabled': False,
#    'EnabledCloudwatchLogsExports': ['postgresql'],
#    'DeletionProtection': False,
#    'AssociatedRoles': [],
#    'TagList': [{'Key': 'ProjectName', 'Value': 'Caseflow'},
#     {'Key': 'project', 'Value': 'appeals'},
#     {'Key': 'office', 'Value': 'osva'},
#     {'Key': 'Name', 'Value': 'appeals-prod-caseflow-aurora-primary'},
#     {'Key': 'VAECID', 'Value': 'AWG20180405001'},
#     {'Key': 'environment', 'Value': 'prod'},
#     {'Key': 'Adminstration', 'Value': 'VBA'},
#     {'Key': 'provider', 'Value': 'aws'},
#     {'Key': 'managed', 'Value': 'terraform'},
#     {'Key': 'region', 'Value': 'govcloud'},
#     {'Key': 'suboffice', 'Value': 'cto'},
#     {'Key': 'ProjectShort', 'Value': 'Caseflow'},
#     {'Key': 'dsva_version', 'Value': 'v2'},
#     {'Key': 'group', 'Value': 'dsva'}],
#    'CustomerOwnedIpEnabled': False,
#    'BackupTarget': 'region'},
#   {'DBInstanceIdentifier': 'appeals-prod-caseflow-aurora-reader',
#    'DBInstanceClass': 'db.r5.xlarge',
#    'Engine': 'aurora-postgresql',
#    'DBInstanceStatus': 'available',
#    'MasterUsername': 'caseflow',
#    'DBName': 'caseflow_certification',
#    'Endpoint': {'Address': 'appeals-prod-caseflow-aurora-reader.cdqbofmbcmtd.us-gov-west-1.rds.amazonaws.com',
#     'Port': 5432,
#     'HostedZoneId': 'Z2YROVNTF0QJSQ'},
#    'AllocatedStorage': 300,
#    'InstanceCreateTime': datetime.datetime(2021, 11, 20, 17, 50, 22, 148000, tzinfo=tzutc()),
#    'PreferredBackupWindow': '11:21-11:51',
#    'BackupRetentionPeriod': 35,
#    'DBSecurityGroups': [],
#    'VpcSecurityGroups': [{'VpcSecurityGroupId': 'sg-0df0e2159d72a5a10',
#      'Status': 'active'}],
#    'DBParameterGroups': [{'DBParameterGroupName': 'default.aurora-postgresql11',
#      'ParameterApplyStatus': 'in-sync'}],
#    'AvailabilityZone': 'us-gov-west-1a',
#    'DBSubnetGroup': {'DBSubnetGroupName': 'default-vpc-527dfb37',
#     'DBSubnetGroupDescription': 'Database subnet group for prod',
#     'VpcId': 'vpc-527dfb37',
#     'SubnetGroupStatus': 'Complete',
#     'Subnets': [{'SubnetIdentifier': 'subnet-7f220808',
#       'SubnetAvailabilityZone': {'Name': 'us-gov-west-1a'},
#       'SubnetOutpost': {},
#       'SubnetStatus': 'Active'},
#      {'SubnetIdentifier': 'subnet-5ab9833f',
#       'SubnetAvailabilityZone': {'Name': 'us-gov-west-1b'},
#       'SubnetOutpost': {},
#       'SubnetStatus': 'Active'}]},
#    'PreferredMaintenanceWindow': 'tue:06:07-tue:06:37',
#    'PendingModifiedValues': {},
#    'MultiAZ': False,
#    'EngineVersion': '11.15',
#    'AutoMinorVersionUpgrade': False,
#    'ReadReplicaDBInstanceIdentifiers': [],
#    'LicenseModel': 'postgresql-license',
#    'OptionGroupMemberships': [{'OptionGroupName': 'default:aurora-postgresql-11',
#      'Status': 'in-sync'}],
#    'PubliclyAccessible': False,
#    'StorageType': 'aurora',
#    'DbInstancePort': 0,
#    'DBClusterIdentifier': 'appeals-prod-caseflow-aurora-cluster',
#    'StorageEncrypted': True,
#    'KmsKeyId': 'arn:aws-us-gov:kms:us-gov-west-1:008577686731:key/fe091b47-2349-41f4-b5d0-06959e62ba12',
#    'DbiResourceId': 'db-ROZENOD2FISMDVSOPMFVGB2OKY',
#    'CACertificateIdentifier': 'rds-ca-rsa4096-g1',
#    'DomainMemberships': [],
#    'CopyTagsToSnapshot': True,
#    'MonitoringInterval': 0,
#    'PromotionTier': 0,
#    'DBInstanceArn': 'arn:aws-us-gov:rds:us-gov-west-1:008577686731:db:appeals-prod-caseflow-aurora-reader',
#    'IAMDatabaseAuthenticationEnabled': False,
#    'PerformanceInsightsEnabled': False,
#    'EnabledCloudwatchLogsExports': ['postgresql'],
#    'DeletionProtection': False,
#    'AssociatedRoles': [],
#    'TagList': [{'Key': 'ProjectName', 'Value': 'Caseflow'},
#     {'Key': 'project', 'Value': 'appeals'},
#     {'Key': 'office', 'Value': 'osva'},
#     {'Key': 'Name', 'Value': 'appeals-prod-caseflow-aurora-reader'},
#     {'Key': 'VAECID', 'Value': 'AWG20180405001'},
#     {'Key': 'environment', 'Value': 'prod'},
#     {'Key': 'Adminstration', 'Value': 'VBA'},
#     {'Key': 'provider', 'Value': 'aws'},
#     {'Key': 'managed', 'Value': 'terraform'},
#     {'Key': 'region', 'Value': 'govcloud'},
#     {'Key': 'suboffice', 'Value': 'cto'},
#     {'Key': 'ProjectShort', 'Value': 'Caseflow'},
#     {'Key': 'dsva_version', 'Value': 'v2'},
#     {'Key': 'group', 'Value': 'dsva'}],
#    'CustomerOwnedIpEnabled': False,
#    'BackupTarget': 'region'},
#   {'DBInstanceIdentifier': 'appeals-prod-efolder-aurora-primary',
#    'DBInstanceClass': 'db.r5.4xlarge',
#    'Engine': 'aurora-postgresql',
#    'DBInstanceStatus': 'available',
#    'MasterUsername': 'efolder_express',
#    'DBName': 'efolder_express',
#    'Endpoint': {'Address': 'appeals-prod-efolder-aurora-primary.cdqbofmbcmtd.us-gov-west-1.rds.amazonaws.com',
#     'Port': 5432,
#     'HostedZoneId': 'Z2YROVNTF0QJSQ'},
#    'AllocatedStorage': 200,
#    'InstanceCreateTime': datetime.datetime(2021, 11, 20, 17, 25, 15, 649000, tzinfo=tzutc()),
#    'PreferredBackupWindow': '13:21-13:51',
#    'BackupRetentionPeriod': 35,
#    'DBSecurityGroups': [],
#    'VpcSecurityGroups': [{'VpcSecurityGroupId': 'sg-098ea22c88b0e0d61',
#      'Status': 'active'}],
#    'DBParameterGroups': [{'DBParameterGroupName': 'default.aurora-postgresql11',
#      'ParameterApplyStatus': 'in-sync'}],
#    'AvailabilityZone': 'us-gov-west-1b',
#    'DBSubnetGroup': {'DBSubnetGroupName': 'default-vpc-527dfb37',
#     'DBSubnetGroupDescription': 'Database subnet group for prod',
#     'VpcId': 'vpc-527dfb37',
#     'SubnetGroupStatus': 'Complete',
#     'Subnets': [{'SubnetIdentifier': 'subnet-7f220808',
#       'SubnetAvailabilityZone': {'Name': 'us-gov-west-1a'},
#       'SubnetOutpost': {},
#       'SubnetStatus': 'Active'},
#      {'SubnetIdentifier': 'subnet-5ab9833f',
#       'SubnetAvailabilityZone': {'Name': 'us-gov-west-1b'},
#       'SubnetOutpost': {},
#       'SubnetStatus': 'Active'}]},
#    'PreferredMaintenanceWindow': 'wed:09:59-wed:10:29',
#    'PendingModifiedValues': {},
#    'MultiAZ': False,
#    'EngineVersion': '11.15',
#    'AutoMinorVersionUpgrade': True,
#    'ReadReplicaDBInstanceIdentifiers': [],
#    'LicenseModel': 'postgresql-license',
#    'OptionGroupMemberships': [{'OptionGroupName': 'default:aurora-postgresql-11',
#      'Status': 'in-sync'}],
#    'PubliclyAccessible': False,
#    'StorageType': 'aurora',
#    'DbInstancePort': 0,
#    'DBClusterIdentifier': 'appeals-prod-efolder-aurora-cluster',
#    'StorageEncrypted': True,
#    'KmsKeyId': 'arn:aws-us-gov:kms:us-gov-west-1:008577686731:key/402bd545-9834-4e33-9680-a22c9a726714',
#    'DbiResourceId': 'db-LLUNLOOP7YOXJZZEI52RPK7VMA',
#    'CACertificateIdentifier': 'rds-ca-rsa4096-g1',
#    'DomainMemberships': [],
#    'CopyTagsToSnapshot': True,
#    'MonitoringInterval': 0,
#    'PromotionTier': 0,
#    'DBInstanceArn': 'arn:aws-us-gov:rds:us-gov-west-1:008577686731:db:appeals-prod-efolder-aurora-primary',
#    'IAMDatabaseAuthenticationEnabled': False,
#    'PerformanceInsightsEnabled': False,
#    'EnabledCloudwatchLogsExports': ['postgresql'],
#    'DeletionProtection': False,
#    'AssociatedRoles': [],
#    'TagList': [{'Key': 'ProjectName', 'Value': 'Caseflow'},
#     {'Key': 'project', 'Value': 'appeals'},
#     {'Key': 'office', 'Value': 'osva'},
#     {'Key': 'Name', 'Value': 'appeals-prod-efolder-aurora-primary'},
#     {'Key': 'VAECID', 'Value': 'AWG20180405001'},
#     {'Key': 'environment', 'Value': 'prod'},
#     {'Key': 'Adminstration', 'Value': 'VBA'},
#     {'Key': 'provider', 'Value': 'aws'},
#     {'Key': 'managed', 'Value': 'terraform'},
#     {'Key': 'region', 'Value': 'govcloud'},
#     {'Key': 'suboffice', 'Value': 'cto'},
#     {'Key': 'ProjectShort', 'Value': 'Caseflow'},
#     {'Key': 'dsva_version', 'Value': 'v2'},
#     {'Key': 'group', 'Value': 'dsva'}],
#    'CustomerOwnedIpEnabled': False,
#    'BackupTarget': 'region'},
#   {'DBInstanceIdentifier': 'appeals-prod-efolder-aurora-reader',
#    'DBInstanceClass': 'db.r5.4xlarge',
#    'Engine': 'aurora-postgresql',
#    'DBInstanceStatus': 'available',
#    'MasterUsername': 'efolder_express',
#    'DBName': 'efolder_express',
#    'Endpoint': {'Address': 'appeals-prod-efolder-aurora-reader.cdqbofmbcmtd.us-gov-west-1.rds.amazonaws.com',
#     'Port': 5432,
#     'HostedZoneId': 'Z2YROVNTF0QJSQ'},
#    'AllocatedStorage': 200,
#    'InstanceCreateTime': datetime.datetime(2022, 4, 13, 22, 43, 48, 245000, tzinfo=tzutc()),
#    'PreferredBackupWindow': '13:21-13:51',
#    'BackupRetentionPeriod': 35,
#    'DBSecurityGroups': [],
#    'VpcSecurityGroups': [{'VpcSecurityGroupId': 'sg-098ea22c88b0e0d61',
#      'Status': 'active'}],
#    'DBParameterGroups': [{'DBParameterGroupName': 'default.aurora-postgresql11',
#      'ParameterApplyStatus': 'in-sync'}],
#    'AvailabilityZone': 'us-gov-west-1a',
#    'DBSubnetGroup': {'DBSubnetGroupName': 'default-vpc-527dfb37',
#     'DBSubnetGroupDescription': 'Database subnet group for prod',
#     'VpcId': 'vpc-527dfb37',
#     'SubnetGroupStatus': 'Complete',
#     'Subnets': [{'SubnetIdentifier': 'subnet-7f220808',
#       'SubnetAvailabilityZone': {'Name': 'us-gov-west-1a'},
#       'SubnetOutpost': {},
#       'SubnetStatus': 'Active'},
#      {'SubnetIdentifier': 'subnet-5ab9833f',
#       'SubnetAvailabilityZone': {'Name': 'us-gov-west-1b'},
#       'SubnetOutpost': {},
#       'SubnetStatus': 'Active'}]},
#    'PreferredMaintenanceWindow': 'sat:07:59-sat:08:29',
#    'PendingModifiedValues': {},
#    'MultiAZ': False,
#    'EngineVersion': '11.15',
#    'AutoMinorVersionUpgrade': True,
#    'ReadReplicaDBInstanceIdentifiers': [],
#    'LicenseModel': 'postgresql-license',
#    'OptionGroupMemberships': [{'OptionGroupName': 'default:aurora-postgresql-11',
#      'Status': 'in-sync'}],
#    'PubliclyAccessible': False,
#    'StorageType': 'aurora',
#    'DbInstancePort': 0,
#    'DBClusterIdentifier': 'appeals-prod-efolder-aurora-cluster',
#    'StorageEncrypted': True,
#    'KmsKeyId': 'arn:aws-us-gov:kms:us-gov-west-1:008577686731:key/402bd545-9834-4e33-9680-a22c9a726714',
#    'DbiResourceId': 'db-DDMV2V3PKBCMJWP4KNUUDYM2PU',
#    'CACertificateIdentifier': 'rds-ca-rsa4096-g1',
#    'DomainMemberships': [],
#    'CopyTagsToSnapshot': True,
#    'MonitoringInterval': 0,
#    'PromotionTier': 0,
#    'DBInstanceArn': 'arn:aws-us-gov:rds:us-gov-west-1:008577686731:db:appeals-prod-efolder-aurora-reader',
#    'IAMDatabaseAuthenticationEnabled': False,
#    'PerformanceInsightsEnabled': False,
#    'EnabledCloudwatchLogsExports': ['postgresql'],
#    'DeletionProtection': False,
#    'AssociatedRoles': [],
#    'TagList': [{'Key': 'ProjectName', 'Value': 'Caseflow'},
#     {'Key': 'project', 'Value': 'appeals'},
#     {'Key': 'office', 'Value': 'osva'},
#     {'Key': 'Name', 'Value': 'appeals-prod-efolder-aurora-reader'},
#     {'Key': 'VAECID', 'Value': 'AWG20180405001'},
#     {'Key': 'environment', 'Value': 'prod'},
#     {'Key': 'Adminstration', 'Value': 'VBA'},
#     {'Key': 'provider', 'Value': 'aws'},
#     {'Key': 'managed', 'Value': 'terraform'},
#     {'Key': 'region', 'Value': 'govcloud'},
#     {'Key': 'suboffice', 'Value': 'cto'},
#     {'Key': 'ProjectShort', 'Value': 'Caseflow'},
#     {'Key': 'dsva_version', 'Value': 'v2'},
#     {'Key': 'group', 'Value': 'dsva'}],
#    'CustomerOwnedIpEnabled': False,
#    'BackupTarget': 'region'},
#   {'DBInstanceIdentifier': 'appeals-prod-sentry',
#    'DBInstanceClass': 'db.t2.medium',
#    'Engine': 'postgres',
#    'DBInstanceStatus': 'available',
#    'MasterUsername': 'sentry',
#    'DBName': 'sentry',
#    'Endpoint': {'Address': 'appeals-prod-sentry.cdqbofmbcmtd.us-gov-west-1.rds.amazonaws.com',
#     'Port': 5432,
#     'HostedZoneId': 'Z2YROVNTF0QJSQ'},
#    'AllocatedStorage': 300,
#    'InstanceCreateTime': datetime.datetime(2021, 11, 20, 15, 49, 53, 177000, tzinfo=tzutc()),
#    'PreferredBackupWindow': '07:23-07:53',
#    'BackupRetentionPeriod': 7,
#    'DBSecurityGroups': [],
#    'VpcSecurityGroups': [{'VpcSecurityGroupId': 'sg-02d02b6bf6fc04aef',
#      'Status': 'active'}],
#    'DBParameterGroups': [{'DBParameterGroupName': 'default.postgres12',
#      'ParameterApplyStatus': 'in-sync'}],
#    'AvailabilityZone': 'us-gov-west-1a',
#    'DBSubnetGroup': {'DBSubnetGroupName': 'default-vpc-527dfb37',
#     'DBSubnetGroupDescription': 'Database subnet group for prod',
#     'VpcId': 'vpc-527dfb37',
#     'SubnetGroupStatus': 'Complete',
#     'Subnets': [{'SubnetIdentifier': 'subnet-7f220808',
#       'SubnetAvailabilityZone': {'Name': 'us-gov-west-1a'},
#       'SubnetOutpost': {},
#       'SubnetStatus': 'Active'},
#      {'SubnetIdentifier': 'subnet-5ab9833f',
#       'SubnetAvailabilityZone': {'Name': 'us-gov-west-1b'},
#       'SubnetOutpost': {},
#       'SubnetStatus': 'Active'}]},
#    'PreferredMaintenanceWindow': 'sat:23:30-sun:00:00',
#    'PendingModifiedValues': {},
#    'LatestRestorableTime': datetime.datetime(2022, 5, 18, 2, 54, 44, tzinfo=tzutc()),
#    'MultiAZ': True,
#    'EngineVersion': '12.10',
#    'AutoMinorVersionUpgrade': False,
#    'ReadReplicaDBInstanceIdentifiers': [],
#    'LicenseModel': 'postgresql-license',
#    'OptionGroupMemberships': [{'OptionGroupName': 'default:postgres-12',
#      'Status': 'in-sync'}],
#    'SecondaryAvailabilityZone': 'us-gov-west-1b',
#    'PubliclyAccessible': False,
#    'StorageType': 'gp2',
#    'DbInstancePort': 0,
#    'StorageEncrypted': False,
#    'DbiResourceId': 'db-EFQJSLG3MIAJZ6YGQ5NFDEMSB4',
#    'CACertificateIdentifier': 'rds-ca-rsa4096-g1',
#    'DomainMemberships': [],
#    'CopyTagsToSnapshot': True,
#    'MonitoringInterval': 0,
#    'DBInstanceArn': 'arn:aws-us-gov:rds:us-gov-west-1:008577686731:db:appeals-prod-sentry',
#    'IAMDatabaseAuthenticationEnabled': False,
#    'PerformanceInsightsEnabled': False,
#    'DeletionProtection': True,
#    'AssociatedRoles': [],
#    'TagList': [{'Key': 'ProjectName', 'Value': 'Caseflow'},
#     {'Key': 'project', 'Value': 'appeals'},
#     {'Key': 'office', 'Value': 'osva'},
#     {'Key': 'Name', 'Value': 'appeals-prod-sentry'},
#     {'Key': 'VAECID', 'Value': 'AWG20180405001'},
#     {'Key': 'environment', 'Value': 'prod'},
#     {'Key': 'Adminstration', 'Value': 'VBA'},
#     {'Key': 'provider', 'Value': 'aws'},
#     {'Key': 'managed', 'Value': 'terraform'},
#     {'Key': 'region', 'Value': 'govcloud'},
#     {'Key': 'suboffice', 'Value': 'cto'},
#     {'Key': 'ProjectShort', 'Value': 'Caseflow'},
#     {'Key': 'dsva_version', 'Value': 'v2'},
#     {'Key': 'group', 'Value': 'dsva'}],
#    'CustomerOwnedIpEnabled': False,
#    'BackupTarget': 'region'},
#   {'DBInstanceIdentifier': 'appeals-uat-caseflow-aurora-primary',
#    'DBInstanceClass': 'db.t3.medium',
#    'Engine': 'aurora-postgresql',
#    'DBInstanceStatus': 'available',
#    'MasterUsername': 'caseflow',
#    'DBName': 'caseflow_certification',
#    'Endpoint': {'Address': 'appeals-uat-caseflow-aurora-primary.cdqbofmbcmtd.us-gov-west-1.rds.amazonaws.com',
#     'Port': 5432,
#     'HostedZoneId': 'Z2YROVNTF0QJSQ'},
#    'AllocatedStorage': 20,
#    'InstanceCreateTime': datetime.datetime(2021, 8, 24, 15, 12, 26, 116000, tzinfo=tzutc()),
#    'PreferredBackupWindow': '09:08-09:38',
#    'BackupRetentionPeriod': 7,
#    'DBSecurityGroups': [],
#    'VpcSecurityGroups': [{'VpcSecurityGroupId': 'sg-0552340dbcbd8c4b9',
#      'Status': 'active'}],
#    'DBParameterGroups': [{'DBParameterGroupName': 'default.aurora-postgresql11',
#      'ParameterApplyStatus': 'in-sync'}],
#    'AvailabilityZone': 'us-gov-west-1a',
#    'DBSubnetGroup': {'DBSubnetGroupName': 'default-vpc-ef7cfa8a',
#     'DBSubnetGroupDescription': 'Database subnet group for staging',
#     'VpcId': 'vpc-ef7cfa8a',
#     'SubnetGroupStatus': 'Complete',
#     'Subnets': [{'SubnetIdentifier': 'subnet-1db98378',
#       'SubnetAvailabilityZone': {'Name': 'us-gov-west-1b'},
#       'SubnetOutpost': {},
#       'SubnetStatus': 'Active'},
#      {'SubnetIdentifier': 'subnet-ea22089d',
#       'SubnetAvailabilityZone': {'Name': 'us-gov-west-1a'},
#       'SubnetOutpost': {},
#       'SubnetStatus': 'Active'}]},
#    'PreferredMaintenanceWindow': 'sat:06:30-sat:07:00',
#    'PendingModifiedValues': {},
#    'MultiAZ': False,
#    'EngineVersion': '11.15',
#    'AutoMinorVersionUpgrade': True,
#    'ReadReplicaDBInstanceIdentifiers': [],
#    'LicenseModel': 'postgresql-license',
#    'OptionGroupMemberships': [{'OptionGroupName': 'default:aurora-postgresql-11',
#      'Status': 'in-sync'}],
#    'PubliclyAccessible': False,
#    'StorageType': 'aurora',
#    'DbInstancePort': 0,
#    'DBClusterIdentifier': 'appeals-uat-caseflow-aurora-cluster',
#    'StorageEncrypted': True,
#    'KmsKeyId': 'arn:aws-us-gov:kms:us-gov-west-1:008577686731:key/bc1cbc6f-9cc6-4f60-bcac-622c5cb091b2',
#    'DbiResourceId': 'db-DA4K3MC3T72PXMZDJVUQZTRON4',
#    'CACertificateIdentifier': 'rds-ca-rsa4096-g1',
#    'DomainMemberships': [],
#    'CopyTagsToSnapshot': True,
#    'MonitoringInterval': 0,
#    'PromotionTier': 0,
#    'DBInstanceArn': 'arn:aws-us-gov:rds:us-gov-west-1:008577686731:db:appeals-uat-caseflow-aurora-primary',
#    'IAMDatabaseAuthenticationEnabled': False,
#    'PerformanceInsightsEnabled': False,
#    'EnabledCloudwatchLogsExports': ['postgresql'],
#    'DeletionProtection': False,
#    'AssociatedRoles': [],
#    'TagList': [{'Key': 'ProjectName', 'Value': 'Caseflow'},
#     {'Key': 'project', 'Value': 'appeals'},
#     {'Key': 'office', 'Value': 'osva'},
#     {'Key': 'Name', 'Value': 'appeals-uat-caseflow-aurora-primary'},
#     {'Key': 'VAECID', 'Value': 'AWG20180405001'},
#     {'Key': 'environment', 'Value': 'uat'},
#     {'Key': 'Adminstration', 'Value': 'VBA'},
#     {'Key': 'provider', 'Value': 'aws'},
#     {'Key': 'managed', 'Value': 'terraform'},
#     {'Key': 'region', 'Value': 'govcloud'},
#     {'Key': 'suboffice', 'Value': 'cto'},
#     {'Key': 'ProjectShort', 'Value': 'Caseflow'},
#     {'Key': 'dsva_version', 'Value': 'v2'},
#     {'Key': 'group', 'Value': 'dsva'}],
#    'CustomerOwnedIpEnabled': False,
#    'BackupTarget': 'region'},
#   {'DBInstanceIdentifier': 'appeals-uat-caseflow-aurora-reader',
#    'DBInstanceClass': 'db.t3.medium',
#    'Engine': 'aurora-postgresql',
#    'DBInstanceStatus': 'available',
#    'MasterUsername': 'caseflow',
#    'DBName': 'caseflow_certification',
#    'Endpoint': {'Address': 'appeals-uat-caseflow-aurora-reader.cdqbofmbcmtd.us-gov-west-1.rds.amazonaws.com',
#     'Port': 5432,
#     'HostedZoneId': 'Z2YROVNTF0QJSQ'},
#    'AllocatedStorage': 20,
#    'InstanceCreateTime': datetime.datetime(2021, 8, 24, 15, 17, 30, 643000, tzinfo=tzutc()),
#    'PreferredBackupWindow': '09:08-09:38',
#    'BackupRetentionPeriod': 7,
#    'DBSecurityGroups': [],
#    'VpcSecurityGroups': [{'VpcSecurityGroupId': 'sg-0552340dbcbd8c4b9',
#      'Status': 'active'}],
#    'DBParameterGroups': [{'DBParameterGroupName': 'default.aurora-postgresql11',
#      'ParameterApplyStatus': 'in-sync'}],
#    'AvailabilityZone': 'us-gov-west-1b',
#    'DBSubnetGroup': {'DBSubnetGroupName': 'default-vpc-ef7cfa8a',
#     'DBSubnetGroupDescription': 'Database subnet group for staging',
#     'VpcId': 'vpc-ef7cfa8a',
#     'SubnetGroupStatus': 'Complete',
#     'Subnets': [{'SubnetIdentifier': 'subnet-1db98378',
#       'SubnetAvailabilityZone': {'Name': 'us-gov-west-1b'},
#       'SubnetOutpost': {},
#       'SubnetStatus': 'Active'},
#      {'SubnetIdentifier': 'subnet-ea22089d',
#       'SubnetAvailabilityZone': {'Name': 'us-gov-west-1a'},
#       'SubnetOutpost': {},
#       'SubnetStatus': 'Active'}]},
#    'PreferredMaintenanceWindow': 'tue:12:35-tue:13:05',
#    'PendingModifiedValues': {},
#    'MultiAZ': False,
#    'EngineVersion': '11.15',
#    'AutoMinorVersionUpgrade': True,
#    'ReadReplicaDBInstanceIdentifiers': [],
#    'LicenseModel': 'postgresql-license',
#    'OptionGroupMemberships': [{'OptionGroupName': 'default:aurora-postgresql-11',
#      'Status': 'in-sync'}],
#    'PubliclyAccessible': False,
#    'StorageType': 'aurora',
#    'DbInstancePort': 0,
#    'DBClusterIdentifier': 'appeals-uat-caseflow-aurora-cluster',
#    'StorageEncrypted': True,
#    'KmsKeyId': 'arn:aws-us-gov:kms:us-gov-west-1:008577686731:key/bc1cbc6f-9cc6-4f60-bcac-622c5cb091b2',
#    'DbiResourceId': 'db-EXWMOJR7J6HECRWWLEAVVZP6FU',
#    'CACertificateIdentifier': 'rds-ca-rsa4096-g1',
#    'DomainMemberships': [],
#    'CopyTagsToSnapshot': True,
#    'MonitoringInterval': 0,
#    'PromotionTier': 0,
#    'DBInstanceArn': 'arn:aws-us-gov:rds:us-gov-west-1:008577686731:db:appeals-uat-caseflow-aurora-reader',
#    'IAMDatabaseAuthenticationEnabled': False,
#    'PerformanceInsightsEnabled': False,
#    'EnabledCloudwatchLogsExports': ['postgresql'],
#    'DeletionProtection': False,
#    'AssociatedRoles': [],
#    'TagList': [{'Key': 'ProjectName', 'Value': 'Caseflow'},
#     {'Key': 'project', 'Value': 'appeals'},
#     {'Key': 'office', 'Value': 'osva'},
#     {'Key': 'Name', 'Value': 'appeals-uat-caseflow-aurora-reader'},
#     {'Key': 'VAECID', 'Value': 'AWG20180405001'},
#     {'Key': 'environment', 'Value': 'uat'},
#     {'Key': 'Adminstration', 'Value': 'VBA'},
#     {'Key': 'provider', 'Value': 'aws'},
#     {'Key': 'managed', 'Value': 'terraform'},
#     {'Key': 'region', 'Value': 'govcloud'},
#     {'Key': 'suboffice', 'Value': 'cto'},
#     {'Key': 'ProjectShort', 'Value': 'Caseflow'},
#     {'Key': 'dsva_version', 'Value': 'v2'},
#     {'Key': 'group', 'Value': 'dsva'}],
#    'CustomerOwnedIpEnabled': False,
#    'BackupTarget': 'region'},
#   {'DBInstanceIdentifier': 'appeals-uat-efolder-aurora-primary',
#    'DBInstanceClass': 'db.r4.xlarge',
#    'Engine': 'aurora-postgresql',
#    'DBInstanceStatus': 'available',
#    'MasterUsername': 'efolder_express',
#    'DBName': 'efolder_express',
#    'Endpoint': {'Address': 'appeals-uat-efolder-aurora-primary.cdqbofmbcmtd.us-gov-west-1.rds.amazonaws.com',
#     'Port': 5432,
#     'HostedZoneId': 'Z2YROVNTF0QJSQ'},
#    'AllocatedStorage': 100,
#    'InstanceCreateTime': datetime.datetime(2021, 8, 25, 15, 39, 42, 484000, tzinfo=tzutc()),
#    'PreferredBackupWindow': '09:18-09:48',
#    'BackupRetentionPeriod': 7,
#    'DBSecurityGroups': [],
#    'VpcSecurityGroups': [{'VpcSecurityGroupId': 'sg-0095b2f1a9b3a612b',
#      'Status': 'active'}],
#    'DBParameterGroups': [{'DBParameterGroupName': 'default.aurora-postgresql11',
#      'ParameterApplyStatus': 'in-sync'}],
#    'AvailabilityZone': 'us-gov-west-1b',
#    'DBSubnetGroup': {'DBSubnetGroupName': 'default-vpc-ef7cfa8a',
#     'DBSubnetGroupDescription': 'Database subnet group for staging',
#     'VpcId': 'vpc-ef7cfa8a',
#     'SubnetGroupStatus': 'Complete',
#     'Subnets': [{'SubnetIdentifier': 'subnet-1db98378',
#       'SubnetAvailabilityZone': {'Name': 'us-gov-west-1b'},
#       'SubnetOutpost': {},
#       'SubnetStatus': 'Active'},
#      {'SubnetIdentifier': 'subnet-ea22089d',
#       'SubnetAvailabilityZone': {'Name': 'us-gov-west-1a'},
#       'SubnetOutpost': {},
#       'SubnetStatus': 'Active'}]},
#    'PreferredMaintenanceWindow': 'fri:08:12-fri:08:42',
#    'PendingModifiedValues': {},
#    'MultiAZ': False,
#    'EngineVersion': '11.15',
#    'AutoMinorVersionUpgrade': True,
#    'ReadReplicaDBInstanceIdentifiers': [],
#    'LicenseModel': 'postgresql-license',
#    'OptionGroupMemberships': [{'OptionGroupName': 'default:aurora-postgresql-11',
#      'Status': 'in-sync'}],
#    'PubliclyAccessible': False,
#    'StorageType': 'aurora',
#    'DbInstancePort': 0,
#    'DBClusterIdentifier': 'appeals-uat-efolder-aurora-cluster',
#    'StorageEncrypted': True,
#    'KmsKeyId': 'arn:aws-us-gov:kms:us-gov-west-1:008577686731:key/ec97b6a7-b644-416e-b9fd-99f9d34e857f',
#    'DbiResourceId': 'db-2KBY6MWI5RBJ2D5ZCVRX7ZJMCA',
#    'CACertificateIdentifier': 'rds-ca-rsa4096-g1',
#    'DomainMemberships': [],
#    'CopyTagsToSnapshot': True,
#    'MonitoringInterval': 0,
#    'PromotionTier': 0,
#    'DBInstanceArn': 'arn:aws-us-gov:rds:us-gov-west-1:008577686731:db:appeals-uat-efolder-aurora-primary',
#    'IAMDatabaseAuthenticationEnabled': False,
#    'PerformanceInsightsEnabled': False,
#    'EnabledCloudwatchLogsExports': ['postgresql'],
#    'DeletionProtection': False,
#    'AssociatedRoles': [],
#    'TagList': [{'Key': 'ProjectName', 'Value': 'Caseflow'},
#     {'Key': 'project', 'Value': 'appeals'},
#     {'Key': 'office', 'Value': 'osva'},
#     {'Key': 'Name', 'Value': 'appeals-uat-efolder-aurora-primary'},
#     {'Key': 'VAECID', 'Value': 'AWG20180405001'},
#     {'Key': 'environment', 'Value': 'uat'},
#     {'Key': 'Adminstration', 'Value': 'VBA'},
#     {'Key': 'provider', 'Value': 'aws'},
#     {'Key': 'managed', 'Value': 'terraform'},
#     {'Key': 'region', 'Value': 'govcloud'},
#     {'Key': 'suboffice', 'Value': 'cto'},
#     {'Key': 'ProjectShort', 'Value': 'Caseflow'},
#     {'Key': 'dsva_version', 'Value': 'v2'},
#     {'Key': 'group', 'Value': 'dsva'}],
#    'CustomerOwnedIpEnabled': False,
#    'BackupTarget': 'region'},
#   {'DBInstanceIdentifier': 'appeals-uat-etl',
#    'DBInstanceClass': 'db.t2.medium',
#    'Engine': 'postgres',
#    'DBInstanceStatus': 'available',
#    'MasterUsername': 'caseflowetluat',
#    'DBName': 'caseflow_etl',
#    'Endpoint': {'Address': 'appeals-uat-etl.cdqbofmbcmtd.us-gov-west-1.rds.amazonaws.com',
#     'Port': 5432,
#     'HostedZoneId': 'Z2YROVNTF0QJSQ'},
#    'AllocatedStorage': 300,
#    'InstanceCreateTime': datetime.datetime(2021, 8, 30, 13, 6, 42, 166000, tzinfo=tzutc()),
#    'PreferredBackupWindow': '09:33-10:03',
#    'BackupRetentionPeriod': 0,
#    'DBSecurityGroups': [],
#    'VpcSecurityGroups': [{'VpcSecurityGroupId': 'sg-05246c41007d39430',
#      'Status': 'active'}],
#    'DBParameterGroups': [{'DBParameterGroupName': 'default.postgres11',
#      'ParameterApplyStatus': 'in-sync'}],
#    'AvailabilityZone': 'us-gov-west-1a',
#    'DBSubnetGroup': {'DBSubnetGroupName': 'default-vpc-ef7cfa8a',
#     'DBSubnetGroupDescription': 'Database subnet group for staging',
#     'VpcId': 'vpc-ef7cfa8a',
#     'SubnetGroupStatus': 'Complete',
#     'Subnets': [{'SubnetIdentifier': 'subnet-1db98378',
#       'SubnetAvailabilityZone': {'Name': 'us-gov-west-1b'},
#       'SubnetOutpost': {},
#       'SubnetStatus': 'Active'},
#      {'SubnetIdentifier': 'subnet-ea22089d',
#       'SubnetAvailabilityZone': {'Name': 'us-gov-west-1a'},
#       'SubnetOutpost': {},
#       'SubnetStatus': 'Active'}]},
#    'PreferredMaintenanceWindow': 'sun:11:32-sun:12:02',
#    'PendingModifiedValues': {},
#    'MultiAZ': False,
#    'EngineVersion': '11.15',
#    'AutoMinorVersionUpgrade': False,
#    'ReadReplicaDBInstanceIdentifiers': [],
#    'LicenseModel': 'postgresql-license',
#    'OptionGroupMemberships': [{'OptionGroupName': 'default:postgres-11',
#      'Status': 'in-sync'}],
#    'PubliclyAccessible': False,
#    'StorageType': 'gp2',
#    'DbInstancePort': 0,
#    'StorageEncrypted': True,
#    'KmsKeyId': 'arn:aws-us-gov:kms:us-gov-west-1:008577686731:key/da52fa14-0ee7-4e02-bc43-e09d2e0638c9',
#    'DbiResourceId': 'db-5JKK7FNHQ7LMRI3NMLBGD5JRVE',
#    'CACertificateIdentifier': 'rds-ca-rsa4096-g1',
#    'DomainMemberships': [],
#    'CopyTagsToSnapshot': True,
#    'MonitoringInterval': 0,
#    'DBInstanceArn': 'arn:aws-us-gov:rds:us-gov-west-1:008577686731:db:appeals-uat-etl',
#    'IAMDatabaseAuthenticationEnabled': False,
#    'PerformanceInsightsEnabled': False,
#    'DeletionProtection': True,
#    'AssociatedRoles': [],
#    'MaxAllocatedStorage': 2000,
#    'TagList': [{'Key': 'ProjectName', 'Value': 'Caseflow'},
#     {'Key': 'project', 'Value': 'appeals'},
#     {'Key': 'office', 'Value': 'osva'},
#     {'Key': 'Name', 'Value': 'appeals-uat-etl'},
#     {'Key': 'VAECID', 'Value': 'AWG20180405001'},
#     {'Key': 'environment', 'Value': 'uat'},
#     {'Key': 'Adminstration', 'Value': 'VBA'},
#     {'Key': 'provider', 'Value': 'aws'},
#     {'Key': 'managed', 'Value': 'terraform'},
#     {'Key': 'region', 'Value': 'govcloud'},
#     {'Key': 'suboffice', 'Value': 'cto'},
#     {'Key': 'ProjectShort', 'Value': 'Caseflow'},
#     {'Key': 'dsva_version', 'Value': 'v2'},
#     {'Key': 'group', 'Value': 'dsva'}],
#    'CustomerOwnedIpEnabled': False,
#    'BackupTarget': 'region'},
#   {'DBInstanceIdentifier': 'appeals-uat-sentry',
#    'DBInstanceClass': 'db.t2.small',
#    'Engine': 'postgres',
#    'DBInstanceStatus': 'available',
#    'MasterUsername': 'dsva',
#    'Endpoint': {'Address': 'appeals-uat-sentry.cdqbofmbcmtd.us-gov-west-1.rds.amazonaws.com',
#     'Port': 5432,
#     'HostedZoneId': 'Z2YROVNTF0QJSQ'},
#    'AllocatedStorage': 50,
#    'InstanceCreateTime': datetime.datetime(2021, 8, 31, 12, 47, 50, 837000, tzinfo=tzutc()),
#    'PreferredBackupWindow': '11:32-12:02',
#    'BackupRetentionPeriod': 7,
#    'DBSecurityGroups': [],
#    'VpcSecurityGroups': [{'VpcSecurityGroupId': 'sg-098ededfd49f47484',
#      'Status': 'active'}],
#    'DBParameterGroups': [{'DBParameterGroupName': 'default.postgres12',
#      'ParameterApplyStatus': 'in-sync'}],
#    'AvailabilityZone': 'us-gov-west-1b',
#    'DBSubnetGroup': {'DBSubnetGroupName': 'default-vpc-ef7cfa8a',
#     'DBSubnetGroupDescription': 'Database subnet group for staging',
#     'VpcId': 'vpc-ef7cfa8a',
#     'SubnetGroupStatus': 'Complete',
#     'Subnets': [{'SubnetIdentifier': 'subnet-1db98378',
#       'SubnetAvailabilityZone': {'Name': 'us-gov-west-1b'},
#       'SubnetOutpost': {},
#       'SubnetStatus': 'Active'},
#      {'SubnetIdentifier': 'subnet-ea22089d',
#       'SubnetAvailabilityZone': {'Name': 'us-gov-west-1a'},
#       'SubnetOutpost': {},
#       'SubnetStatus': 'Active'}]},
#    'PreferredMaintenanceWindow': 'thu:09:05-thu:09:35',
#    'PendingModifiedValues': {},
#    'LatestRestorableTime': datetime.datetime(2022, 5, 18, 2, 54, 39, tzinfo=tzutc()),
#    'MultiAZ': False,
#    'EngineVersion': '12.10',
#    'AutoMinorVersionUpgrade': False,
#    'ReadReplicaDBInstanceIdentifiers': [],
#    'LicenseModel': 'postgresql-license',
#    'OptionGroupMemberships': [{'OptionGroupName': 'default:postgres-12',
#      'Status': 'in-sync'}],
#    'PubliclyAccessible': False,
#    'StorageType': 'gp2',
#    'DbInstancePort': 0,
#    'StorageEncrypted': False,
#    'DbiResourceId': 'db-MMQRVNLZ3ZARASVUL32MXCM2CA',
#    'CACertificateIdentifier': 'rds-ca-rsa4096-g1',
#    'DomainMemberships': [],
#    'CopyTagsToSnapshot': True,
#    'MonitoringInterval': 0,
#    'DBInstanceArn': 'arn:aws-us-gov:rds:us-gov-west-1:008577686731:db:appeals-uat-sentry',
#    'IAMDatabaseAuthenticationEnabled': False,
#    'PerformanceInsightsEnabled': False,
#    'DeletionProtection': True,
#    'AssociatedRoles': [],
#    'TagList': [{'Key': 'ProjectName', 'Value': 'Caseflow'},
#     {'Key': 'project', 'Value': 'appeals'},
#     {'Key': 'office', 'Value': 'osva'},
#     {'Key': 'Name', 'Value': 'appeals-uat-sentry'},
#     {'Key': 'VAECID', 'Value': 'AWG20180405001'},
#     {'Key': 'environment', 'Value': 'uat'},
#     {'Key': 'Adminstration', 'Value': 'VBA'},
#     {'Key': 'provider', 'Value': 'aws'},
#     {'Key': 'managed', 'Value': 'terraform'},
#     {'Key': 'region', 'Value': 'govcloud'},
#     {'Key': 'suboffice', 'Value': 'cto'},
#     {'Key': 'ProjectShort', 'Value': 'Caseflow'},
#     {'Key': 'dsva_version', 'Value': 'v2'},
#     {'Key': 'group', 'Value': 'dsva'}],
#    'CustomerOwnedIpEnabled': False,
#    'BackupTarget': 'region'},
#   {'DBInstanceIdentifier': 'dsva-appeals-etl-spoke-prod',
#    'DBInstanceClass': 'db.r4.large',
#    'Engine': 'postgres',
#    'DBInstanceStatus': 'available',
#    'MasterUsername': 'caseflowetlprod',
#    'DBName': 'caseflow_etl',
#    'Endpoint': {'Address': 'dsva-appeals-etl-spoke-prod.cdqbofmbcmtd.us-gov-west-1.rds.amazonaws.com',
#     'Port': 5432,
#     'HostedZoneId': 'Z2YROVNTF0QJSQ'},
#    'AllocatedStorage': 300,
#    'InstanceCreateTime': datetime.datetime(2019, 12, 10, 21, 34, 9, 682000, tzinfo=tzutc()),
#    'PreferredBackupWindow': '10:14-10:44',
#    'BackupRetentionPeriod': 30,
#    'DBSecurityGroups': [],
#    'VpcSecurityGroups': [{'VpcSecurityGroupId': 'sg-0e1b55f2471ac46dc',
#      'Status': 'active'}],
#    'DBParameterGroups': [{'DBParameterGroupName': 'default.postgres11',
#      'ParameterApplyStatus': 'in-sync'}],
#    'AvailabilityZone': 'us-gov-west-1a',
#    'DBSubnetGroup': {'DBSubnetGroupName': 'default-vpc-527dfb37',
#     'DBSubnetGroupDescription': 'Database subnet group for prod',
#     'VpcId': 'vpc-527dfb37',
#     'SubnetGroupStatus': 'Complete',
#     'Subnets': [{'SubnetIdentifier': 'subnet-7f220808',
#       'SubnetAvailabilityZone': {'Name': 'us-gov-west-1a'},
#       'SubnetOutpost': {},
#       'SubnetStatus': 'Active'},
#      {'SubnetIdentifier': 'subnet-5ab9833f',
#       'SubnetAvailabilityZone': {'Name': 'us-gov-west-1b'},
#       'SubnetOutpost': {},
#       'SubnetStatus': 'Active'}]},
#    'PreferredMaintenanceWindow': 'wed:08:45-wed:09:15',
#    'PendingModifiedValues': {},
#    'LatestRestorableTime': datetime.datetime(2022, 5, 18, 2, 54, 39, tzinfo=tzutc()),
#    'MultiAZ': False,
#    'EngineVersion': '11.15',
#    'AutoMinorVersionUpgrade': False,
#    'ReadReplicaDBInstanceIdentifiers': [],
#    'LicenseModel': 'postgresql-license',
#    'OptionGroupMemberships': [{'OptionGroupName': 'default:postgres-11',
#      'Status': 'in-sync'}],
#    'PubliclyAccessible': False,
#    'StorageType': 'gp2',
#    'DbInstancePort': 0,
#    'StorageEncrypted': True,
#    'KmsKeyId': 'arn:aws-us-gov:kms:us-gov-west-1:008577686731:key/da52fa14-0ee7-4e02-bc43-e09d2e0638c9',
#    'DbiResourceId': 'db-M42DBES3NYLA4CMRVPMZCFMPD4',
#    'CACertificateIdentifier': 'rds-ca-rsa4096-g1',
#    'DomainMemberships': [],
#    'CopyTagsToSnapshot': True,
#    'MonitoringInterval': 0,
#    'DBInstanceArn': 'arn:aws-us-gov:rds:us-gov-west-1:008577686731:db:dsva-appeals-etl-spoke-prod',
#    'IAMDatabaseAuthenticationEnabled': False,
#    'PerformanceInsightsEnabled': False,
#    'DeletionProtection': True,
#    'AssociatedRoles': [],
#    'MaxAllocatedStorage': 2000,
#    'TagList': [{'Key': 'ProjectName', 'Value': 'Caseflow'},
#     {'Key': 'project', 'Value': 'appeals'},
#     {'Key': 'office', 'Value': 'osva'},
#     {'Key': 'Name', 'Value': 'dsva-appeals-etl-spoke-prod'},
#     {'Key': 'VAECID', 'Value': 'AWG20180405001'},
#     {'Key': 'environment', 'Value': 'prod'},
#     {'Key': 'Adminstration', 'Value': 'VBA'},
#     {'Key': 'provider', 'Value': 'aws'},
#     {'Key': 'managed', 'Value': 'terraform'},
#     {'Key': 'region', 'Value': 'govcloud'},
#     {'Key': 'suboffice', 'Value': 'cto'},
#     {'Key': 'ProjectShort', 'Value': 'Caseflow'},
#     {'Key': 'dsva_version', 'Value': 'v2'},
#     {'Key': 'group', 'Value': 'dsva'}],
#    'CustomerOwnedIpEnabled': False,
#    'BackupTarget': 'region'},
#   {'DBInstanceIdentifier': 'dsva-appeals-metabase-spoke-prod',
#    'DBInstanceClass': 'db.r4.large',
#    'Engine': 'aurora-postgresql',
#    'DBInstanceStatus': 'available',
#    'MasterUsername': 'appeals_devops',
#    'DBName': 'appealsmetabase',
#    'Endpoint': {'Address': 'dsva-appeals-metabase-spoke-prod.cdqbofmbcmtd.us-gov-west-1.rds.amazonaws.com',
#     'Port': 5432,
#     'HostedZoneId': 'Z2YROVNTF0QJSQ'},
#    'AllocatedStorage': 1,
#    'InstanceCreateTime': datetime.datetime(2020, 1, 2, 15, 35, 28, 325000, tzinfo=tzutc()),
#    'PreferredBackupWindow': '11:02-11:32',
#    'BackupRetentionPeriod': 5,
#    'DBSecurityGroups': [],
#    'VpcSecurityGroups': [{'VpcSecurityGroupId': 'sg-bd65e0d9',
#      'Status': 'active'}],
#    'DBParameterGroups': [{'DBParameterGroupName': 'default.aurora-postgresql11',
#      'ParameterApplyStatus': 'in-sync'}],
#    'AvailabilityZone': 'us-gov-west-1a',
#    'DBSubnetGroup': {'DBSubnetGroupName': 'default-vpc-527dfb37',
#     'DBSubnetGroupDescription': 'Database subnet group for prod',
#     'VpcId': 'vpc-527dfb37',
#     'SubnetGroupStatus': 'Complete',
#     'Subnets': [{'SubnetIdentifier': 'subnet-7f220808',
#       'SubnetAvailabilityZone': {'Name': 'us-gov-west-1a'},
#       'SubnetOutpost': {},
#       'SubnetStatus': 'Active'},
#      {'SubnetIdentifier': 'subnet-5ab9833f',
#       'SubnetAvailabilityZone': {'Name': 'us-gov-west-1b'},
#       'SubnetOutpost': {},
#       'SubnetStatus': 'Active'}]},
#    'PreferredMaintenanceWindow': 'sat:23:35-sun:01:35',
#    'PendingModifiedValues': {},
#    'MultiAZ': False,
#    'EngineVersion': '11.15',
#    'AutoMinorVersionUpgrade': False,
#    'ReadReplicaDBInstanceIdentifiers': [],
#    'LicenseModel': 'postgresql-license',
#    'OptionGroupMemberships': [{'OptionGroupName': 'default:aurora-postgresql-11',
#      'Status': 'in-sync'}],
#    'PubliclyAccessible': False,
#    'StorageType': 'aurora',
#    'DbInstancePort': 0,
#    'DBClusterIdentifier': 'appealsmetabase',
#    'StorageEncrypted': True,
#    'KmsKeyId': 'arn:aws-us-gov:kms:us-gov-west-1:008577686731:key/da52fa14-0ee7-4e02-bc43-e09d2e0638c9',
#    'DbiResourceId': 'db-2DLIYE2XQCZJCIIQ3OOGNNYFGE',
#    'CACertificateIdentifier': 'rds-ca-rsa4096-g1',
# ...
#    'PubliclyAccessible': False,
#    'StorageType': 'gp2',
#    'DbInstancePort': 0,
#    'StorageEncrypted': True,
#    'KmsKeyId': 'arn:aws-us-gov:kms:us-gov-west-1:008577686731:key/da52fa14-0ee7-4e02-bc43-e09d2e0638c9',
#    'DbiResourceId': 'db-3MLQUTINTZWUAJMXZPVEULOMWM',
#    'CACertificateIdentifier': 'rds-ca-2017',
#    'DomainMemberships': [],
#    'CopyTagsToSnapshot': True,
#    'MonitoringInterval': 0,
#    'DBInstanceArn': 'arn:aws-us-gov:rds:us-gov-west-1:008577686731:db:dvp-dev-api-gateway-db',
#    'IAMDatabaseAuthenticationEnabled': False,
#    'PerformanceInsightsEnabled': False,
#    'EnabledCloudwatchLogsExports': ['postgresql', 'upgrade'],
#    'DeletionProtection': True,
#    'AssociatedRoles': [],
#    'TagList': [{'Key': 'Office', 'Value': 'tbd'},
#     {'Key': 'ProjectName', 'Value': 'VA Vets.gov'},
#     {'Key': 'ResTag', 'Value': 'shared'},
#     {'Key': 'project', 'Value': 'dvp'},
#     {'Key': 'office', 'Value': 'osva'},
#     {'Key': 'Name', 'Value': 'dsva-dvp-dev-api-gateway'},
#     {'Key': 'Role', 'Value': 'tbd'},
#     {'Key': 'VAECID', 'Value': 'AWG20180517003'},
#     {'Key': 'ConnectionID', 'Value': '313-68'},
#     {'Key': 'environment', 'Value': 'dev'},
#     {'Key': 'Adminstration', 'Value': 'TBD'},
#     {'Key': 'application', 'Value': 'api-gateway'},
#     {'Key': 'provider', 'Value': 'aws'},
#     {'Key': 'managed', 'Value': 'terraform'},
#     {'Key': 'Environment', 'Value': 'DEV'},
#     {'Key': 'region', 'Value': 'govcloud'},
#     {'Key': 'suboffice', 'Value': 'cto'},
#     {'Key': 'ProjectShort', 'Value': 'Vets.gov'},
#     {'Key': 'dsva_version', 'Value': 'v2'}],
#    'CustomerOwnedIpEnabled': False,
#    'BackupTarget': 'region'},
#   {'DBInstanceIdentifier': 'dvp-prod-api-gateway-db',
#    'DBInstanceClass': 'db.m4.large',
#    'Engine': 'postgres',
#    'DBInstanceStatus': 'available',
#    'MasterUsername': 'api_gateway_kong',
#    'DBName': 'api_gateway',
#    'Endpoint': {'Address': 'dvp-prod-api-gateway-db.cdqbofmbcmtd.us-gov-west-1.rds.amazonaws.com',
#     'Port': 5432,
#     'HostedZoneId': 'Z2YROVNTF0QJSQ'},
#    'AllocatedStorage': 100,
#    'InstanceCreateTime': datetime.datetime(2019, 3, 27, 21, 18, 34, 930000, tzinfo=tzutc()),
#    'PreferredBackupWindow': '08:45-09:15',
#    'BackupRetentionPeriod': 7,
#    'DBSecurityGroups': [],
#    'VpcSecurityGroups': [{'VpcSecurityGroupId': 'sg-d45e22b3',
#      'Status': 'active'},
#     {'VpcSecurityGroupId': 'sg-71298416', 'Status': 'active'}],
#    'DBParameterGroups': [{'DBParameterGroupName': 'default.postgres9.6',
#      'ParameterApplyStatus': 'in-sync'}],
#    'AvailabilityZone': 'us-gov-west-1b',
#    'DBSubnetGroup': {'DBSubnetGroupName': 'dsva-dvp-prod-api-gateway-db-sng',
#     'DBSubnetGroupDescription': 'api-gateway prod PostgreSQL subnet group',
#     'VpcId': 'vpc-fcbd4298',
#     'SubnetGroupStatus': 'Complete',
#     'Subnets': [{'SubnetIdentifier': 'subnet-6fa52a0b',
#       'SubnetAvailabilityZone': {'Name': 'us-gov-west-1b'},
#       'SubnetOutpost': {},
#       'SubnetStatus': 'Active'},
#      {'SubnetIdentifier': 'subnet-03c44475',
#       'SubnetAvailabilityZone': {'Name': 'us-gov-west-1a'},
#       'SubnetOutpost': {},
#       'SubnetStatus': 'Active'},
#      {'SubnetIdentifier': 'subnet-4578971c',
#       'SubnetAvailabilityZone': {'Name': 'us-gov-west-1c'},
#       'SubnetOutpost': {},
#       'SubnetStatus': 'Active'}]},
#    'PreferredMaintenanceWindow': 'thu:10:21-thu:10:51',
#    'PendingModifiedValues': {},
#    'LatestRestorableTime': datetime.datetime(2022, 5, 18, 2, 54, 33, tzinfo=tzutc()),
#    'MultiAZ': True,
#    'EngineVersion': '9.6.23',
#    'AutoMinorVersionUpgrade': True,
#    'ReadReplicaDBInstanceIdentifiers': [],
#    'LicenseModel': 'postgresql-license',
#    'OptionGroupMemberships': [{'OptionGroupName': 'default:postgres-9-6',
#      'Status': 'in-sync'}],
#    'SecondaryAvailabilityZone': 'us-gov-west-1a',
#    'PubliclyAccessible': False,
#    'StorageType': 'gp2',
#    'DbInstancePort': 0,
#    'StorageEncrypted': True,
#    'KmsKeyId': 'arn:aws-us-gov:kms:us-gov-west-1:008577686731:key/da52fa14-0ee7-4e02-bc43-e09d2e0638c9',
#    'DbiResourceId': 'db-KA2QOGEGO5IP5NYVVNO3QGUZEQ',
#    'CACertificateIdentifier': 'rds-ca-2017',
#    'DomainMemberships': [],
#    'CopyTagsToSnapshot': True,
#    'MonitoringInterval': 0,
#    'DBInstanceArn': 'arn:aws-us-gov:rds:us-gov-west-1:008577686731:db:dvp-prod-api-gateway-db',
#    'IAMDatabaseAuthenticationEnabled': False,
#    'PerformanceInsightsEnabled': False,
#    'EnabledCloudwatchLogsExports': ['postgresql', 'upgrade'],
#    'DeletionProtection': True,
#    'AssociatedRoles': [],
#    'TagList': [{'Key': 'Office', 'Value': 'tbd'},
#     {'Key': 'ProjectName', 'Value': 'VA Vets.gov'},
#     {'Key': 'ResTag', 'Value': 'shared'},
#     {'Key': 'project', 'Value': 'dvp'},
#     {'Key': 'office', 'Value': 'osva'},
#     {'Key': 'Name', 'Value': 'dsva-dvp-prod-api-gateway'},
#     {'Key': 'Role', 'Value': 'tbd'},
#     {'Key': 'VAECID', 'Value': 'AWG20180517003'},
#     {'Key': 'environment', 'Value': 'prod'},
#     {'Key': 'Adminstration', 'Value': 'TBD'},
#     {'Key': 'application', 'Value': 'api-gateway'},
#     {'Key': 'provider', 'Value': 'aws'},
#     {'Key': 'managed', 'Value': 'terraform'},
#     {'Key': 'Environment', 'Value': 'PROD'},
#     {'Key': 'region', 'Value': 'govcloud'},
#     {'Key': 'suboffice', 'Value': 'cto'},
#     {'Key': 'ProjectShort', 'Value': 'Vets.gov'},
#     {'Key': 'dsva_version', 'Value': 'v2'}],
#    'CustomerOwnedIpEnabled': False,
#    'BackupTarget': 'region'},
#   {'DBInstanceIdentifier': 'dvp-sandbox-api-gateway-db',
#    'DBInstanceClass': 'db.m4.large',
#    'Engine': 'postgres',
#    'DBInstanceStatus': 'available',
#    'MasterUsername': 'api_gateway_kong',
#    'DBName': 'api_gateway',
#    'Endpoint': {'Address': 'dvp-sandbox-api-gateway-db.cdqbofmbcmtd.us-gov-west-1.rds.amazonaws.com',
#     'Port': 5432,
#     'HostedZoneId': 'Z2YROVNTF0QJSQ'},
#    'AllocatedStorage': 100,
#    'InstanceCreateTime': datetime.datetime(2019, 10, 4, 17, 12, 44, 370000, tzinfo=tzutc()),
#    'PreferredBackupWindow': '08:45-09:15',
#    'BackupRetentionPeriod': 7,
#    'DBSecurityGroups': [],
#    'VpcSecurityGroups': [{'VpcSecurityGroupId': 'sg-ba5a26dd',
#      'Status': 'active'},
#     {'VpcSecurityGroupId': 'sg-41e93227', 'Status': 'active'}],
#    'DBParameterGroups': [{'DBParameterGroupName': 'default.postgres9.6',
#      'ParameterApplyStatus': 'in-sync'}],
#    'AvailabilityZone': 'us-gov-west-1b',
#    'DBSubnetGroup': {'DBSubnetGroupName': 'dsva-dvp-sandbox-api-gateway-db-sng',
#     'DBSubnetGroupDescription': 'api-gateway sandbox PostgreSQL subnet group',
#     'VpcId': 'vpc-ec28e088',
#     'SubnetGroupStatus': 'Complete',
#     'Subnets': [{'SubnetIdentifier': 'subnet-4f98042b',
#       'SubnetAvailabilityZone': {'Name': 'us-gov-west-1b'},
#       'SubnetOutpost': {},
#       'SubnetStatus': 'Active'},
#      {'SubnetIdentifier': 'subnet-61e27217',
#       'SubnetAvailabilityZone': {'Name': 'us-gov-west-1a'},
#       'SubnetOutpost': {},
#       'SubnetStatus': 'Active'}]},
#    'PreferredMaintenanceWindow': 'thu:10:21-thu:10:51',
#    'PendingModifiedValues': {},
#    'LatestRestorableTime': datetime.datetime(2022, 5, 18, 2, 54, 34, tzinfo=tzutc()),
#    'MultiAZ': True,
#    'EngineVersion': '9.6.23',
#    'AutoMinorVersionUpgrade': True,
#    'ReadReplicaDBInstanceIdentifiers': [],
#    'LicenseModel': 'postgresql-license',
#    'OptionGroupMemberships': [{'OptionGroupName': 'default:postgres-9-6',
#      'Status': 'in-sync'}],
#    'SecondaryAvailabilityZone': 'us-gov-west-1a',
#    'PubliclyAccessible': False,
#    'StorageType': 'gp2',
#    'DbInstancePort': 0,
#    'StorageEncrypted': True,
#    'KmsKeyId': 'arn:aws-us-gov:kms:us-gov-west-1:008577686731:key/da52fa14-0ee7-4e02-bc43-e09d2e0638c9',
#    'DbiResourceId': 'db-2L3R73EIHLRJZ5QZGBG5AEWVBU',
#    'CACertificateIdentifier': 'rds-ca-2017',
#    'DomainMemberships': [],
#    'CopyTagsToSnapshot': True,
#    'MonitoringInterval': 0,
#    'DBInstanceArn': 'arn:aws-us-gov:rds:us-gov-west-1:008577686731:db:dvp-sandbox-api-gateway-db',
#    'IAMDatabaseAuthenticationEnabled': False,
#    'PerformanceInsightsEnabled': False,
#    'EnabledCloudwatchLogsExports': ['postgresql', 'upgrade'],
#    'DeletionProtection': True,
#    'AssociatedRoles': [],
#    'TagList': [{'Key': 'Office', 'Value': 'tbd'},
#     {'Key': 'ProjectName', 'Value': 'DVP Lighthouse Platform API'},
#     {'Key': 'ResTag', 'Value': 'shared'},
#     {'Key': 'project', 'Value': 'dvp'},
#     {'Key': 'office', 'Value': 'osva'},
#     {'Key': 'Name', 'Value': 'dsva-dvp-sandbox-api-gateway'},
#     {'Key': 'Role', 'Value': 'tbd'},
#     {'Key': 'VAECID', 'Value': 'AWG20180517003'},
#     {'Key': 'environment', 'Value': 'sandbox'},
#     {'Key': 'Adminstration', 'Value': 'TBD'},
#     {'Key': 'application', 'Value': 'api-gateway'},
#     {'Key': 'provider', 'Value': 'aws'},
#     {'Key': 'managed', 'Value': 'terraform'},
#     {'Key': 'Environment', 'Value': 'SANDBOX'},
#     {'Key': 'region', 'Value': 'govcloud'},
#     {'Key': 'suboffice', 'Value': 'cto'},
#     {'Key': 'ProjectShort', 'Value': 'DVP-Lighthouse'},
#     {'Key': 'dsva_version', 'Value': 'v2'}],
#    'CustomerOwnedIpEnabled': False,
#    'BackupTarget': 'region'},
#   {'DBInstanceIdentifier': 'dvp-staging-api-gateway-db',
#    'DBInstanceClass': 'db.m4.large',
#    'Engine': 'postgres',
#    'DBInstanceStatus': 'available',
#    'MasterUsername': 'api_gateway_kong',
#    'DBName': 'api_gateway',
#    'Endpoint': {'Address': 'dvp-staging-api-gateway-db.cdqbofmbcmtd.us-gov-west-1.rds.amazonaws.com',
#     'Port': 5432,
#     'HostedZoneId': 'Z2YROVNTF0QJSQ'},
#    'AllocatedStorage': 100,
#    'InstanceCreateTime': datetime.datetime(2019, 3, 27, 21, 1, 35, 955000, tzinfo=tzutc()),
#    'PreferredBackupWindow': '08:45-09:15',
#    'BackupRetentionPeriod': 7,
#    'DBSecurityGroups': [],
#    'VpcSecurityGroups': [{'VpcSecurityGroupId': 'sg-bd5c20da',
#      'Status': 'active'},
#     {'VpcSecurityGroupId': 'sg-665ef301', 'Status': 'active'}],
#    'DBParameterGroups': [{'DBParameterGroupName': 'default.postgres9.6',
#      'ParameterApplyStatus': 'in-sync'}],
#    'AvailabilityZone': 'us-gov-west-1a',
#    'DBSubnetGroup': {'DBSubnetGroupName': 'dsva-dvp-staging-api-gateway-db-sng',
#     'DBSubnetGroupDescription': 'api-gateway staging PostgreSQL subnet group',
#     'VpcId': 'vpc-0bb6496f',
#     'SubnetGroupStatus': 'Complete',
#     'Subnets': [{'SubnetIdentifier': 'subnet-1bcd4d6d',
#       'SubnetAvailabilityZone': {'Name': 'us-gov-west-1a'},
#       'SubnetOutpost': {},
#       'SubnetStatus': 'Active'},
#      {'SubnetIdentifier': 'subnet-60a82704',
#       'SubnetAvailabilityZone': {'Name': 'us-gov-west-1b'},
#       'SubnetOutpost': {},
#       'SubnetStatus': 'Active'}]},
#    'PreferredMaintenanceWindow': 'thu:10:21-thu:10:51',
#    'PendingModifiedValues': {},
#    'LatestRestorableTime': datetime.datetime(2022, 5, 18, 2, 54, 34, tzinfo=tzutc()),
#    'MultiAZ': True,
#    'EngineVersion': '9.6.23',
#    'AutoMinorVersionUpgrade': True,
#    'ReadReplicaDBInstanceIdentifiers': [],
#    'LicenseModel': 'postgresql-license',
#    'OptionGroupMemberships': [{'OptionGroupName': 'default:postgres-9-6',
#      'Status': 'in-sync'}],
#    'SecondaryAvailabilityZone': 'us-gov-west-1b',
#    'PubliclyAccessible': False,
#    'StorageType': 'gp2',
#    'DbInstancePort': 0,
#    'StorageEncrypted': True,
#    'KmsKeyId': 'arn:aws-us-gov:kms:us-gov-west-1:008577686731:key/da52fa14-0ee7-4e02-bc43-e09d2e0638c9',
#    'DbiResourceId': 'db-QT45PPQBO7YCJJ75GN2EI3XN2I',
#    'CACertificateIdentifier': 'rds-ca-2017',
#    'DomainMemberships': [],
#    'CopyTagsToSnapshot': True,
#    'MonitoringInterval': 0,
#    'DBInstanceArn': 'arn:aws-us-gov:rds:us-gov-west-1:008577686731:db:dvp-staging-api-gateway-db',
#    'IAMDatabaseAuthenticationEnabled': False,
#    'PerformanceInsightsEnabled': False,
#    'EnabledCloudwatchLogsExports': ['postgresql', 'upgrade'],
#    'DeletionProtection': True,
#    'AssociatedRoles': [],
#    'TagList': [{'Key': 'Office', 'Value': 'tbd'},
#     {'Key': 'ProjectName', 'Value': 'VA Vets.gov'},
#     {'Key': 'ResTag', 'Value': 'shared'},
#     {'Key': 'project', 'Value': 'dvp'},
#     {'Key': 'office', 'Value': 'osva'},
#     {'Key': 'Name', 'Value': 'dsva-dvp-staging-api-gateway'},
#     {'Key': 'Role', 'Value': 'tbd'},
#     {'Key': 'VAECID', 'Value': 'AWG20180517003'},
#     {'Key': 'environment', 'Value': 'staging'},
#     {'Key': 'Adminstration', 'Value': 'TBD'},
#     {'Key': 'application', 'Value': 'api-gateway'},
#     {'Key': 'provider', 'Value': 'aws'},
#     {'Key': 'managed', 'Value': 'terraform'},
#     {'Key': 'Environment', 'Value': 'STAGING'},
#     {'Key': 'region', 'Value': 'govcloud'},
#     {'Key': 'suboffice', 'Value': 'cto'},
#     {'Key': 'ProjectShort', 'Value': 'Vets.gov'},
#     {'Key': 'dsva_version', 'Value': 'v2'}],
#    'CustomerOwnedIpEnabled': False,
#    'BackupTarget': 'region'},
#   {'DBInstanceIdentifier': 'vacols-postgres-analytics',
#    'DBInstanceClass': 'db.m4.large',
#    'Engine': 'postgres',
#    'DBInstanceStatus': 'available',
#    'MasterUsername': 'DSUSERROOT',
#    'DBName': 'VACOLS',
#    'Endpoint': {'Address': 'vacols-postgres-analytics.cdqbofmbcmtd.us-gov-west-1.rds.amazonaws.com',
#     'Port': 5432,
#     'HostedZoneId': 'Z2YROVNTF0QJSQ'},
#    'AllocatedStorage': 100,
#    'InstanceCreateTime': datetime.datetime(2018, 7, 12, 17, 25, 7, 303000, tzinfo=tzutc()),
#    'PreferredBackupWindow': '10:46-11:16',
#    'BackupRetentionPeriod': 7,
#    'DBSecurityGroups': [],
#    'VpcSecurityGroups': [{'VpcSecurityGroupId': 'sg-d70584b3',
#      'Status': 'active'},
#     {'VpcSecurityGroupId': 'sg-10587375', 'Status': 'active'}],
#    'DBParameterGroups': [{'DBParameterGroupName': 'postgres96-logicalreplication',
#      'ParameterApplyStatus': 'in-sync'}],
#    'AvailabilityZone': 'us-gov-west-1a',
#    'DBSubnetGroup': {'DBSubnetGroupName': 'default-vpc-527dfb37',
#     'DBSubnetGroupDescription': 'Database subnet group for prod',
#     'VpcId': 'vpc-527dfb37',
#     'SubnetGroupStatus': 'Complete',
#     'Subnets': [{'SubnetIdentifier': 'subnet-7f220808',
#       'SubnetAvailabilityZone': {'Name': 'us-gov-west-1a'},
#       'SubnetOutpost': {},
#       'SubnetStatus': 'Active'},
#      {'SubnetIdentifier': 'subnet-5ab9833f',
#       'SubnetAvailabilityZone': {'Name': 'us-gov-west-1b'},
#       'SubnetOutpost': {},
#       'SubnetStatus': 'Active'}]},
#    'PreferredMaintenanceWindow': 'wed:07:07-wed:07:37',
#    'PendingModifiedValues': {},
#    'LatestRestorableTime': datetime.datetime(2022, 5, 18, 2, 54, 36, tzinfo=tzutc()),
#    'MultiAZ': True,
#    'EngineVersion': '9.6.23',
#    'AutoMinorVersionUpgrade': True,
#    'ReadReplicaDBInstanceIdentifiers': [],
#    'LicenseModel': 'postgresql-license',
#    'Iops': 1000,
#    'OptionGroupMemberships': [{'OptionGroupName': 'default:postgres-9-6',
#      'Status': 'in-sync'}],
#    'SecondaryAvailabilityZone': 'us-gov-west-1b',
#    'PubliclyAccessible': False,
#    'StorageType': 'io1',
#    'DbInstancePort': 0,
#    'StorageEncrypted': True,
#    'KmsKeyId': 'arn:aws-us-gov:kms:us-gov-west-1:008577686731:key/da52fa14-0ee7-4e02-bc43-e09d2e0638c9',
#    'DbiResourceId': 'db-BLMOXDKTYNFX4NMOKMCVKDCS74',
#    'CACertificateIdentifier': 'rds-ca-2017',
#    'DomainMemberships': [],
#    'CopyTagsToSnapshot': True,
#    'MonitoringInterval': 60,
#    'EnhancedMonitoringResourceArn': 'arn:aws-us-gov:logs:us-gov-west-1:008577686731:log-group:RDSOSMetrics:log-stream:db-BLMOXDKTYNFX4NMOKMCVKDCS74',
#    'MonitoringRoleArn': 'arn:aws-us-gov:iam::008577686731:role/rds-monitoring-role',
#    'DBInstanceArn': 'arn:aws-us-gov:rds:us-gov-west-1:008577686731:db:vacols-postgres-analytics',
#    'IAMDatabaseAuthenticationEnabled': False,
#    'PerformanceInsightsEnabled': False,
#    'DeletionProtection': False,
#    'AssociatedRoles': [],
#    'TagList': [{'Key': 'VAECID', 'Value': 'AWG20180405001'},
#     {'Key': 'workload-type', 'Value': 'production'},
#     {'Key': 'ProjectName', 'Value': 'Caseflow'},
#     {'Key': 'ProjectShort', 'Value': 'Caseflow'}],
#    'CustomerOwnedIpEnabled': False,
#    'BackupTarget': 'region'}],
#  'ResponseMetadata': {'RequestId': 'b5dd87e4-570d-4308-a981-bcb2eadf664b',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': 'b5dd87e4-570d-4308-a981-bcb2eadf664b',
#    'content-type': 'text/xml',
#    'content-length': '302495',
#    'date': 'Wed, 18 May 2022 02:59:09 GMT'},
#   'RetryAttempts': 0}}

# %%
get_db_instances = describe_rds_response.get("DBInstances")

# %%
get_db_instances
# Out:
# [{'DBInstanceIdentifier': 'appeals-preprod-caseflow-aurora-primary',
#   'DBInstanceClass': 'db.t3.medium',
#   'Engine': 'aurora-postgresql',
#   'DBInstanceStatus': 'available',
#   'MasterUsername': 'caseflow',
#   'DBName': 'caseflow_certification',
#   'Endpoint': {'Address': 'appeals-preprod-caseflow-aurora-primary.cdqbofmbcmtd.us-gov-west-1.rds.amazonaws.com',
#    'Port': 5432,
#    'HostedZoneId': 'Z2YROVNTF0QJSQ'},
#   'AllocatedStorage': 20,
#   'InstanceCreateTime': datetime.datetime(2021, 8, 20, 18, 46, 40, 813000, tzinfo=tzutc()),
#   'PreferredBackupWindow': '08:47-09:17',
#   'BackupRetentionPeriod': 7,
#   'DBSecurityGroups': [],
#   'VpcSecurityGroups': [{'VpcSecurityGroupId': 'sg-04a768d794318de67',
#     'Status': 'active'}],
#   'DBParameterGroups': [{'DBParameterGroupName': 'default.aurora-postgresql11',
#     'ParameterApplyStatus': 'in-sync'}],
#   'AvailabilityZone': 'us-gov-west-1b',
#   'DBSubnetGroup': {'DBSubnetGroupName': 'default-vpc-ef7cfa8a',
#    'DBSubnetGroupDescription': 'Database subnet group for staging',
#    'VpcId': 'vpc-ef7cfa8a',
#    'SubnetGroupStatus': 'Complete',
#    'Subnets': [{'SubnetIdentifier': 'subnet-1db98378',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1b'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'},
#     {'SubnetIdentifier': 'subnet-ea22089d',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1a'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'}]},
#   'PreferredMaintenanceWindow': 'sun:08:12-sun:08:42',
#   'PendingModifiedValues': {},
#   'MultiAZ': False,
#   'EngineVersion': '11.15',
#   'AutoMinorVersionUpgrade': False,
#   'ReadReplicaDBInstanceIdentifiers': [],
#   'LicenseModel': 'postgresql-license',
#   'OptionGroupMemberships': [{'OptionGroupName': 'default:aurora-postgresql-11',
#     'Status': 'in-sync'}],
#   'PubliclyAccessible': False,
#   'StorageType': 'aurora',
#   'DbInstancePort': 0,
#   'DBClusterIdentifier': 'appeals-preprod-caseflow-aurora-cluster',
#   'StorageEncrypted': True,
#   'KmsKeyId': 'arn:aws-us-gov:kms:us-gov-west-1:008577686731:key/41845171-61fd-43f1-9061-acedf9d6d823',
#   'DbiResourceId': 'db-SGDG5SMMXLMXOD7O6D5YFFJZQQ',
#   'CACertificateIdentifier': 'rds-ca-rsa4096-g1',
#   'DomainMemberships': [],
#   'CopyTagsToSnapshot': True,
#   'MonitoringInterval': 0,
#   'PromotionTier': 0,
#   'DBInstanceArn': 'arn:aws-us-gov:rds:us-gov-west-1:008577686731:db:appeals-preprod-caseflow-aurora-primary',
#   'IAMDatabaseAuthenticationEnabled': False,
#   'PerformanceInsightsEnabled': False,
#   'EnabledCloudwatchLogsExports': ['postgresql'],
#   'DeletionProtection': False,
#   'AssociatedRoles': [],
#   'TagList': [{'Key': 'ProjectName', 'Value': 'Caseflow'},
#    {'Key': 'project', 'Value': 'appeals'},
#    {'Key': 'office', 'Value': 'osva'},
#    {'Key': 'Name', 'Value': 'appeals-preprod-caseflow-aurora-primary'},
#    {'Key': 'VAECID', 'Value': 'AWG20180405001'},
#    {'Key': 'environment', 'Value': 'preprod'},
#    {'Key': 'Adminstration', 'Value': 'VBA'},
#    {'Key': 'provider', 'Value': 'aws'},
#    {'Key': 'managed', 'Value': 'terraform'},
#    {'Key': 'region', 'Value': 'govcloud'},
#    {'Key': 'suboffice', 'Value': 'cto'},
#    {'Key': 'ProjectShort', 'Value': 'Caseflow'},
#    {'Key': 'dsva_version', 'Value': 'v2'},
#    {'Key': 'group', 'Value': 'dsva'}],
#   'CustomerOwnedIpEnabled': False,
#   'BackupTarget': 'region'},
#  {'DBInstanceIdentifier': 'appeals-preprod-efolder-aurora-primary',
#   'DBInstanceClass': 'db.r4.xlarge',
#   'Engine': 'aurora-postgresql',
#   'DBInstanceStatus': 'available',
#   'MasterUsername': 'efolder_express',
#   'DBName': 'efolder_express',
#   'Endpoint': {'Address': 'appeals-preprod-efolder-aurora-primary.cdqbofmbcmtd.us-gov-west-1.rds.amazonaws.com',
#    'Port': 5432,
#    'HostedZoneId': 'Z2YROVNTF0QJSQ'},
#   'AllocatedStorage': 100,
#   'InstanceCreateTime': datetime.datetime(2021, 8, 25, 14, 37, 27, 414000, tzinfo=tzutc()),
#   'PreferredBackupWindow': '11:39-12:09',
#   'BackupRetentionPeriod': 7,
#   'DBSecurityGroups': [],
#   'VpcSecurityGroups': [{'VpcSecurityGroupId': 'sg-035a66de36ae41986',
#     'Status': 'active'}],
#   'DBParameterGroups': [{'DBParameterGroupName': 'default.aurora-postgresql11',
#     'ParameterApplyStatus': 'in-sync'}],
#   'AvailabilityZone': 'us-gov-west-1a',
#   'DBSubnetGroup': {'DBSubnetGroupName': 'default-vpc-ef7cfa8a',
#    'DBSubnetGroupDescription': 'Database subnet group for staging',
#    'VpcId': 'vpc-ef7cfa8a',
#    'SubnetGroupStatus': 'Complete',
#    'Subnets': [{'SubnetIdentifier': 'subnet-1db98378',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1b'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'},
#     {'SubnetIdentifier': 'subnet-ea22089d',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1a'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'}]},
#   'PreferredMaintenanceWindow': 'sat:11:16-sat:11:46',
#   'PendingModifiedValues': {},
#   'MultiAZ': False,
#   'EngineVersion': '11.15',
#   'AutoMinorVersionUpgrade': True,
#   'ReadReplicaDBInstanceIdentifiers': [],
#   'LicenseModel': 'postgresql-license',
#   'OptionGroupMemberships': [{'OptionGroupName': 'default:aurora-postgresql-11',
#     'Status': 'in-sync'}],
#   'PubliclyAccessible': False,
#   'StorageType': 'aurora',
#   'DbInstancePort': 0,
#   'DBClusterIdentifier': 'appeals-preprod-efolder-aurora-cluster',
#   'StorageEncrypted': True,
#   'KmsKeyId': 'arn:aws-us-gov:kms:us-gov-west-1:008577686731:key/b3fcaa93-eb3c-421a-9302-9da8cd3a30af',
#   'DbiResourceId': 'db-WQIQ25KVYDKTQWMJNAFO6PUDR4',
#   'CACertificateIdentifier': 'rds-ca-rsa4096-g1',
#   'DomainMemberships': [],
#   'CopyTagsToSnapshot': True,
#   'MonitoringInterval': 0,
#   'PromotionTier': 0,
#   'DBInstanceArn': 'arn:aws-us-gov:rds:us-gov-west-1:008577686731:db:appeals-preprod-efolder-aurora-primary',
#   'IAMDatabaseAuthenticationEnabled': False,
#   'PerformanceInsightsEnabled': False,
#   'EnabledCloudwatchLogsExports': ['postgresql'],
#   'DeletionProtection': False,
#   'AssociatedRoles': [],
#   'TagList': [{'Key': 'ProjectName', 'Value': 'Caseflow'},
#    {'Key': 'project', 'Value': 'appeals'},
#    {'Key': 'office', 'Value': 'osva'},
#    {'Key': 'Name', 'Value': 'appeals-preprod-efolder-aurora-primary'},
#    {'Key': 'VAECID', 'Value': 'AWG20180405001'},
#    {'Key': 'environment', 'Value': 'preprod'},
#    {'Key': 'Adminstration', 'Value': 'VBA'},
#    {'Key': 'provider', 'Value': 'aws'},
#    {'Key': 'managed', 'Value': 'terraform'},
#    {'Key': 'region', 'Value': 'govcloud'},
#    {'Key': 'suboffice', 'Value': 'cto'},
#    {'Key': 'ProjectShort', 'Value': 'Caseflow'},
#    {'Key': 'dsva_version', 'Value': 'v2'},
#    {'Key': 'group', 'Value': 'dsva'}],
#   'CustomerOwnedIpEnabled': False,
#   'BackupTarget': 'region'},
#  {'DBInstanceIdentifier': 'appeals-preprod-etl',
#   'DBInstanceClass': 'db.t2.medium',
#   'Engine': 'postgres',
#   'DBInstanceStatus': 'available',
#   'MasterUsername': 'caseflowetlpreprod',
#   'DBName': 'caseflow_etl',
#   'Endpoint': {'Address': 'appeals-preprod-etl.cdqbofmbcmtd.us-gov-west-1.rds.amazonaws.com',
#    'Port': 5432,
#    'HostedZoneId': 'Z2YROVNTF0QJSQ'},
#   'AllocatedStorage': 300,
#   'InstanceCreateTime': datetime.datetime(2021, 8, 30, 12, 46, 11, 894000, tzinfo=tzutc()),
#   'PreferredBackupWindow': '10:06-10:36',
#   'BackupRetentionPeriod': 10,
#   'DBSecurityGroups': [],
#   'VpcSecurityGroups': [{'VpcSecurityGroupId': 'sg-0ab53708fe340cee7',
#     'Status': 'active'}],
#   'DBParameterGroups': [{'DBParameterGroupName': 'default.postgres11',
#     'ParameterApplyStatus': 'in-sync'}],
#   'AvailabilityZone': 'us-gov-west-1a',
#   'DBSubnetGroup': {'DBSubnetGroupName': 'default-vpc-ef7cfa8a',
#    'DBSubnetGroupDescription': 'Database subnet group for staging',
#    'VpcId': 'vpc-ef7cfa8a',
#    'SubnetGroupStatus': 'Complete',
#    'Subnets': [{'SubnetIdentifier': 'subnet-1db98378',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1b'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'},
#     {'SubnetIdentifier': 'subnet-ea22089d',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1a'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'}]},
#   'PreferredMaintenanceWindow': 'sat:07:16-sat:07:46',
#   'PendingModifiedValues': {},
#   'LatestRestorableTime': datetime.datetime(2022, 5, 18, 2, 54, 36, tzinfo=tzutc()),
#   'MultiAZ': False,
#   'EngineVersion': '11.15',
#   'AutoMinorVersionUpgrade': False,
#   'ReadReplicaDBInstanceIdentifiers': [],
#   'LicenseModel': 'postgresql-license',
#   'OptionGroupMemberships': [{'OptionGroupName': 'default:postgres-11',
#     'Status': 'in-sync'}],
#   'PubliclyAccessible': False,
#   'StorageType': 'gp2',
#   'DbInstancePort': 0,
#   'StorageEncrypted': True,
#   'KmsKeyId': 'arn:aws-us-gov:kms:us-gov-west-1:008577686731:key/da52fa14-0ee7-4e02-bc43-e09d2e0638c9',
#   'DbiResourceId': 'db-J7DWOYUQEJCVRSINEMIZVDN65M',
#   'CACertificateIdentifier': 'rds-ca-rsa4096-g1',
#   'DomainMemberships': [],
#   'CopyTagsToSnapshot': True,
#   'MonitoringInterval': 0,
#   'DBInstanceArn': 'arn:aws-us-gov:rds:us-gov-west-1:008577686731:db:appeals-preprod-etl',
#   'IAMDatabaseAuthenticationEnabled': False,
#   'PerformanceInsightsEnabled': False,
#   'DeletionProtection': True,
#   'AssociatedRoles': [],
#   'MaxAllocatedStorage': 2000,
#   'TagList': [{'Key': 'ProjectName', 'Value': 'Caseflow'},
#    {'Key': 'project', 'Value': 'appeals'},
#    {'Key': 'office', 'Value': 'osva'},
#    {'Key': 'Name', 'Value': 'appeals-preprod-etl'},
#    {'Key': 'VAECID', 'Value': 'AWG20180405001'},
#    {'Key': 'environment', 'Value': 'preprod'},
#    {'Key': 'Adminstration', 'Value': 'VBA'},
#    {'Key': 'provider', 'Value': 'aws'},
#    {'Key': 'managed', 'Value': 'terraform'},
#    {'Key': 'region', 'Value': 'govcloud'},
#    {'Key': 'suboffice', 'Value': 'cto'},
#    {'Key': 'ProjectShort', 'Value': 'Caseflow'},
#    {'Key': 'dsva_version', 'Value': 'v2'},
#    {'Key': 'group', 'Value': 'dsva'}],
#   'CustomerOwnedIpEnabled': False,
#   'BackupTarget': 'region'},
#  {'DBInstanceIdentifier': 'appeals-prod-caseflow-aurora-primary',
#   'DBInstanceClass': 'db.r5.xlarge',
#   'Engine': 'aurora-postgresql',
#   'DBInstanceStatus': 'available',
#   'MasterUsername': 'caseflow',
#   'DBName': 'caseflow_certification',
#   'Endpoint': {'Address': 'appeals-prod-caseflow-aurora-primary.cdqbofmbcmtd.us-gov-west-1.rds.amazonaws.com',
#    'Port': 5432,
#    'HostedZoneId': 'Z2YROVNTF0QJSQ'},
#   'AllocatedStorage': 300,
#   'InstanceCreateTime': datetime.datetime(2021, 11, 20, 17, 45, 13, 450000, tzinfo=tzutc()),
#   'PreferredBackupWindow': '11:21-11:51',
#   'BackupRetentionPeriod': 35,
#   'DBSecurityGroups': [],
#   'VpcSecurityGroups': [{'VpcSecurityGroupId': 'sg-0df0e2159d72a5a10',
#     'Status': 'active'}],
#   'DBParameterGroups': [{'DBParameterGroupName': 'default.aurora-postgresql11',
#     'ParameterApplyStatus': 'in-sync'}],
#   'AvailabilityZone': 'us-gov-west-1b',
#   'DBSubnetGroup': {'DBSubnetGroupName': 'default-vpc-527dfb37',
#    'DBSubnetGroupDescription': 'Database subnet group for prod',
#    'VpcId': 'vpc-527dfb37',
#    'SubnetGroupStatus': 'Complete',
#    'Subnets': [{'SubnetIdentifier': 'subnet-7f220808',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1a'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'},
#     {'SubnetIdentifier': 'subnet-5ab9833f',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1b'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'}]},
#   'PreferredMaintenanceWindow': 'sat:04:12-sat:04:42',
#   'PendingModifiedValues': {},
#   'MultiAZ': False,
#   'EngineVersion': '11.15',
#   'AutoMinorVersionUpgrade': False,
#   'ReadReplicaDBInstanceIdentifiers': [],
#   'LicenseModel': 'postgresql-license',
#   'OptionGroupMemberships': [{'OptionGroupName': 'default:aurora-postgresql-11',
#     'Status': 'in-sync'}],
#   'PubliclyAccessible': False,
#   'StorageType': 'aurora',
#   'DbInstancePort': 0,
#   'DBClusterIdentifier': 'appeals-prod-caseflow-aurora-cluster',
#   'StorageEncrypted': True,
#   'KmsKeyId': 'arn:aws-us-gov:kms:us-gov-west-1:008577686731:key/fe091b47-2349-41f4-b5d0-06959e62ba12',
#   'DbiResourceId': 'db-3IMP2NQTEDS5RGLGEQD45WVOK4',
#   'CACertificateIdentifier': 'rds-ca-rsa4096-g1',
#   'DomainMemberships': [],
#   'CopyTagsToSnapshot': True,
#   'MonitoringInterval': 0,
#   'PromotionTier': 0,
#   'DBInstanceArn': 'arn:aws-us-gov:rds:us-gov-west-1:008577686731:db:appeals-prod-caseflow-aurora-primary',
#   'IAMDatabaseAuthenticationEnabled': False,
#   'PerformanceInsightsEnabled': False,
#   'EnabledCloudwatchLogsExports': ['postgresql'],
#   'DeletionProtection': False,
#   'AssociatedRoles': [],
#   'TagList': [{'Key': 'ProjectName', 'Value': 'Caseflow'},
#    {'Key': 'project', 'Value': 'appeals'},
#    {'Key': 'office', 'Value': 'osva'},
#    {'Key': 'Name', 'Value': 'appeals-prod-caseflow-aurora-primary'},
#    {'Key': 'VAECID', 'Value': 'AWG20180405001'},
#    {'Key': 'environment', 'Value': 'prod'},
#    {'Key': 'Adminstration', 'Value': 'VBA'},
#    {'Key': 'provider', 'Value': 'aws'},
#    {'Key': 'managed', 'Value': 'terraform'},
#    {'Key': 'region', 'Value': 'govcloud'},
#    {'Key': 'suboffice', 'Value': 'cto'},
#    {'Key': 'ProjectShort', 'Value': 'Caseflow'},
#    {'Key': 'dsva_version', 'Value': 'v2'},
#    {'Key': 'group', 'Value': 'dsva'}],
#   'CustomerOwnedIpEnabled': False,
#   'BackupTarget': 'region'},
#  {'DBInstanceIdentifier': 'appeals-prod-caseflow-aurora-reader',
#   'DBInstanceClass': 'db.r5.xlarge',
#   'Engine': 'aurora-postgresql',
#   'DBInstanceStatus': 'available',
#   'MasterUsername': 'caseflow',
#   'DBName': 'caseflow_certification',
#   'Endpoint': {'Address': 'appeals-prod-caseflow-aurora-reader.cdqbofmbcmtd.us-gov-west-1.rds.amazonaws.com',
#    'Port': 5432,
#    'HostedZoneId': 'Z2YROVNTF0QJSQ'},
#   'AllocatedStorage': 300,
#   'InstanceCreateTime': datetime.datetime(2021, 11, 20, 17, 50, 22, 148000, tzinfo=tzutc()),
#   'PreferredBackupWindow': '11:21-11:51',
#   'BackupRetentionPeriod': 35,
#   'DBSecurityGroups': [],
#   'VpcSecurityGroups': [{'VpcSecurityGroupId': 'sg-0df0e2159d72a5a10',
#     'Status': 'active'}],
#   'DBParameterGroups': [{'DBParameterGroupName': 'default.aurora-postgresql11',
#     'ParameterApplyStatus': 'in-sync'}],
#   'AvailabilityZone': 'us-gov-west-1a',
#   'DBSubnetGroup': {'DBSubnetGroupName': 'default-vpc-527dfb37',
#    'DBSubnetGroupDescription': 'Database subnet group for prod',
#    'VpcId': 'vpc-527dfb37',
#    'SubnetGroupStatus': 'Complete',
#    'Subnets': [{'SubnetIdentifier': 'subnet-7f220808',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1a'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'},
#     {'SubnetIdentifier': 'subnet-5ab9833f',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1b'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'}]},
#   'PreferredMaintenanceWindow': 'tue:06:07-tue:06:37',
#   'PendingModifiedValues': {},
#   'MultiAZ': False,
#   'EngineVersion': '11.15',
#   'AutoMinorVersionUpgrade': False,
#   'ReadReplicaDBInstanceIdentifiers': [],
#   'LicenseModel': 'postgresql-license',
#   'OptionGroupMemberships': [{'OptionGroupName': 'default:aurora-postgresql-11',
#     'Status': 'in-sync'}],
#   'PubliclyAccessible': False,
#   'StorageType': 'aurora',
#   'DbInstancePort': 0,
#   'DBClusterIdentifier': 'appeals-prod-caseflow-aurora-cluster',
#   'StorageEncrypted': True,
#   'KmsKeyId': 'arn:aws-us-gov:kms:us-gov-west-1:008577686731:key/fe091b47-2349-41f4-b5d0-06959e62ba12',
#   'DbiResourceId': 'db-ROZENOD2FISMDVSOPMFVGB2OKY',
#   'CACertificateIdentifier': 'rds-ca-rsa4096-g1',
#   'DomainMemberships': [],
#   'CopyTagsToSnapshot': True,
#   'MonitoringInterval': 0,
#   'PromotionTier': 0,
#   'DBInstanceArn': 'arn:aws-us-gov:rds:us-gov-west-1:008577686731:db:appeals-prod-caseflow-aurora-reader',
#   'IAMDatabaseAuthenticationEnabled': False,
#   'PerformanceInsightsEnabled': False,
#   'EnabledCloudwatchLogsExports': ['postgresql'],
#   'DeletionProtection': False,
#   'AssociatedRoles': [],
#   'TagList': [{'Key': 'ProjectName', 'Value': 'Caseflow'},
#    {'Key': 'project', 'Value': 'appeals'},
#    {'Key': 'office', 'Value': 'osva'},
#    {'Key': 'Name', 'Value': 'appeals-prod-caseflow-aurora-reader'},
#    {'Key': 'VAECID', 'Value': 'AWG20180405001'},
#    {'Key': 'environment', 'Value': 'prod'},
#    {'Key': 'Adminstration', 'Value': 'VBA'},
#    {'Key': 'provider', 'Value': 'aws'},
#    {'Key': 'managed', 'Value': 'terraform'},
#    {'Key': 'region', 'Value': 'govcloud'},
#    {'Key': 'suboffice', 'Value': 'cto'},
#    {'Key': 'ProjectShort', 'Value': 'Caseflow'},
#    {'Key': 'dsva_version', 'Value': 'v2'},
#    {'Key': 'group', 'Value': 'dsva'}],
#   'CustomerOwnedIpEnabled': False,
#   'BackupTarget': 'region'},
#  {'DBInstanceIdentifier': 'appeals-prod-efolder-aurora-primary',
#   'DBInstanceClass': 'db.r5.4xlarge',
#   'Engine': 'aurora-postgresql',
#   'DBInstanceStatus': 'available',
#   'MasterUsername': 'efolder_express',
#   'DBName': 'efolder_express',
#   'Endpoint': {'Address': 'appeals-prod-efolder-aurora-primary.cdqbofmbcmtd.us-gov-west-1.rds.amazonaws.com',
#    'Port': 5432,
#    'HostedZoneId': 'Z2YROVNTF0QJSQ'},
#   'AllocatedStorage': 200,
#   'InstanceCreateTime': datetime.datetime(2021, 11, 20, 17, 25, 15, 649000, tzinfo=tzutc()),
#   'PreferredBackupWindow': '13:21-13:51',
#   'BackupRetentionPeriod': 35,
#   'DBSecurityGroups': [],
#   'VpcSecurityGroups': [{'VpcSecurityGroupId': 'sg-098ea22c88b0e0d61',
#     'Status': 'active'}],
#   'DBParameterGroups': [{'DBParameterGroupName': 'default.aurora-postgresql11',
#     'ParameterApplyStatus': 'in-sync'}],
#   'AvailabilityZone': 'us-gov-west-1b',
#   'DBSubnetGroup': {'DBSubnetGroupName': 'default-vpc-527dfb37',
#    'DBSubnetGroupDescription': 'Database subnet group for prod',
#    'VpcId': 'vpc-527dfb37',
#    'SubnetGroupStatus': 'Complete',
#    'Subnets': [{'SubnetIdentifier': 'subnet-7f220808',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1a'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'},
#     {'SubnetIdentifier': 'subnet-5ab9833f',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1b'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'}]},
#   'PreferredMaintenanceWindow': 'wed:09:59-wed:10:29',
#   'PendingModifiedValues': {},
#   'MultiAZ': False,
#   'EngineVersion': '11.15',
#   'AutoMinorVersionUpgrade': True,
#   'ReadReplicaDBInstanceIdentifiers': [],
#   'LicenseModel': 'postgresql-license',
#   'OptionGroupMemberships': [{'OptionGroupName': 'default:aurora-postgresql-11',
#     'Status': 'in-sync'}],
#   'PubliclyAccessible': False,
#   'StorageType': 'aurora',
#   'DbInstancePort': 0,
#   'DBClusterIdentifier': 'appeals-prod-efolder-aurora-cluster',
#   'StorageEncrypted': True,
#   'KmsKeyId': 'arn:aws-us-gov:kms:us-gov-west-1:008577686731:key/402bd545-9834-4e33-9680-a22c9a726714',
#   'DbiResourceId': 'db-LLUNLOOP7YOXJZZEI52RPK7VMA',
#   'CACertificateIdentifier': 'rds-ca-rsa4096-g1',
#   'DomainMemberships': [],
#   'CopyTagsToSnapshot': True,
#   'MonitoringInterval': 0,
#   'PromotionTier': 0,
#   'DBInstanceArn': 'arn:aws-us-gov:rds:us-gov-west-1:008577686731:db:appeals-prod-efolder-aurora-primary',
#   'IAMDatabaseAuthenticationEnabled': False,
#   'PerformanceInsightsEnabled': False,
#   'EnabledCloudwatchLogsExports': ['postgresql'],
#   'DeletionProtection': False,
#   'AssociatedRoles': [],
#   'TagList': [{'Key': 'ProjectName', 'Value': 'Caseflow'},
#    {'Key': 'project', 'Value': 'appeals'},
#    {'Key': 'office', 'Value': 'osva'},
#    {'Key': 'Name', 'Value': 'appeals-prod-efolder-aurora-primary'},
#    {'Key': 'VAECID', 'Value': 'AWG20180405001'},
#    {'Key': 'environment', 'Value': 'prod'},
#    {'Key': 'Adminstration', 'Value': 'VBA'},
#    {'Key': 'provider', 'Value': 'aws'},
#    {'Key': 'managed', 'Value': 'terraform'},
#    {'Key': 'region', 'Value': 'govcloud'},
#    {'Key': 'suboffice', 'Value': 'cto'},
#    {'Key': 'ProjectShort', 'Value': 'Caseflow'},
#    {'Key': 'dsva_version', 'Value': 'v2'},
#    {'Key': 'group', 'Value': 'dsva'}],
#   'CustomerOwnedIpEnabled': False,
#   'BackupTarget': 'region'},
#  {'DBInstanceIdentifier': 'appeals-prod-efolder-aurora-reader',
#   'DBInstanceClass': 'db.r5.4xlarge',
#   'Engine': 'aurora-postgresql',
#   'DBInstanceStatus': 'available',
#   'MasterUsername': 'efolder_express',
#   'DBName': 'efolder_express',
#   'Endpoint': {'Address': 'appeals-prod-efolder-aurora-reader.cdqbofmbcmtd.us-gov-west-1.rds.amazonaws.com',
#    'Port': 5432,
#    'HostedZoneId': 'Z2YROVNTF0QJSQ'},
#   'AllocatedStorage': 200,
#   'InstanceCreateTime': datetime.datetime(2022, 4, 13, 22, 43, 48, 245000, tzinfo=tzutc()),
#   'PreferredBackupWindow': '13:21-13:51',
#   'BackupRetentionPeriod': 35,
#   'DBSecurityGroups': [],
#   'VpcSecurityGroups': [{'VpcSecurityGroupId': 'sg-098ea22c88b0e0d61',
#     'Status': 'active'}],
#   'DBParameterGroups': [{'DBParameterGroupName': 'default.aurora-postgresql11',
#     'ParameterApplyStatus': 'in-sync'}],
#   'AvailabilityZone': 'us-gov-west-1a',
#   'DBSubnetGroup': {'DBSubnetGroupName': 'default-vpc-527dfb37',
#    'DBSubnetGroupDescription': 'Database subnet group for prod',
#    'VpcId': 'vpc-527dfb37',
#    'SubnetGroupStatus': 'Complete',
#    'Subnets': [{'SubnetIdentifier': 'subnet-7f220808',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1a'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'},
#     {'SubnetIdentifier': 'subnet-5ab9833f',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1b'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'}]},
#   'PreferredMaintenanceWindow': 'sat:07:59-sat:08:29',
#   'PendingModifiedValues': {},
#   'MultiAZ': False,
#   'EngineVersion': '11.15',
#   'AutoMinorVersionUpgrade': True,
#   'ReadReplicaDBInstanceIdentifiers': [],
#   'LicenseModel': 'postgresql-license',
#   'OptionGroupMemberships': [{'OptionGroupName': 'default:aurora-postgresql-11',
#     'Status': 'in-sync'}],
#   'PubliclyAccessible': False,
#   'StorageType': 'aurora',
#   'DbInstancePort': 0,
#   'DBClusterIdentifier': 'appeals-prod-efolder-aurora-cluster',
#   'StorageEncrypted': True,
#   'KmsKeyId': 'arn:aws-us-gov:kms:us-gov-west-1:008577686731:key/402bd545-9834-4e33-9680-a22c9a726714',
#   'DbiResourceId': 'db-DDMV2V3PKBCMJWP4KNUUDYM2PU',
#   'CACertificateIdentifier': 'rds-ca-rsa4096-g1',
#   'DomainMemberships': [],
#   'CopyTagsToSnapshot': True,
#   'MonitoringInterval': 0,
#   'PromotionTier': 0,
#   'DBInstanceArn': 'arn:aws-us-gov:rds:us-gov-west-1:008577686731:db:appeals-prod-efolder-aurora-reader',
#   'IAMDatabaseAuthenticationEnabled': False,
#   'PerformanceInsightsEnabled': False,
#   'EnabledCloudwatchLogsExports': ['postgresql'],
#   'DeletionProtection': False,
#   'AssociatedRoles': [],
#   'TagList': [{'Key': 'ProjectName', 'Value': 'Caseflow'},
#    {'Key': 'project', 'Value': 'appeals'},
#    {'Key': 'office', 'Value': 'osva'},
#    {'Key': 'Name', 'Value': 'appeals-prod-efolder-aurora-reader'},
#    {'Key': 'VAECID', 'Value': 'AWG20180405001'},
#    {'Key': 'environment', 'Value': 'prod'},
#    {'Key': 'Adminstration', 'Value': 'VBA'},
#    {'Key': 'provider', 'Value': 'aws'},
#    {'Key': 'managed', 'Value': 'terraform'},
#    {'Key': 'region', 'Value': 'govcloud'},
#    {'Key': 'suboffice', 'Value': 'cto'},
#    {'Key': 'ProjectShort', 'Value': 'Caseflow'},
#    {'Key': 'dsva_version', 'Value': 'v2'},
#    {'Key': 'group', 'Value': 'dsva'}],
#   'CustomerOwnedIpEnabled': False,
#   'BackupTarget': 'region'},
#  {'DBInstanceIdentifier': 'appeals-prod-sentry',
#   'DBInstanceClass': 'db.t2.medium',
#   'Engine': 'postgres',
#   'DBInstanceStatus': 'available',
#   'MasterUsername': 'sentry',
#   'DBName': 'sentry',
#   'Endpoint': {'Address': 'appeals-prod-sentry.cdqbofmbcmtd.us-gov-west-1.rds.amazonaws.com',
#    'Port': 5432,
#    'HostedZoneId': 'Z2YROVNTF0QJSQ'},
#   'AllocatedStorage': 300,
#   'InstanceCreateTime': datetime.datetime(2021, 11, 20, 15, 49, 53, 177000, tzinfo=tzutc()),
#   'PreferredBackupWindow': '07:23-07:53',
#   'BackupRetentionPeriod': 7,
#   'DBSecurityGroups': [],
#   'VpcSecurityGroups': [{'VpcSecurityGroupId': 'sg-02d02b6bf6fc04aef',
#     'Status': 'active'}],
#   'DBParameterGroups': [{'DBParameterGroupName': 'default.postgres12',
#     'ParameterApplyStatus': 'in-sync'}],
#   'AvailabilityZone': 'us-gov-west-1a',
#   'DBSubnetGroup': {'DBSubnetGroupName': 'default-vpc-527dfb37',
#    'DBSubnetGroupDescription': 'Database subnet group for prod',
#    'VpcId': 'vpc-527dfb37',
#    'SubnetGroupStatus': 'Complete',
#    'Subnets': [{'SubnetIdentifier': 'subnet-7f220808',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1a'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'},
#     {'SubnetIdentifier': 'subnet-5ab9833f',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1b'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'}]},
#   'PreferredMaintenanceWindow': 'sat:23:30-sun:00:00',
#   'PendingModifiedValues': {},
#   'LatestRestorableTime': datetime.datetime(2022, 5, 18, 2, 54, 44, tzinfo=tzutc()),
#   'MultiAZ': True,
#   'EngineVersion': '12.10',
#   'AutoMinorVersionUpgrade': False,
#   'ReadReplicaDBInstanceIdentifiers': [],
#   'LicenseModel': 'postgresql-license',
#   'OptionGroupMemberships': [{'OptionGroupName': 'default:postgres-12',
#     'Status': 'in-sync'}],
#   'SecondaryAvailabilityZone': 'us-gov-west-1b',
#   'PubliclyAccessible': False,
#   'StorageType': 'gp2',
#   'DbInstancePort': 0,
#   'StorageEncrypted': False,
#   'DbiResourceId': 'db-EFQJSLG3MIAJZ6YGQ5NFDEMSB4',
#   'CACertificateIdentifier': 'rds-ca-rsa4096-g1',
#   'DomainMemberships': [],
#   'CopyTagsToSnapshot': True,
#   'MonitoringInterval': 0,
#   'DBInstanceArn': 'arn:aws-us-gov:rds:us-gov-west-1:008577686731:db:appeals-prod-sentry',
#   'IAMDatabaseAuthenticationEnabled': False,
#   'PerformanceInsightsEnabled': False,
#   'DeletionProtection': True,
#   'AssociatedRoles': [],
#   'TagList': [{'Key': 'ProjectName', 'Value': 'Caseflow'},
#    {'Key': 'project', 'Value': 'appeals'},
#    {'Key': 'office', 'Value': 'osva'},
#    {'Key': 'Name', 'Value': 'appeals-prod-sentry'},
#    {'Key': 'VAECID', 'Value': 'AWG20180405001'},
#    {'Key': 'environment', 'Value': 'prod'},
#    {'Key': 'Adminstration', 'Value': 'VBA'},
#    {'Key': 'provider', 'Value': 'aws'},
#    {'Key': 'managed', 'Value': 'terraform'},
#    {'Key': 'region', 'Value': 'govcloud'},
#    {'Key': 'suboffice', 'Value': 'cto'},
#    {'Key': 'ProjectShort', 'Value': 'Caseflow'},
#    {'Key': 'dsva_version', 'Value': 'v2'},
#    {'Key': 'group', 'Value': 'dsva'}],
#   'CustomerOwnedIpEnabled': False,
#   'BackupTarget': 'region'},
#  {'DBInstanceIdentifier': 'appeals-uat-caseflow-aurora-primary',
#   'DBInstanceClass': 'db.t3.medium',
#   'Engine': 'aurora-postgresql',
#   'DBInstanceStatus': 'available',
#   'MasterUsername': 'caseflow',
#   'DBName': 'caseflow_certification',
#   'Endpoint': {'Address': 'appeals-uat-caseflow-aurora-primary.cdqbofmbcmtd.us-gov-west-1.rds.amazonaws.com',
#    'Port': 5432,
#    'HostedZoneId': 'Z2YROVNTF0QJSQ'},
#   'AllocatedStorage': 20,
#   'InstanceCreateTime': datetime.datetime(2021, 8, 24, 15, 12, 26, 116000, tzinfo=tzutc()),
#   'PreferredBackupWindow': '09:08-09:38',
#   'BackupRetentionPeriod': 7,
#   'DBSecurityGroups': [],
#   'VpcSecurityGroups': [{'VpcSecurityGroupId': 'sg-0552340dbcbd8c4b9',
#     'Status': 'active'}],
#   'DBParameterGroups': [{'DBParameterGroupName': 'default.aurora-postgresql11',
#     'ParameterApplyStatus': 'in-sync'}],
#   'AvailabilityZone': 'us-gov-west-1a',
#   'DBSubnetGroup': {'DBSubnetGroupName': 'default-vpc-ef7cfa8a',
#    'DBSubnetGroupDescription': 'Database subnet group for staging',
#    'VpcId': 'vpc-ef7cfa8a',
#    'SubnetGroupStatus': 'Complete',
#    'Subnets': [{'SubnetIdentifier': 'subnet-1db98378',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1b'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'},
#     {'SubnetIdentifier': 'subnet-ea22089d',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1a'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'}]},
#   'PreferredMaintenanceWindow': 'sat:06:30-sat:07:00',
#   'PendingModifiedValues': {},
#   'MultiAZ': False,
#   'EngineVersion': '11.15',
#   'AutoMinorVersionUpgrade': True,
#   'ReadReplicaDBInstanceIdentifiers': [],
#   'LicenseModel': 'postgresql-license',
#   'OptionGroupMemberships': [{'OptionGroupName': 'default:aurora-postgresql-11',
#     'Status': 'in-sync'}],
#   'PubliclyAccessible': False,
#   'StorageType': 'aurora',
#   'DbInstancePort': 0,
#   'DBClusterIdentifier': 'appeals-uat-caseflow-aurora-cluster',
#   'StorageEncrypted': True,
#   'KmsKeyId': 'arn:aws-us-gov:kms:us-gov-west-1:008577686731:key/bc1cbc6f-9cc6-4f60-bcac-622c5cb091b2',
#   'DbiResourceId': 'db-DA4K3MC3T72PXMZDJVUQZTRON4',
#   'CACertificateIdentifier': 'rds-ca-rsa4096-g1',
#   'DomainMemberships': [],
#   'CopyTagsToSnapshot': True,
#   'MonitoringInterval': 0,
#   'PromotionTier': 0,
#   'DBInstanceArn': 'arn:aws-us-gov:rds:us-gov-west-1:008577686731:db:appeals-uat-caseflow-aurora-primary',
#   'IAMDatabaseAuthenticationEnabled': False,
#   'PerformanceInsightsEnabled': False,
#   'EnabledCloudwatchLogsExports': ['postgresql'],
#   'DeletionProtection': False,
#   'AssociatedRoles': [],
#   'TagList': [{'Key': 'ProjectName', 'Value': 'Caseflow'},
#    {'Key': 'project', 'Value': 'appeals'},
#    {'Key': 'office', 'Value': 'osva'},
#    {'Key': 'Name', 'Value': 'appeals-uat-caseflow-aurora-primary'},
#    {'Key': 'VAECID', 'Value': 'AWG20180405001'},
#    {'Key': 'environment', 'Value': 'uat'},
#    {'Key': 'Adminstration', 'Value': 'VBA'},
#    {'Key': 'provider', 'Value': 'aws'},
#    {'Key': 'managed', 'Value': 'terraform'},
#    {'Key': 'region', 'Value': 'govcloud'},
#    {'Key': 'suboffice', 'Value': 'cto'},
#    {'Key': 'ProjectShort', 'Value': 'Caseflow'},
#    {'Key': 'dsva_version', 'Value': 'v2'},
#    {'Key': 'group', 'Value': 'dsva'}],
#   'CustomerOwnedIpEnabled': False,
#   'BackupTarget': 'region'},
#  {'DBInstanceIdentifier': 'appeals-uat-caseflow-aurora-reader',
#   'DBInstanceClass': 'db.t3.medium',
#   'Engine': 'aurora-postgresql',
#   'DBInstanceStatus': 'available',
#   'MasterUsername': 'caseflow',
#   'DBName': 'caseflow_certification',
#   'Endpoint': {'Address': 'appeals-uat-caseflow-aurora-reader.cdqbofmbcmtd.us-gov-west-1.rds.amazonaws.com',
#    'Port': 5432,
#    'HostedZoneId': 'Z2YROVNTF0QJSQ'},
#   'AllocatedStorage': 20,
#   'InstanceCreateTime': datetime.datetime(2021, 8, 24, 15, 17, 30, 643000, tzinfo=tzutc()),
#   'PreferredBackupWindow': '09:08-09:38',
#   'BackupRetentionPeriod': 7,
#   'DBSecurityGroups': [],
#   'VpcSecurityGroups': [{'VpcSecurityGroupId': 'sg-0552340dbcbd8c4b9',
#     'Status': 'active'}],
#   'DBParameterGroups': [{'DBParameterGroupName': 'default.aurora-postgresql11',
#     'ParameterApplyStatus': 'in-sync'}],
#   'AvailabilityZone': 'us-gov-west-1b',
#   'DBSubnetGroup': {'DBSubnetGroupName': 'default-vpc-ef7cfa8a',
#    'DBSubnetGroupDescription': 'Database subnet group for staging',
#    'VpcId': 'vpc-ef7cfa8a',
#    'SubnetGroupStatus': 'Complete',
#    'Subnets': [{'SubnetIdentifier': 'subnet-1db98378',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1b'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'},
#     {'SubnetIdentifier': 'subnet-ea22089d',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1a'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'}]},
#   'PreferredMaintenanceWindow': 'tue:12:35-tue:13:05',
#   'PendingModifiedValues': {},
#   'MultiAZ': False,
#   'EngineVersion': '11.15',
#   'AutoMinorVersionUpgrade': True,
#   'ReadReplicaDBInstanceIdentifiers': [],
#   'LicenseModel': 'postgresql-license',
#   'OptionGroupMemberships': [{'OptionGroupName': 'default:aurora-postgresql-11',
#     'Status': 'in-sync'}],
#   'PubliclyAccessible': False,
#   'StorageType': 'aurora',
#   'DbInstancePort': 0,
#   'DBClusterIdentifier': 'appeals-uat-caseflow-aurora-cluster',
#   'StorageEncrypted': True,
#   'KmsKeyId': 'arn:aws-us-gov:kms:us-gov-west-1:008577686731:key/bc1cbc6f-9cc6-4f60-bcac-622c5cb091b2',
#   'DbiResourceId': 'db-EXWMOJR7J6HECRWWLEAVVZP6FU',
#   'CACertificateIdentifier': 'rds-ca-rsa4096-g1',
#   'DomainMemberships': [],
#   'CopyTagsToSnapshot': True,
#   'MonitoringInterval': 0,
#   'PromotionTier': 0,
#   'DBInstanceArn': 'arn:aws-us-gov:rds:us-gov-west-1:008577686731:db:appeals-uat-caseflow-aurora-reader',
#   'IAMDatabaseAuthenticationEnabled': False,
#   'PerformanceInsightsEnabled': False,
#   'EnabledCloudwatchLogsExports': ['postgresql'],
#   'DeletionProtection': False,
#   'AssociatedRoles': [],
#   'TagList': [{'Key': 'ProjectName', 'Value': 'Caseflow'},
#    {'Key': 'project', 'Value': 'appeals'},
#    {'Key': 'office', 'Value': 'osva'},
#    {'Key': 'Name', 'Value': 'appeals-uat-caseflow-aurora-reader'},
#    {'Key': 'VAECID', 'Value': 'AWG20180405001'},
#    {'Key': 'environment', 'Value': 'uat'},
#    {'Key': 'Adminstration', 'Value': 'VBA'},
#    {'Key': 'provider', 'Value': 'aws'},
#    {'Key': 'managed', 'Value': 'terraform'},
#    {'Key': 'region', 'Value': 'govcloud'},
#    {'Key': 'suboffice', 'Value': 'cto'},
#    {'Key': 'ProjectShort', 'Value': 'Caseflow'},
#    {'Key': 'dsva_version', 'Value': 'v2'},
#    {'Key': 'group', 'Value': 'dsva'}],
#   'CustomerOwnedIpEnabled': False,
#   'BackupTarget': 'region'},
#  {'DBInstanceIdentifier': 'appeals-uat-efolder-aurora-primary',
#   'DBInstanceClass': 'db.r4.xlarge',
#   'Engine': 'aurora-postgresql',
#   'DBInstanceStatus': 'available',
#   'MasterUsername': 'efolder_express',
#   'DBName': 'efolder_express',
#   'Endpoint': {'Address': 'appeals-uat-efolder-aurora-primary.cdqbofmbcmtd.us-gov-west-1.rds.amazonaws.com',
#    'Port': 5432,
#    'HostedZoneId': 'Z2YROVNTF0QJSQ'},
#   'AllocatedStorage': 100,
#   'InstanceCreateTime': datetime.datetime(2021, 8, 25, 15, 39, 42, 484000, tzinfo=tzutc()),
#   'PreferredBackupWindow': '09:18-09:48',
#   'BackupRetentionPeriod': 7,
#   'DBSecurityGroups': [],
#   'VpcSecurityGroups': [{'VpcSecurityGroupId': 'sg-0095b2f1a9b3a612b',
#     'Status': 'active'}],
#   'DBParameterGroups': [{'DBParameterGroupName': 'default.aurora-postgresql11',
#     'ParameterApplyStatus': 'in-sync'}],
#   'AvailabilityZone': 'us-gov-west-1b',
#   'DBSubnetGroup': {'DBSubnetGroupName': 'default-vpc-ef7cfa8a',
#    'DBSubnetGroupDescription': 'Database subnet group for staging',
#    'VpcId': 'vpc-ef7cfa8a',
#    'SubnetGroupStatus': 'Complete',
#    'Subnets': [{'SubnetIdentifier': 'subnet-1db98378',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1b'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'},
#     {'SubnetIdentifier': 'subnet-ea22089d',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1a'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'}]},
#   'PreferredMaintenanceWindow': 'fri:08:12-fri:08:42',
#   'PendingModifiedValues': {},
#   'MultiAZ': False,
#   'EngineVersion': '11.15',
#   'AutoMinorVersionUpgrade': True,
#   'ReadReplicaDBInstanceIdentifiers': [],
#   'LicenseModel': 'postgresql-license',
#   'OptionGroupMemberships': [{'OptionGroupName': 'default:aurora-postgresql-11',
#     'Status': 'in-sync'}],
#   'PubliclyAccessible': False,
#   'StorageType': 'aurora',
#   'DbInstancePort': 0,
#   'DBClusterIdentifier': 'appeals-uat-efolder-aurora-cluster',
#   'StorageEncrypted': True,
#   'KmsKeyId': 'arn:aws-us-gov:kms:us-gov-west-1:008577686731:key/ec97b6a7-b644-416e-b9fd-99f9d34e857f',
#   'DbiResourceId': 'db-2KBY6MWI5RBJ2D5ZCVRX7ZJMCA',
#   'CACertificateIdentifier': 'rds-ca-rsa4096-g1',
#   'DomainMemberships': [],
#   'CopyTagsToSnapshot': True,
#   'MonitoringInterval': 0,
#   'PromotionTier': 0,
#   'DBInstanceArn': 'arn:aws-us-gov:rds:us-gov-west-1:008577686731:db:appeals-uat-efolder-aurora-primary',
#   'IAMDatabaseAuthenticationEnabled': False,
#   'PerformanceInsightsEnabled': False,
#   'EnabledCloudwatchLogsExports': ['postgresql'],
#   'DeletionProtection': False,
#   'AssociatedRoles': [],
#   'TagList': [{'Key': 'ProjectName', 'Value': 'Caseflow'},
#    {'Key': 'project', 'Value': 'appeals'},
#    {'Key': 'office', 'Value': 'osva'},
#    {'Key': 'Name', 'Value': 'appeals-uat-efolder-aurora-primary'},
#    {'Key': 'VAECID', 'Value': 'AWG20180405001'},
#    {'Key': 'environment', 'Value': 'uat'},
#    {'Key': 'Adminstration', 'Value': 'VBA'},
#    {'Key': 'provider', 'Value': 'aws'},
#    {'Key': 'managed', 'Value': 'terraform'},
#    {'Key': 'region', 'Value': 'govcloud'},
#    {'Key': 'suboffice', 'Value': 'cto'},
#    {'Key': 'ProjectShort', 'Value': 'Caseflow'},
#    {'Key': 'dsva_version', 'Value': 'v2'},
#    {'Key': 'group', 'Value': 'dsva'}],
#   'CustomerOwnedIpEnabled': False,
#   'BackupTarget': 'region'},
#  {'DBInstanceIdentifier': 'appeals-uat-etl',
#   'DBInstanceClass': 'db.t2.medium',
#   'Engine': 'postgres',
#   'DBInstanceStatus': 'available',
#   'MasterUsername': 'caseflowetluat',
#   'DBName': 'caseflow_etl',
#   'Endpoint': {'Address': 'appeals-uat-etl.cdqbofmbcmtd.us-gov-west-1.rds.amazonaws.com',
#    'Port': 5432,
#    'HostedZoneId': 'Z2YROVNTF0QJSQ'},
#   'AllocatedStorage': 300,
#   'InstanceCreateTime': datetime.datetime(2021, 8, 30, 13, 6, 42, 166000, tzinfo=tzutc()),
#   'PreferredBackupWindow': '09:33-10:03',
#   'BackupRetentionPeriod': 0,
#   'DBSecurityGroups': [],
#   'VpcSecurityGroups': [{'VpcSecurityGroupId': 'sg-05246c41007d39430',
#     'Status': 'active'}],
#   'DBParameterGroups': [{'DBParameterGroupName': 'default.postgres11',
#     'ParameterApplyStatus': 'in-sync'}],
#   'AvailabilityZone': 'us-gov-west-1a',
#   'DBSubnetGroup': {'DBSubnetGroupName': 'default-vpc-ef7cfa8a',
#    'DBSubnetGroupDescription': 'Database subnet group for staging',
#    'VpcId': 'vpc-ef7cfa8a',
#    'SubnetGroupStatus': 'Complete',
#    'Subnets': [{'SubnetIdentifier': 'subnet-1db98378',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1b'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'},
#     {'SubnetIdentifier': 'subnet-ea22089d',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1a'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'}]},
#   'PreferredMaintenanceWindow': 'sun:11:32-sun:12:02',
#   'PendingModifiedValues': {},
#   'MultiAZ': False,
#   'EngineVersion': '11.15',
#   'AutoMinorVersionUpgrade': False,
#   'ReadReplicaDBInstanceIdentifiers': [],
#   'LicenseModel': 'postgresql-license',
#   'OptionGroupMemberships': [{'OptionGroupName': 'default:postgres-11',
#     'Status': 'in-sync'}],
#   'PubliclyAccessible': False,
#   'StorageType': 'gp2',
#   'DbInstancePort': 0,
#   'StorageEncrypted': True,
#   'KmsKeyId': 'arn:aws-us-gov:kms:us-gov-west-1:008577686731:key/da52fa14-0ee7-4e02-bc43-e09d2e0638c9',
#   'DbiResourceId': 'db-5JKK7FNHQ7LMRI3NMLBGD5JRVE',
#   'CACertificateIdentifier': 'rds-ca-rsa4096-g1',
#   'DomainMemberships': [],
#   'CopyTagsToSnapshot': True,
#   'MonitoringInterval': 0,
#   'DBInstanceArn': 'arn:aws-us-gov:rds:us-gov-west-1:008577686731:db:appeals-uat-etl',
#   'IAMDatabaseAuthenticationEnabled': False,
#   'PerformanceInsightsEnabled': False,
#   'DeletionProtection': True,
#   'AssociatedRoles': [],
#   'MaxAllocatedStorage': 2000,
#   'TagList': [{'Key': 'ProjectName', 'Value': 'Caseflow'},
#    {'Key': 'project', 'Value': 'appeals'},
#    {'Key': 'office', 'Value': 'osva'},
#    {'Key': 'Name', 'Value': 'appeals-uat-etl'},
#    {'Key': 'VAECID', 'Value': 'AWG20180405001'},
#    {'Key': 'environment', 'Value': 'uat'},
#    {'Key': 'Adminstration', 'Value': 'VBA'},
#    {'Key': 'provider', 'Value': 'aws'},
#    {'Key': 'managed', 'Value': 'terraform'},
#    {'Key': 'region', 'Value': 'govcloud'},
#    {'Key': 'suboffice', 'Value': 'cto'},
#    {'Key': 'ProjectShort', 'Value': 'Caseflow'},
#    {'Key': 'dsva_version', 'Value': 'v2'},
#    {'Key': 'group', 'Value': 'dsva'}],
#   'CustomerOwnedIpEnabled': False,
#   'BackupTarget': 'region'},
#  {'DBInstanceIdentifier': 'appeals-uat-sentry',
#   'DBInstanceClass': 'db.t2.small',
#   'Engine': 'postgres',
#   'DBInstanceStatus': 'available',
#   'MasterUsername': 'dsva',
#   'Endpoint': {'Address': 'appeals-uat-sentry.cdqbofmbcmtd.us-gov-west-1.rds.amazonaws.com',
#    'Port': 5432,
#    'HostedZoneId': 'Z2YROVNTF0QJSQ'},
#   'AllocatedStorage': 50,
#   'InstanceCreateTime': datetime.datetime(2021, 8, 31, 12, 47, 50, 837000, tzinfo=tzutc()),
#   'PreferredBackupWindow': '11:32-12:02',
#   'BackupRetentionPeriod': 7,
#   'DBSecurityGroups': [],
#   'VpcSecurityGroups': [{'VpcSecurityGroupId': 'sg-098ededfd49f47484',
#     'Status': 'active'}],
#   'DBParameterGroups': [{'DBParameterGroupName': 'default.postgres12',
#     'ParameterApplyStatus': 'in-sync'}],
#   'AvailabilityZone': 'us-gov-west-1b',
#   'DBSubnetGroup': {'DBSubnetGroupName': 'default-vpc-ef7cfa8a',
#    'DBSubnetGroupDescription': 'Database subnet group for staging',
#    'VpcId': 'vpc-ef7cfa8a',
#    'SubnetGroupStatus': 'Complete',
#    'Subnets': [{'SubnetIdentifier': 'subnet-1db98378',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1b'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'},
#     {'SubnetIdentifier': 'subnet-ea22089d',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1a'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'}]},
#   'PreferredMaintenanceWindow': 'thu:09:05-thu:09:35',
#   'PendingModifiedValues': {},
#   'LatestRestorableTime': datetime.datetime(2022, 5, 18, 2, 54, 39, tzinfo=tzutc()),
#   'MultiAZ': False,
#   'EngineVersion': '12.10',
#   'AutoMinorVersionUpgrade': False,
#   'ReadReplicaDBInstanceIdentifiers': [],
#   'LicenseModel': 'postgresql-license',
#   'OptionGroupMemberships': [{'OptionGroupName': 'default:postgres-12',
#     'Status': 'in-sync'}],
#   'PubliclyAccessible': False,
#   'StorageType': 'gp2',
#   'DbInstancePort': 0,
#   'StorageEncrypted': False,
#   'DbiResourceId': 'db-MMQRVNLZ3ZARASVUL32MXCM2CA',
#   'CACertificateIdentifier': 'rds-ca-rsa4096-g1',
#   'DomainMemberships': [],
#   'CopyTagsToSnapshot': True,
#   'MonitoringInterval': 0,
#   'DBInstanceArn': 'arn:aws-us-gov:rds:us-gov-west-1:008577686731:db:appeals-uat-sentry',
#   'IAMDatabaseAuthenticationEnabled': False,
#   'PerformanceInsightsEnabled': False,
#   'DeletionProtection': True,
#   'AssociatedRoles': [],
#   'TagList': [{'Key': 'ProjectName', 'Value': 'Caseflow'},
#    {'Key': 'project', 'Value': 'appeals'},
#    {'Key': 'office', 'Value': 'osva'},
#    {'Key': 'Name', 'Value': 'appeals-uat-sentry'},
#    {'Key': 'VAECID', 'Value': 'AWG20180405001'},
#    {'Key': 'environment', 'Value': 'uat'},
#    {'Key': 'Adminstration', 'Value': 'VBA'},
#    {'Key': 'provider', 'Value': 'aws'},
#    {'Key': 'managed', 'Value': 'terraform'},
#    {'Key': 'region', 'Value': 'govcloud'},
#    {'Key': 'suboffice', 'Value': 'cto'},
#    {'Key': 'ProjectShort', 'Value': 'Caseflow'},
#    {'Key': 'dsva_version', 'Value': 'v2'},
#    {'Key': 'group', 'Value': 'dsva'}],
#   'CustomerOwnedIpEnabled': False,
#   'BackupTarget': 'region'},
#  {'DBInstanceIdentifier': 'dsva-appeals-etl-spoke-prod',
#   'DBInstanceClass': 'db.r4.large',
#   'Engine': 'postgres',
#   'DBInstanceStatus': 'available',
#   'MasterUsername': 'caseflowetlprod',
#   'DBName': 'caseflow_etl',
#   'Endpoint': {'Address': 'dsva-appeals-etl-spoke-prod.cdqbofmbcmtd.us-gov-west-1.rds.amazonaws.com',
#    'Port': 5432,
#    'HostedZoneId': 'Z2YROVNTF0QJSQ'},
#   'AllocatedStorage': 300,
#   'InstanceCreateTime': datetime.datetime(2019, 12, 10, 21, 34, 9, 682000, tzinfo=tzutc()),
#   'PreferredBackupWindow': '10:14-10:44',
#   'BackupRetentionPeriod': 30,
#   'DBSecurityGroups': [],
#   'VpcSecurityGroups': [{'VpcSecurityGroupId': 'sg-0e1b55f2471ac46dc',
#     'Status': 'active'}],
#   'DBParameterGroups': [{'DBParameterGroupName': 'default.postgres11',
#     'ParameterApplyStatus': 'in-sync'}],
#   'AvailabilityZone': 'us-gov-west-1a',
#   'DBSubnetGroup': {'DBSubnetGroupName': 'default-vpc-527dfb37',
#    'DBSubnetGroupDescription': 'Database subnet group for prod',
#    'VpcId': 'vpc-527dfb37',
#    'SubnetGroupStatus': 'Complete',
#    'Subnets': [{'SubnetIdentifier': 'subnet-7f220808',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1a'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'},
#     {'SubnetIdentifier': 'subnet-5ab9833f',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1b'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'}]},
#   'PreferredMaintenanceWindow': 'wed:08:45-wed:09:15',
#   'PendingModifiedValues': {},
#   'LatestRestorableTime': datetime.datetime(2022, 5, 18, 2, 54, 39, tzinfo=tzutc()),
#   'MultiAZ': False,
#   'EngineVersion': '11.15',
#   'AutoMinorVersionUpgrade': False,
#   'ReadReplicaDBInstanceIdentifiers': [],
#   'LicenseModel': 'postgresql-license',
#   'OptionGroupMemberships': [{'OptionGroupName': 'default:postgres-11',
#     'Status': 'in-sync'}],
#   'PubliclyAccessible': False,
#   'StorageType': 'gp2',
#   'DbInstancePort': 0,
#   'StorageEncrypted': True,
#   'KmsKeyId': 'arn:aws-us-gov:kms:us-gov-west-1:008577686731:key/da52fa14-0ee7-4e02-bc43-e09d2e0638c9',
#   'DbiResourceId': 'db-M42DBES3NYLA4CMRVPMZCFMPD4',
#   'CACertificateIdentifier': 'rds-ca-rsa4096-g1',
#   'DomainMemberships': [],
#   'CopyTagsToSnapshot': True,
#   'MonitoringInterval': 0,
#   'DBInstanceArn': 'arn:aws-us-gov:rds:us-gov-west-1:008577686731:db:dsva-appeals-etl-spoke-prod',
#   'IAMDatabaseAuthenticationEnabled': False,
#   'PerformanceInsightsEnabled': False,
#   'DeletionProtection': True,
#   'AssociatedRoles': [],
#   'MaxAllocatedStorage': 2000,
#   'TagList': [{'Key': 'ProjectName', 'Value': 'Caseflow'},
#    {'Key': 'project', 'Value': 'appeals'},
#    {'Key': 'office', 'Value': 'osva'},
#    {'Key': 'Name', 'Value': 'dsva-appeals-etl-spoke-prod'},
#    {'Key': 'VAECID', 'Value': 'AWG20180405001'},
#    {'Key': 'environment', 'Value': 'prod'},
#    {'Key': 'Adminstration', 'Value': 'VBA'},
#    {'Key': 'provider', 'Value': 'aws'},
#    {'Key': 'managed', 'Value': 'terraform'},
#    {'Key': 'region', 'Value': 'govcloud'},
#    {'Key': 'suboffice', 'Value': 'cto'},
#    {'Key': 'ProjectShort', 'Value': 'Caseflow'},
#    {'Key': 'dsva_version', 'Value': 'v2'},
#    {'Key': 'group', 'Value': 'dsva'}],
#   'CustomerOwnedIpEnabled': False,
#   'BackupTarget': 'region'},
#  {'DBInstanceIdentifier': 'dsva-appeals-metabase-spoke-prod',
#   'DBInstanceClass': 'db.r4.large',
#   'Engine': 'aurora-postgresql',
#   'DBInstanceStatus': 'available',
#   'MasterUsername': 'appeals_devops',
#   'DBName': 'appealsmetabase',
#   'Endpoint': {'Address': 'dsva-appeals-metabase-spoke-prod.cdqbofmbcmtd.us-gov-west-1.rds.amazonaws.com',
#    'Port': 5432,
#    'HostedZoneId': 'Z2YROVNTF0QJSQ'},
#   'AllocatedStorage': 1,
#   'InstanceCreateTime': datetime.datetime(2020, 1, 2, 15, 35, 28, 325000, tzinfo=tzutc()),
#   'PreferredBackupWindow': '11:02-11:32',
#   'BackupRetentionPeriod': 5,
#   'DBSecurityGroups': [],
#   'VpcSecurityGroups': [{'VpcSecurityGroupId': 'sg-bd65e0d9',
#     'Status': 'active'}],
#   'DBParameterGroups': [{'DBParameterGroupName': 'default.aurora-postgresql11',
#     'ParameterApplyStatus': 'in-sync'}],
#   'AvailabilityZone': 'us-gov-west-1a',
#   'DBSubnetGroup': {'DBSubnetGroupName': 'default-vpc-527dfb37',
#    'DBSubnetGroupDescription': 'Database subnet group for prod',
#    'VpcId': 'vpc-527dfb37',
#    'SubnetGroupStatus': 'Complete',
#    'Subnets': [{'SubnetIdentifier': 'subnet-7f220808',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1a'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'},
#     {'SubnetIdentifier': 'subnet-5ab9833f',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1b'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'}]},
#   'PreferredMaintenanceWindow': 'sat:23:35-sun:01:35',
#   'PendingModifiedValues': {},
#   'MultiAZ': False,
#   'EngineVersion': '11.15',
#   'AutoMinorVersionUpgrade': False,
#   'ReadReplicaDBInstanceIdentifiers': [],
#   'LicenseModel': 'postgresql-license',
#   'OptionGroupMemberships': [{'OptionGroupName': 'default:aurora-postgresql-11',
#     'Status': 'in-sync'}],
#   'PubliclyAccessible': False,
#   'StorageType': 'aurora',
#   'DbInstancePort': 0,
#   'DBClusterIdentifier': 'appealsmetabase',
#   'StorageEncrypted': True,
#   'KmsKeyId': 'arn:aws-us-gov:kms:us-gov-west-1:008577686731:key/da52fa14-0ee7-4e02-bc43-e09d2e0638c9',
#   'DbiResourceId': 'db-2DLIYE2XQCZJCIIQ3OOGNNYFGE',
#   'CACertificateIdentifier': 'rds-ca-rsa4096-g1',
#   'DomainMemberships': [],
#   'CopyTagsToSnapshot': False,
#   'MonitoringInterval': 0,
#   'PromotionTier': 1,
#   'DBInstanceArn': 'arn:aws-us-gov:rds:us-gov-west-1:008577686731:db:dsva-appeals-metabase-spoke-prod',
#   'IAMDatabaseAuthenticationEnabled': False,
#   'PerformanceInsightsEnabled': False,
#   'DeletionProtection': False,
#   'AssociatedRoles': [],
#   'TagList': [{'Key': 'VAECID', 'Value': 'AWG20180405001'},
#    {'Key': 'workload-type', 'Value': 'other'},
#    {'Key': 'ProjectName', 'Value': 'Caseflow'},
#    {'Key': 'ProjectShort', 'Value': 'Caseflow'}],
#   'CustomerOwnedIpEnabled': False,
#   'BackupTarget': 'region'},
#  {'DBInstanceIdentifier': 'dsva-appeals-spoke-prod-vacols-dr',
#   'DBInstanceClass': 'db.m4.xlarge',
#   'Engine': 'oracle-ee',
#   'DBInstanceStatus': 'backing-up',
#   'MasterUsername': 'DSUSERROOT',
#   'DBName': 'ORCL',
#   'Endpoint': {'Address': 'dsva-appeals-spoke-prod-vacols-dr.cdqbofmbcmtd.us-gov-west-1.rds.amazonaws.com',
#    'Port': 1521,
#    'HostedZoneId': 'Z2YROVNTF0QJSQ'},
#   'AllocatedStorage': 500,
# ...
#     {'SubnetIdentifier': 'subnet-20f47b44',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1b'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'}]},
#   'PreferredMaintenanceWindow': 'thu:10:21-thu:10:51',
#   'PendingModifiedValues': {},
#   'LatestRestorableTime': datetime.datetime(2022, 5, 18, 2, 54, 34, tzinfo=tzutc()),
#   'MultiAZ': True,
#   'EngineVersion': '9.6.23',
#   'AutoMinorVersionUpgrade': True,
#   'ReadReplicaDBInstanceIdentifiers': [],
#   'LicenseModel': 'postgresql-license',
#   'OptionGroupMemberships': [{'OptionGroupName': 'default:postgres-9-6',
#     'Status': 'in-sync'}],
#   'SecondaryAvailabilityZone': 'us-gov-west-1a',
#   'PubliclyAccessible': False,
#   'StorageType': 'gp2',
#   'DbInstancePort': 0,
#   'StorageEncrypted': True,
#   'KmsKeyId': 'arn:aws-us-gov:kms:us-gov-west-1:008577686731:key/da52fa14-0ee7-4e02-bc43-e09d2e0638c9',
#   'DbiResourceId': 'db-3MLQUTINTZWUAJMXZPVEULOMWM',
#   'CACertificateIdentifier': 'rds-ca-2017',
#   'DomainMemberships': [],
#   'CopyTagsToSnapshot': True,
#   'MonitoringInterval': 0,
#   'DBInstanceArn': 'arn:aws-us-gov:rds:us-gov-west-1:008577686731:db:dvp-dev-api-gateway-db',
#   'IAMDatabaseAuthenticationEnabled': False,
#   'PerformanceInsightsEnabled': False,
#   'EnabledCloudwatchLogsExports': ['postgresql', 'upgrade'],
#   'DeletionProtection': True,
#   'AssociatedRoles': [],
#   'TagList': [{'Key': 'Office', 'Value': 'tbd'},
#    {'Key': 'ProjectName', 'Value': 'VA Vets.gov'},
#    {'Key': 'ResTag', 'Value': 'shared'},
#    {'Key': 'project', 'Value': 'dvp'},
#    {'Key': 'office', 'Value': 'osva'},
#    {'Key': 'Name', 'Value': 'dsva-dvp-dev-api-gateway'},
#    {'Key': 'Role', 'Value': 'tbd'},
#    {'Key': 'VAECID', 'Value': 'AWG20180517003'},
#    {'Key': 'ConnectionID', 'Value': '313-68'},
#    {'Key': 'environment', 'Value': 'dev'},
#    {'Key': 'Adminstration', 'Value': 'TBD'},
#    {'Key': 'application', 'Value': 'api-gateway'},
#    {'Key': 'provider', 'Value': 'aws'},
#    {'Key': 'managed', 'Value': 'terraform'},
#    {'Key': 'Environment', 'Value': 'DEV'},
#    {'Key': 'region', 'Value': 'govcloud'},
#    {'Key': 'suboffice', 'Value': 'cto'},
#    {'Key': 'ProjectShort', 'Value': 'Vets.gov'},
#    {'Key': 'dsva_version', 'Value': 'v2'}],
#   'CustomerOwnedIpEnabled': False,
#   'BackupTarget': 'region'},
#  {'DBInstanceIdentifier': 'dvp-prod-api-gateway-db',
#   'DBInstanceClass': 'db.m4.large',
#   'Engine': 'postgres',
#   'DBInstanceStatus': 'available',
#   'MasterUsername': 'api_gateway_kong',
#   'DBName': 'api_gateway',
#   'Endpoint': {'Address': 'dvp-prod-api-gateway-db.cdqbofmbcmtd.us-gov-west-1.rds.amazonaws.com',
#    'Port': 5432,
#    'HostedZoneId': 'Z2YROVNTF0QJSQ'},
#   'AllocatedStorage': 100,
#   'InstanceCreateTime': datetime.datetime(2019, 3, 27, 21, 18, 34, 930000, tzinfo=tzutc()),
#   'PreferredBackupWindow': '08:45-09:15',
#   'BackupRetentionPeriod': 7,
#   'DBSecurityGroups': [],
#   'VpcSecurityGroups': [{'VpcSecurityGroupId': 'sg-d45e22b3',
#     'Status': 'active'},
#    {'VpcSecurityGroupId': 'sg-71298416', 'Status': 'active'}],
#   'DBParameterGroups': [{'DBParameterGroupName': 'default.postgres9.6',
#     'ParameterApplyStatus': 'in-sync'}],
#   'AvailabilityZone': 'us-gov-west-1b',
#   'DBSubnetGroup': {'DBSubnetGroupName': 'dsva-dvp-prod-api-gateway-db-sng',
#    'DBSubnetGroupDescription': 'api-gateway prod PostgreSQL subnet group',
#    'VpcId': 'vpc-fcbd4298',
#    'SubnetGroupStatus': 'Complete',
#    'Subnets': [{'SubnetIdentifier': 'subnet-6fa52a0b',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1b'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'},
#     {'SubnetIdentifier': 'subnet-03c44475',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1a'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'},
#     {'SubnetIdentifier': 'subnet-4578971c',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1c'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'}]},
#   'PreferredMaintenanceWindow': 'thu:10:21-thu:10:51',
#   'PendingModifiedValues': {},
#   'LatestRestorableTime': datetime.datetime(2022, 5, 18, 2, 54, 33, tzinfo=tzutc()),
#   'MultiAZ': True,
#   'EngineVersion': '9.6.23',
#   'AutoMinorVersionUpgrade': True,
#   'ReadReplicaDBInstanceIdentifiers': [],
#   'LicenseModel': 'postgresql-license',
#   'OptionGroupMemberships': [{'OptionGroupName': 'default:postgres-9-6',
#     'Status': 'in-sync'}],
#   'SecondaryAvailabilityZone': 'us-gov-west-1a',
#   'PubliclyAccessible': False,
#   'StorageType': 'gp2',
#   'DbInstancePort': 0,
#   'StorageEncrypted': True,
#   'KmsKeyId': 'arn:aws-us-gov:kms:us-gov-west-1:008577686731:key/da52fa14-0ee7-4e02-bc43-e09d2e0638c9',
#   'DbiResourceId': 'db-KA2QOGEGO5IP5NYVVNO3QGUZEQ',
#   'CACertificateIdentifier': 'rds-ca-2017',
#   'DomainMemberships': [],
#   'CopyTagsToSnapshot': True,
#   'MonitoringInterval': 0,
#   'DBInstanceArn': 'arn:aws-us-gov:rds:us-gov-west-1:008577686731:db:dvp-prod-api-gateway-db',
#   'IAMDatabaseAuthenticationEnabled': False,
#   'PerformanceInsightsEnabled': False,
#   'EnabledCloudwatchLogsExports': ['postgresql', 'upgrade'],
#   'DeletionProtection': True,
#   'AssociatedRoles': [],
#   'TagList': [{'Key': 'Office', 'Value': 'tbd'},
#    {'Key': 'ProjectName', 'Value': 'VA Vets.gov'},
#    {'Key': 'ResTag', 'Value': 'shared'},
#    {'Key': 'project', 'Value': 'dvp'},
#    {'Key': 'office', 'Value': 'osva'},
#    {'Key': 'Name', 'Value': 'dsva-dvp-prod-api-gateway'},
#    {'Key': 'Role', 'Value': 'tbd'},
#    {'Key': 'VAECID', 'Value': 'AWG20180517003'},
#    {'Key': 'environment', 'Value': 'prod'},
#    {'Key': 'Adminstration', 'Value': 'TBD'},
#    {'Key': 'application', 'Value': 'api-gateway'},
#    {'Key': 'provider', 'Value': 'aws'},
#    {'Key': 'managed', 'Value': 'terraform'},
#    {'Key': 'Environment', 'Value': 'PROD'},
#    {'Key': 'region', 'Value': 'govcloud'},
#    {'Key': 'suboffice', 'Value': 'cto'},
#    {'Key': 'ProjectShort', 'Value': 'Vets.gov'},
#    {'Key': 'dsva_version', 'Value': 'v2'}],
#   'CustomerOwnedIpEnabled': False,
#   'BackupTarget': 'region'},
#  {'DBInstanceIdentifier': 'dvp-sandbox-api-gateway-db',
#   'DBInstanceClass': 'db.m4.large',
#   'Engine': 'postgres',
#   'DBInstanceStatus': 'available',
#   'MasterUsername': 'api_gateway_kong',
#   'DBName': 'api_gateway',
#   'Endpoint': {'Address': 'dvp-sandbox-api-gateway-db.cdqbofmbcmtd.us-gov-west-1.rds.amazonaws.com',
#    'Port': 5432,
#    'HostedZoneId': 'Z2YROVNTF0QJSQ'},
#   'AllocatedStorage': 100,
#   'InstanceCreateTime': datetime.datetime(2019, 10, 4, 17, 12, 44, 370000, tzinfo=tzutc()),
#   'PreferredBackupWindow': '08:45-09:15',
#   'BackupRetentionPeriod': 7,
#   'DBSecurityGroups': [],
#   'VpcSecurityGroups': [{'VpcSecurityGroupId': 'sg-ba5a26dd',
#     'Status': 'active'},
#    {'VpcSecurityGroupId': 'sg-41e93227', 'Status': 'active'}],
#   'DBParameterGroups': [{'DBParameterGroupName': 'default.postgres9.6',
#     'ParameterApplyStatus': 'in-sync'}],
#   'AvailabilityZone': 'us-gov-west-1b',
#   'DBSubnetGroup': {'DBSubnetGroupName': 'dsva-dvp-sandbox-api-gateway-db-sng',
#    'DBSubnetGroupDescription': 'api-gateway sandbox PostgreSQL subnet group',
#    'VpcId': 'vpc-ec28e088',
#    'SubnetGroupStatus': 'Complete',
#    'Subnets': [{'SubnetIdentifier': 'subnet-4f98042b',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1b'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'},
#     {'SubnetIdentifier': 'subnet-61e27217',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1a'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'}]},
#   'PreferredMaintenanceWindow': 'thu:10:21-thu:10:51',
#   'PendingModifiedValues': {},
#   'LatestRestorableTime': datetime.datetime(2022, 5, 18, 2, 54, 34, tzinfo=tzutc()),
#   'MultiAZ': True,
#   'EngineVersion': '9.6.23',
#   'AutoMinorVersionUpgrade': True,
#   'ReadReplicaDBInstanceIdentifiers': [],
#   'LicenseModel': 'postgresql-license',
#   'OptionGroupMemberships': [{'OptionGroupName': 'default:postgres-9-6',
#     'Status': 'in-sync'}],
#   'SecondaryAvailabilityZone': 'us-gov-west-1a',
#   'PubliclyAccessible': False,
#   'StorageType': 'gp2',
#   'DbInstancePort': 0,
#   'StorageEncrypted': True,
#   'KmsKeyId': 'arn:aws-us-gov:kms:us-gov-west-1:008577686731:key/da52fa14-0ee7-4e02-bc43-e09d2e0638c9',
#   'DbiResourceId': 'db-2L3R73EIHLRJZ5QZGBG5AEWVBU',
#   'CACertificateIdentifier': 'rds-ca-2017',
#   'DomainMemberships': [],
#   'CopyTagsToSnapshot': True,
#   'MonitoringInterval': 0,
#   'DBInstanceArn': 'arn:aws-us-gov:rds:us-gov-west-1:008577686731:db:dvp-sandbox-api-gateway-db',
#   'IAMDatabaseAuthenticationEnabled': False,
#   'PerformanceInsightsEnabled': False,
#   'EnabledCloudwatchLogsExports': ['postgresql', 'upgrade'],
#   'DeletionProtection': True,
#   'AssociatedRoles': [],
#   'TagList': [{'Key': 'Office', 'Value': 'tbd'},
#    {'Key': 'ProjectName', 'Value': 'DVP Lighthouse Platform API'},
#    {'Key': 'ResTag', 'Value': 'shared'},
#    {'Key': 'project', 'Value': 'dvp'},
#    {'Key': 'office', 'Value': 'osva'},
#    {'Key': 'Name', 'Value': 'dsva-dvp-sandbox-api-gateway'},
#    {'Key': 'Role', 'Value': 'tbd'},
#    {'Key': 'VAECID', 'Value': 'AWG20180517003'},
#    {'Key': 'environment', 'Value': 'sandbox'},
#    {'Key': 'Adminstration', 'Value': 'TBD'},
#    {'Key': 'application', 'Value': 'api-gateway'},
#    {'Key': 'provider', 'Value': 'aws'},
#    {'Key': 'managed', 'Value': 'terraform'},
#    {'Key': 'Environment', 'Value': 'SANDBOX'},
#    {'Key': 'region', 'Value': 'govcloud'},
#    {'Key': 'suboffice', 'Value': 'cto'},
#    {'Key': 'ProjectShort', 'Value': 'DVP-Lighthouse'},
#    {'Key': 'dsva_version', 'Value': 'v2'}],
#   'CustomerOwnedIpEnabled': False,
#   'BackupTarget': 'region'},
#  {'DBInstanceIdentifier': 'dvp-staging-api-gateway-db',
#   'DBInstanceClass': 'db.m4.large',
#   'Engine': 'postgres',
#   'DBInstanceStatus': 'available',
#   'MasterUsername': 'api_gateway_kong',
#   'DBName': 'api_gateway',
#   'Endpoint': {'Address': 'dvp-staging-api-gateway-db.cdqbofmbcmtd.us-gov-west-1.rds.amazonaws.com',
#    'Port': 5432,
#    'HostedZoneId': 'Z2YROVNTF0QJSQ'},
#   'AllocatedStorage': 100,
#   'InstanceCreateTime': datetime.datetime(2019, 3, 27, 21, 1, 35, 955000, tzinfo=tzutc()),
#   'PreferredBackupWindow': '08:45-09:15',
#   'BackupRetentionPeriod': 7,
#   'DBSecurityGroups': [],
#   'VpcSecurityGroups': [{'VpcSecurityGroupId': 'sg-bd5c20da',
#     'Status': 'active'},
#    {'VpcSecurityGroupId': 'sg-665ef301', 'Status': 'active'}],
#   'DBParameterGroups': [{'DBParameterGroupName': 'default.postgres9.6',
#     'ParameterApplyStatus': 'in-sync'}],
#   'AvailabilityZone': 'us-gov-west-1a',
#   'DBSubnetGroup': {'DBSubnetGroupName': 'dsva-dvp-staging-api-gateway-db-sng',
#    'DBSubnetGroupDescription': 'api-gateway staging PostgreSQL subnet group',
#    'VpcId': 'vpc-0bb6496f',
#    'SubnetGroupStatus': 'Complete',
#    'Subnets': [{'SubnetIdentifier': 'subnet-1bcd4d6d',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1a'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'},
#     {'SubnetIdentifier': 'subnet-60a82704',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1b'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'}]},
#   'PreferredMaintenanceWindow': 'thu:10:21-thu:10:51',
#   'PendingModifiedValues': {},
#   'LatestRestorableTime': datetime.datetime(2022, 5, 18, 2, 54, 34, tzinfo=tzutc()),
#   'MultiAZ': True,
#   'EngineVersion': '9.6.23',
#   'AutoMinorVersionUpgrade': True,
#   'ReadReplicaDBInstanceIdentifiers': [],
#   'LicenseModel': 'postgresql-license',
#   'OptionGroupMemberships': [{'OptionGroupName': 'default:postgres-9-6',
#     'Status': 'in-sync'}],
#   'SecondaryAvailabilityZone': 'us-gov-west-1b',
#   'PubliclyAccessible': False,
#   'StorageType': 'gp2',
#   'DbInstancePort': 0,
#   'StorageEncrypted': True,
#   'KmsKeyId': 'arn:aws-us-gov:kms:us-gov-west-1:008577686731:key/da52fa14-0ee7-4e02-bc43-e09d2e0638c9',
#   'DbiResourceId': 'db-QT45PPQBO7YCJJ75GN2EI3XN2I',
#   'CACertificateIdentifier': 'rds-ca-2017',
#   'DomainMemberships': [],
#   'CopyTagsToSnapshot': True,
#   'MonitoringInterval': 0,
#   'DBInstanceArn': 'arn:aws-us-gov:rds:us-gov-west-1:008577686731:db:dvp-staging-api-gateway-db',
#   'IAMDatabaseAuthenticationEnabled': False,
#   'PerformanceInsightsEnabled': False,
#   'EnabledCloudwatchLogsExports': ['postgresql', 'upgrade'],
#   'DeletionProtection': True,
#   'AssociatedRoles': [],
#   'TagList': [{'Key': 'Office', 'Value': 'tbd'},
#    {'Key': 'ProjectName', 'Value': 'VA Vets.gov'},
#    {'Key': 'ResTag', 'Value': 'shared'},
#    {'Key': 'project', 'Value': 'dvp'},
#    {'Key': 'office', 'Value': 'osva'},
#    {'Key': 'Name', 'Value': 'dsva-dvp-staging-api-gateway'},
#    {'Key': 'Role', 'Value': 'tbd'},
#    {'Key': 'VAECID', 'Value': 'AWG20180517003'},
#    {'Key': 'environment', 'Value': 'staging'},
#    {'Key': 'Adminstration', 'Value': 'TBD'},
#    {'Key': 'application', 'Value': 'api-gateway'},
#    {'Key': 'provider', 'Value': 'aws'},
#    {'Key': 'managed', 'Value': 'terraform'},
#    {'Key': 'Environment', 'Value': 'STAGING'},
#    {'Key': 'region', 'Value': 'govcloud'},
#    {'Key': 'suboffice', 'Value': 'cto'},
#    {'Key': 'ProjectShort', 'Value': 'Vets.gov'},
#    {'Key': 'dsva_version', 'Value': 'v2'}],
#   'CustomerOwnedIpEnabled': False,
#   'BackupTarget': 'region'},
#  {'DBInstanceIdentifier': 'vacols-postgres-analytics',
#   'DBInstanceClass': 'db.m4.large',
#   'Engine': 'postgres',
#   'DBInstanceStatus': 'available',
#   'MasterUsername': 'DSUSERROOT',
#   'DBName': 'VACOLS',
#   'Endpoint': {'Address': 'vacols-postgres-analytics.cdqbofmbcmtd.us-gov-west-1.rds.amazonaws.com',
#    'Port': 5432,
#    'HostedZoneId': 'Z2YROVNTF0QJSQ'},
#   'AllocatedStorage': 100,
#   'InstanceCreateTime': datetime.datetime(2018, 7, 12, 17, 25, 7, 303000, tzinfo=tzutc()),
#   'PreferredBackupWindow': '10:46-11:16',
#   'BackupRetentionPeriod': 7,
#   'DBSecurityGroups': [],
#   'VpcSecurityGroups': [{'VpcSecurityGroupId': 'sg-d70584b3',
#     'Status': 'active'},
#    {'VpcSecurityGroupId': 'sg-10587375', 'Status': 'active'}],
#   'DBParameterGroups': [{'DBParameterGroupName': 'postgres96-logicalreplication',
#     'ParameterApplyStatus': 'in-sync'}],
#   'AvailabilityZone': 'us-gov-west-1a',
#   'DBSubnetGroup': {'DBSubnetGroupName': 'default-vpc-527dfb37',
#    'DBSubnetGroupDescription': 'Database subnet group for prod',
#    'VpcId': 'vpc-527dfb37',
#    'SubnetGroupStatus': 'Complete',
#    'Subnets': [{'SubnetIdentifier': 'subnet-7f220808',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1a'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'},
#     {'SubnetIdentifier': 'subnet-5ab9833f',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1b'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'}]},
#   'PreferredMaintenanceWindow': 'wed:07:07-wed:07:37',
#   'PendingModifiedValues': {},
#   'LatestRestorableTime': datetime.datetime(2022, 5, 18, 2, 54, 36, tzinfo=tzutc()),
#   'MultiAZ': True,
#   'EngineVersion': '9.6.23',
#   'AutoMinorVersionUpgrade': True,
#   'ReadReplicaDBInstanceIdentifiers': [],
#   'LicenseModel': 'postgresql-license',
#   'Iops': 1000,
#   'OptionGroupMemberships': [{'OptionGroupName': 'default:postgres-9-6',
#     'Status': 'in-sync'}],
#   'SecondaryAvailabilityZone': 'us-gov-west-1b',
#   'PubliclyAccessible': False,
#   'StorageType': 'io1',
#   'DbInstancePort': 0,
#   'StorageEncrypted': True,
#   'KmsKeyId': 'arn:aws-us-gov:kms:us-gov-west-1:008577686731:key/da52fa14-0ee7-4e02-bc43-e09d2e0638c9',
#   'DbiResourceId': 'db-BLMOXDKTYNFX4NMOKMCVKDCS74',
#   'CACertificateIdentifier': 'rds-ca-2017',
#   'DomainMemberships': [],
#   'CopyTagsToSnapshot': True,
#   'MonitoringInterval': 60,
#   'EnhancedMonitoringResourceArn': 'arn:aws-us-gov:logs:us-gov-west-1:008577686731:log-group:RDSOSMetrics:log-stream:db-BLMOXDKTYNFX4NMOKMCVKDCS74',
#   'MonitoringRoleArn': 'arn:aws-us-gov:iam::008577686731:role/rds-monitoring-role',
#   'DBInstanceArn': 'arn:aws-us-gov:rds:us-gov-west-1:008577686731:db:vacols-postgres-analytics',
#   'IAMDatabaseAuthenticationEnabled': False,
#   'PerformanceInsightsEnabled': False,
#   'DeletionProtection': False,
#   'AssociatedRoles': [],
#   'TagList': [{'Key': 'VAECID', 'Value': 'AWG20180405001'},
#    {'Key': 'workload-type', 'Value': 'production'},
#    {'Key': 'ProjectName', 'Value': 'Caseflow'},
#    {'Key': 'ProjectShort', 'Value': 'Caseflow'}],
#   'CustomerOwnedIpEnabled': False,
#   'BackupTarget': 'region'}]

# %%
len(get_db_instances)
# Out:
# 47

# %%
get_only_the_vpc_in_vpc_list = []

for item in get_db_instances:
    check_vpc_id = item.get("DBSubnetGroup").get("VpcId")
    for row in vpc_list:
        if row == check_vpc_id:
            get_only_the_vpc_in_vpc_list.append(item)
        else:
            pass

# %%
len(get_only_the_vpc_in_vpc_list)
# Out:
# 26

# %%
get_only_the_vpc_in_vpc_list
# Out:
# [{'DBInstanceIdentifier': 'dsva-cms-dev-db',
#   'DBInstanceClass': 'db.m5.4xlarge',
#   'Engine': 'mariadb',
#   'DBInstanceStatus': 'available',
#   'MasterUsername': 'master',
#   'DBName': 'dsva_cms_dev',
#   'Endpoint': {'Address': 'dsva-cms-dev-db.cdqbofmbcmtd.us-gov-west-1.rds.amazonaws.com',
#    'Port': 3306,
#    'HostedZoneId': 'Z2YROVNTF0QJSQ'},
#   'AllocatedStorage': 100,
#   'InstanceCreateTime': datetime.datetime(2021, 2, 11, 1, 56, 46, 951000, tzinfo=tzutc()),
#   'PreferredBackupWindow': '07:24-07:54',
#   'BackupRetentionPeriod': 14,
#   'DBSecurityGroups': [],
#   'VpcSecurityGroups': [{'VpcSecurityGroupId': 'sg-4b466d2c',
#     'Status': 'active'}],
#   'DBParameterGroups': [{'DBParameterGroupName': 'cms-dev-mariadb-10-5',
#     'ParameterApplyStatus': 'in-sync'}],
#   'AvailabilityZone': 'us-gov-west-1a',
#   'DBSubnetGroup': {'DBSubnetGroupName': 'dsva-vagov-dev-cms-rds-sng',
#    'DBSubnetGroupDescription': 'RDS subnet group for cms',
#    'VpcId': 'vpc-b50046d0',
#    'SubnetGroupStatus': 'Complete',
#    'Subnets': [{'SubnetIdentifier': 'subnet-2c4e176a',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1c'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'},
#     {'SubnetIdentifier': 'subnet-8d3dd6e9',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1b'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'},
#     {'SubnetIdentifier': 'subnet-d6f512a0',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1a'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'}]},
#   'PreferredMaintenanceWindow': 'wed:10:00-wed:10:30',
#   'PendingModifiedValues': {},
#   'LatestRestorableTime': datetime.datetime(2022, 5, 18, 2, 55, 18, tzinfo=tzutc()),
#   'MultiAZ': True,
#   'EngineVersion': '10.5.13',
#   'AutoMinorVersionUpgrade': True,
#   'ReadReplicaDBInstanceIdentifiers': [],
#   'LicenseModel': 'general-public-license',
#   'OptionGroupMemberships': [{'OptionGroupName': 'default:mariadb-10-5',
#     'Status': 'in-sync'}],
#   'SecondaryAvailabilityZone': 'us-gov-west-1c',
#   'PubliclyAccessible': False,
#   'StorageType': 'gp2',
#   'DbInstancePort': 0,
#   'StorageEncrypted': True,
#   'KmsKeyId': 'arn:aws-us-gov:kms:us-gov-west-1:008577686731:key/da52fa14-0ee7-4e02-bc43-e09d2e0638c9',
#   'DbiResourceId': 'db-JCNP2CGRJ36JVVWLVQAQV33TNQ',
#   'CACertificateIdentifier': 'rds-ca-2017',
#   'DomainMemberships': [],
#   'CopyTagsToSnapshot': True,
#   'MonitoringInterval': 1,
#   'EnhancedMonitoringResourceArn': 'arn:aws-us-gov:logs:us-gov-west-1:008577686731:log-group:RDSOSMetrics:log-stream:db-JCNP2CGRJ36JVVWLVQAQV33TNQ',
#   'MonitoringRoleArn': 'arn:aws-us-gov:iam::008577686731:role/rds-monitoring-role',
#   'DBInstanceArn': 'arn:aws-us-gov:rds:us-gov-west-1:008577686731:db:dsva-cms-dev-db',
#   'IAMDatabaseAuthenticationEnabled': False,
#   'PerformanceInsightsEnabled': False,
#   'DeletionProtection': True,
#   'AssociatedRoles': [],
#   'TagList': [{'Key': 'Office', 'Value': 'tbd'},
#    {'Key': 'ProjectName', 'Value': 'VA Vets.gov'},
#    {'Key': 'ResTag', 'Value': 'shared'},
#    {'Key': 'project', 'Value': 'vagov'},
#    {'Key': 'office', 'Value': 'osva'},
#    {'Key': 'Name', 'Value': 'dsva-vagov-dev-cms-rds'},
#    {'Key': 'Role', 'Value': 'tbd'},
#    {'Key': 'VAECID', 'Value': 'AWG20180517003'},
#    {'Key': 'environment', 'Value': 'dev'},
#    {'Key': 'Adminstration', 'Value': 'TBD'},
#    {'Key': 'application', 'Value': 'cms'},
#    {'Key': 'provider', 'Value': 'aws'},
#    {'Key': 'managed', 'Value': 'terraform'},
#    {'Key': 'Environment', 'Value': 'DEV'},
#    {'Key': 'region', 'Value': 'govcloud'},
#    {'Key': 'suboffice', 'Value': 'cto'},
#    {'Key': 'ProjectShort', 'Value': 'Vets.gov'},
#    {'Key': 'dsva_version', 'Value': 'v2'},
#    {'Key': 'group', 'Value': 'dsva'}],
#   'CustomerOwnedIpEnabled': False,
#   'BackupTarget': 'region'},
#  {'DBInstanceIdentifier': 'dsva-cms-prod-db',
#   'DBInstanceClass': 'db.m5.4xlarge',
#   'Engine': 'mariadb',
#   'DBInstanceStatus': 'available',
#   'MasterUsername': 'master',
#   'DBName': 'dsva_cms_prod',
#   'Endpoint': {'Address': 'dsva-cms-prod-db.cdqbofmbcmtd.us-gov-west-1.rds.amazonaws.com',
#    'Port': 3306,
#    'HostedZoneId': 'Z2YROVNTF0QJSQ'},
#   'AllocatedStorage': 100,
#   'InstanceCreateTime': datetime.datetime(2021, 2, 11, 2, 13, 40, 372000, tzinfo=tzutc()),
#   'PreferredBackupWindow': '07:24-07:54',
#   'BackupRetentionPeriod': 14,
#   'DBSecurityGroups': [],
#   'VpcSecurityGroups': [{'VpcSecurityGroupId': 'sg-b38bb3d4',
#     'Status': 'active'}],
#   'DBParameterGroups': [{'DBParameterGroupName': 'cms-prod-mariadb-10-5',
#     'ParameterApplyStatus': 'in-sync'}],
#   'AvailabilityZone': 'us-gov-west-1b',
#   'DBSubnetGroup': {'DBSubnetGroupName': 'dsva-vagov-prod-cms-rds-sng',
#    'DBSubnetGroupDescription': 'RDS subnet group for cms',
#    'VpcId': 'vpc-d50f49b0',
#    'SubnetGroupStatus': 'Complete',
#    'Subnets': [{'SubnetIdentifier': 'subnet-a433d8c0',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1b'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'},
#     {'SubnetIdentifier': 'subnet-66411820',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1c'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'},
#     {'SubnetIdentifier': 'subnet-f3f31485',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1a'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'}]},
#   'PreferredMaintenanceWindow': 'wed:10:00-wed:10:30',
#   'PendingModifiedValues': {},
#   'LatestRestorableTime': datetime.datetime(2022, 5, 18, 2, 55, tzinfo=tzutc()),
#   'MultiAZ': True,
#   'EngineVersion': '10.5.13',
#   'AutoMinorVersionUpgrade': True,
#   'ReadReplicaDBInstanceIdentifiers': [],
#   'LicenseModel': 'general-public-license',
#   'OptionGroupMemberships': [{'OptionGroupName': 'default:mariadb-10-5',
#     'Status': 'in-sync'}],
#   'SecondaryAvailabilityZone': 'us-gov-west-1c',
#   'PubliclyAccessible': False,
#   'StorageType': 'gp2',
#   'DbInstancePort': 0,
#   'StorageEncrypted': True,
#   'KmsKeyId': 'arn:aws-us-gov:kms:us-gov-west-1:008577686731:key/da52fa14-0ee7-4e02-bc43-e09d2e0638c9',
#   'DbiResourceId': 'db-76M5FGOXHUULCJ6Z7CX2OU4WV4',
#   'CACertificateIdentifier': 'rds-ca-2017',
#   'DomainMemberships': [],
#   'CopyTagsToSnapshot': True,
#   'MonitoringInterval': 1,
#   'EnhancedMonitoringResourceArn': 'arn:aws-us-gov:logs:us-gov-west-1:008577686731:log-group:RDSOSMetrics:log-stream:db-76M5FGOXHUULCJ6Z7CX2OU4WV4',
#   'MonitoringRoleArn': 'arn:aws-us-gov:iam::008577686731:role/rds-monitoring-role',
#   'DBInstanceArn': 'arn:aws-us-gov:rds:us-gov-west-1:008577686731:db:dsva-cms-prod-db',
#   'IAMDatabaseAuthenticationEnabled': False,
#   'PerformanceInsightsEnabled': False,
#   'DeletionProtection': True,
#   'AssociatedRoles': [],
#   'TagList': [{'Key': 'Office', 'Value': 'tbd'},
#    {'Key': 'ProjectName', 'Value': 'VA Vets.gov'},
#    {'Key': 'ResTag', 'Value': 'shared'},
#    {'Key': 'project', 'Value': 'vagov'},
#    {'Key': 'office', 'Value': 'osva'},
#    {'Key': 'Name', 'Value': 'dsva-vagov-prod-cms-rds'},
#    {'Key': 'Role', 'Value': 'tbd'},
#    {'Key': 'VAECID', 'Value': 'AWG20180517003'},
#    {'Key': 'environment', 'Value': 'prod'},
#    {'Key': 'Adminstration', 'Value': 'TBD'},
#    {'Key': 'application', 'Value': 'cms'},
#    {'Key': 'provider', 'Value': 'aws'},
#    {'Key': 'managed', 'Value': 'terraform'},
#    {'Key': 'Environment', 'Value': 'PROD'},
#    {'Key': 'region', 'Value': 'govcloud'},
#    {'Key': 'suboffice', 'Value': 'cto'},
#    {'Key': 'ProjectShort', 'Value': 'Vets.gov'},
#    {'Key': 'dsva_version', 'Value': 'v2'},
#    {'Key': 'group', 'Value': 'dsva'}],
#   'CustomerOwnedIpEnabled': False,
#   'BackupTarget': 'region'},
#  {'DBInstanceIdentifier': 'dsva-cms-staging-db',
#   'DBInstanceClass': 'db.m5.4xlarge',
#   'Engine': 'mariadb',
#   'DBInstanceStatus': 'available',
#   'MasterUsername': 'master',
#   'DBName': 'dsva_cms_staging',
#   'Endpoint': {'Address': 'dsva-cms-staging-db.cdqbofmbcmtd.us-gov-west-1.rds.amazonaws.com',
#    'Port': 3306,
#    'HostedZoneId': 'Z2YROVNTF0QJSQ'},
#   'AllocatedStorage': 100,
#   'InstanceCreateTime': datetime.datetime(2021, 2, 11, 4, 22, 53, 318000, tzinfo=tzutc()),
#   'PreferredBackupWindow': '07:24-07:54',
#   'BackupRetentionPeriod': 14,
#   'DBSecurityGroups': [],
#   'VpcSecurityGroups': [{'VpcSecurityGroupId': 'sg-d690a8b1',
#     'Status': 'active'}],
#   'DBParameterGroups': [{'DBParameterGroupName': 'cms-staging-mariadb-10-5',
#     'ParameterApplyStatus': 'in-sync'}],
#   'AvailabilityZone': 'us-gov-west-1b',
#   'DBSubnetGroup': {'DBSubnetGroupName': 'dsva-vagov-staging-cms-rds-sng',
#    'DBSubnetGroupDescription': 'RDS subnet group for cms',
#    'VpcId': 'vpc-840147e1',
#    'SubnetGroupStatus': 'Complete',
#    'Subnets': [{'SubnetIdentifier': 'subnet-70f51206',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1a'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'},
#     {'SubnetIdentifier': 'subnet-b84e17fe',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1c'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'},
#     {'SubnetIdentifier': 'subnet-cc3cd7a8',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1b'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'}]},
#   'PreferredMaintenanceWindow': 'wed:10:00-wed:10:30',
#   'PendingModifiedValues': {},
#   'LatestRestorableTime': datetime.datetime(2022, 5, 18, 2, 55, tzinfo=tzutc()),
#   'MultiAZ': True,
#   'EngineVersion': '10.5.13',
#   'AutoMinorVersionUpgrade': True,
#   'ReadReplicaDBInstanceIdentifiers': [],
#   'LicenseModel': 'general-public-license',
#   'OptionGroupMemberships': [{'OptionGroupName': 'default:mariadb-10-5',
#     'Status': 'in-sync'}],
#   'SecondaryAvailabilityZone': 'us-gov-west-1c',
#   'PubliclyAccessible': False,
#   'StorageType': 'gp2',
#   'DbInstancePort': 0,
#   'StorageEncrypted': True,
#   'KmsKeyId': 'arn:aws-us-gov:kms:us-gov-west-1:008577686731:key/da52fa14-0ee7-4e02-bc43-e09d2e0638c9',
#   'DbiResourceId': 'db-JSYTLZZL3KYCUCOFKRPXF34LFY',
#   'CACertificateIdentifier': 'rds-ca-2017',
#   'DomainMemberships': [],
#   'CopyTagsToSnapshot': True,
#   'MonitoringInterval': 1,
#   'EnhancedMonitoringResourceArn': 'arn:aws-us-gov:logs:us-gov-west-1:008577686731:log-group:RDSOSMetrics:log-stream:db-JSYTLZZL3KYCUCOFKRPXF34LFY',
#   'MonitoringRoleArn': 'arn:aws-us-gov:iam::008577686731:role/rds-monitoring-role',
#   'DBInstanceArn': 'arn:aws-us-gov:rds:us-gov-west-1:008577686731:db:dsva-cms-staging-db',
#   'IAMDatabaseAuthenticationEnabled': False,
#   'PerformanceInsightsEnabled': False,
#   'DeletionProtection': True,
#   'AssociatedRoles': [],
#   'TagList': [{'Key': 'Office', 'Value': 'tbd'},
#    {'Key': 'ProjectName', 'Value': 'vagov'},
#    {'Key': 'ResTag', 'Value': 'shared'},
#    {'Key': 'project', 'Value': 'vagov'},
#    {'Key': 'office', 'Value': 'osva'},
#    {'Key': 'Name', 'Value': 'dsva-vagov-staging-cms-rds'},
#    {'Key': 'Role', 'Value': 'tbd'},
#    {'Key': 'VAECID', 'Value': 'AWG20180517003'},
#    {'Key': 'environment', 'Value': 'staging'},
#    {'Key': 'Adminstration', 'Value': 'VBA'},
#    {'Key': 'application', 'Value': 'cms'},
#    {'Key': 'provider', 'Value': 'aws'},
#    {'Key': 'managed', 'Value': 'terraform'},
#    {'Key': 'Environment', 'Value': 'STAGING'},
#    {'Key': 'region', 'Value': 'govcloud'},
#    {'Key': 'suboffice', 'Value': 'cto'},
#    {'Key': 'ProjectShort', 'Value': 'Vets.gov'},
#    {'Key': 'dsva_version', 'Value': 'v2'},
#    {'Key': 'group', 'Value': 'dsva'}],
#   'CustomerOwnedIpEnabled': False,
#   'BackupTarget': 'region'},
#  {'DBInstanceIdentifier': 'dsva-cms-test-dev-db',
#   'DBInstanceClass': 'db.m5.4xlarge',
#   'Engine': 'mariadb',
#   'DBInstanceStatus': 'available',
#   'MasterUsername': 'master',
#   'DBName': 'dsva_cms_dev',
#   'Endpoint': {'Address': 'dsva-cms-test-dev-db.cdqbofmbcmtd.us-gov-west-1.rds.amazonaws.com',
#    'Port': 3306,
#    'HostedZoneId': 'Z2YROVNTF0QJSQ'},
#   'AllocatedStorage': 100,
#   'InstanceCreateTime': datetime.datetime(2021, 2, 19, 1, 55, 52, 466000, tzinfo=tzutc()),
#   'PreferredBackupWindow': '07:24-07:54',
#   'BackupRetentionPeriod': 14,
#   'DBSecurityGroups': [],
#   'VpcSecurityGroups': [{'VpcSecurityGroupId': 'sg-e8df7b91',
#     'Status': 'active'}],
#   'DBParameterGroups': [{'DBParameterGroupName': 'cms-test-dev-mariadb-10-5',
#     'ParameterApplyStatus': 'in-sync'}],
#   'AvailabilityZone': 'us-gov-west-1a',
#   'DBSubnetGroup': {'DBSubnetGroupName': 'dsva-vagov-dev-cms-test-rds-sng',
#    'DBSubnetGroupDescription': 'RDS subnet group for cms-test',
#    'VpcId': 'vpc-b50046d0',
#    'SubnetGroupStatus': 'Complete',
#    'Subnets': [{'SubnetIdentifier': 'subnet-8d3dd6e9',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1b'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'},
#     {'SubnetIdentifier': 'subnet-d6f512a0',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1a'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'},
#     {'SubnetIdentifier': 'subnet-2c4e176a',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1c'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'}]},
#   'PreferredMaintenanceWindow': 'wed:10:00-wed:10:30',
#   'PendingModifiedValues': {},
#   'LatestRestorableTime': datetime.datetime(2022, 5, 18, 2, 55, tzinfo=tzutc()),
#   'MultiAZ': True,
#   'EngineVersion': '10.5.13',
#   'AutoMinorVersionUpgrade': True,
#   'ReadReplicaDBInstanceIdentifiers': [],
#   'LicenseModel': 'general-public-license',
#   'OptionGroupMemberships': [{'OptionGroupName': 'default:mariadb-10-5',
#     'Status': 'in-sync'}],
#   'SecondaryAvailabilityZone': 'us-gov-west-1c',
#   'PubliclyAccessible': False,
#   'StorageType': 'gp2',
#   'DbInstancePort': 0,
#   'StorageEncrypted': True,
#   'KmsKeyId': 'arn:aws-us-gov:kms:us-gov-west-1:008577686731:key/da52fa14-0ee7-4e02-bc43-e09d2e0638c9',
#   'DbiResourceId': 'db-PGLCV4STVUB3VCHJSXSVWIYOP4',
#   'CACertificateIdentifier': 'rds-ca-2017',
#   'DomainMemberships': [],
#   'CopyTagsToSnapshot': True,
#   'MonitoringInterval': 1,
#   'EnhancedMonitoringResourceArn': 'arn:aws-us-gov:logs:us-gov-west-1:008577686731:log-group:RDSOSMetrics:log-stream:db-PGLCV4STVUB3VCHJSXSVWIYOP4',
#   'MonitoringRoleArn': 'arn:aws-us-gov:iam::008577686731:role/rds-monitoring-role',
#   'DBInstanceArn': 'arn:aws-us-gov:rds:us-gov-west-1:008577686731:db:dsva-cms-test-dev-db',
#   'IAMDatabaseAuthenticationEnabled': False,
#   'PerformanceInsightsEnabled': False,
#   'DeletionProtection': True,
#   'AssociatedRoles': [],
#   'TagList': [{'Key': 'Office', 'Value': 'tbd'},
#    {'Key': 'ProjectName', 'Value': 'VA Vets.gov'},
#    {'Key': 'ResTag', 'Value': 'shared'},
#    {'Key': 'project', 'Value': 'vagov'},
#    {'Key': 'office', 'Value': 'osva'},
#    {'Key': 'Name', 'Value': 'dsva-vagov-dev-cms-test-rds'},
#    {'Key': 'Role', 'Value': 'tbd'},
#    {'Key': 'VAECID', 'Value': 'AWG20180517003'},
#    {'Key': 'environment', 'Value': 'dev'},
#    {'Key': 'Adminstration', 'Value': 'TBD'},
#    {'Key': 'application', 'Value': 'cms-test'},
#    {'Key': 'provider', 'Value': 'aws'},
#    {'Key': 'managed', 'Value': 'terraform'},
#    {'Key': 'Environment', 'Value': 'DEV'},
#    {'Key': 'region', 'Value': 'govcloud'},
#    {'Key': 'suboffice', 'Value': 'cto'},
#    {'Key': 'ProjectShort', 'Value': 'Vets.gov'},
#    {'Key': 'dsva_version', 'Value': 'v2'},
#    {'Key': 'group', 'Value': 'dsva'}],
#   'CustomerOwnedIpEnabled': False,
#   'BackupTarget': 'region'},
#  {'DBInstanceIdentifier': 'dsva-cms-test-prod-db',
#   'DBInstanceClass': 'db.m5.4xlarge',
#   'Engine': 'mariadb',
#   'DBInstanceStatus': 'available',
#   'MasterUsername': 'master',
#   'DBName': 'dsva_cms_prod',
#   'Endpoint': {'Address': 'dsva-cms-test-prod-db.cdqbofmbcmtd.us-gov-west-1.rds.amazonaws.com',
#    'Port': 3306,
#    'HostedZoneId': 'Z2YROVNTF0QJSQ'},
#   'AllocatedStorage': 100,
#   'InstanceCreateTime': datetime.datetime(2021, 2, 19, 1, 44, 32, 473000, tzinfo=tzutc()),
#   'PreferredBackupWindow': '07:24-07:54',
#   'BackupRetentionPeriod': 14,
#   'DBSecurityGroups': [],
#   'VpcSecurityGroups': [{'VpcSecurityGroupId': 'sg-64db7f1d',
#     'Status': 'active'}],
#   'DBParameterGroups': [{'DBParameterGroupName': 'cms-test-prod-mariadb-10-5',
#     'ParameterApplyStatus': 'in-sync'}],
#   'AvailabilityZone': 'us-gov-west-1b',
#   'DBSubnetGroup': {'DBSubnetGroupName': 'dsva-vagov-prod-cms-test-rds-sng',
#    'DBSubnetGroupDescription': 'RDS subnet group for cms-test',
#    'VpcId': 'vpc-d50f49b0',
#    'SubnetGroupStatus': 'Complete',
#    'Subnets': [{'SubnetIdentifier': 'subnet-a433d8c0',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1b'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'},
#     {'SubnetIdentifier': 'subnet-66411820',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1c'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'},
#     {'SubnetIdentifier': 'subnet-f3f31485',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1a'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'}]},
#   'PreferredMaintenanceWindow': 'wed:10:00-wed:10:30',
#   'PendingModifiedValues': {},
#   'LatestRestorableTime': datetime.datetime(2022, 5, 18, 2, 55, tzinfo=tzutc()),
#   'MultiAZ': True,
#   'EngineVersion': '10.5.13',
#   'AutoMinorVersionUpgrade': True,
#   'ReadReplicaDBInstanceIdentifiers': [],
#   'LicenseModel': 'general-public-license',
#   'OptionGroupMemberships': [{'OptionGroupName': 'default:mariadb-10-5',
#     'Status': 'in-sync'}],
#   'SecondaryAvailabilityZone': 'us-gov-west-1a',
#   'PubliclyAccessible': False,
#   'StorageType': 'gp2',
#   'DbInstancePort': 0,
#   'StorageEncrypted': True,
#   'KmsKeyId': 'arn:aws-us-gov:kms:us-gov-west-1:008577686731:key/da52fa14-0ee7-4e02-bc43-e09d2e0638c9',
#   'DbiResourceId': 'db-2L42RDDVXHURQUSACWQA56DBBQ',
#   'CACertificateIdentifier': 'rds-ca-2017',
#   'DomainMemberships': [],
#   'CopyTagsToSnapshot': True,
#   'MonitoringInterval': 1,
#   'EnhancedMonitoringResourceArn': 'arn:aws-us-gov:logs:us-gov-west-1:008577686731:log-group:RDSOSMetrics:log-stream:db-2L42RDDVXHURQUSACWQA56DBBQ',
#   'MonitoringRoleArn': 'arn:aws-us-gov:iam::008577686731:role/rds-monitoring-role',
#   'DBInstanceArn': 'arn:aws-us-gov:rds:us-gov-west-1:008577686731:db:dsva-cms-test-prod-db',
#   'IAMDatabaseAuthenticationEnabled': False,
#   'PerformanceInsightsEnabled': False,
#   'DeletionProtection': True,
#   'AssociatedRoles': [],
#   'TagList': [{'Key': 'Office', 'Value': 'tbd'},
#    {'Key': 'ProjectName', 'Value': 'VA Vets.gov'},
#    {'Key': 'ResTag', 'Value': 'shared'},
#    {'Key': 'project', 'Value': 'vagov'},
#    {'Key': 'office', 'Value': 'osva'},
#    {'Key': 'Name', 'Value': 'dsva-vagov-prod-cms-test-rds'},
#    {'Key': 'Role', 'Value': 'tbd'},
#    {'Key': 'VAECID', 'Value': 'AWG20180517003'},
#    {'Key': 'environment', 'Value': 'prod'},
#    {'Key': 'Adminstration', 'Value': 'TBD'},
#    {'Key': 'application', 'Value': 'cms-test'},
#    {'Key': 'provider', 'Value': 'aws'},
#    {'Key': 'managed', 'Value': 'terraform'},
#    {'Key': 'Environment', 'Value': 'PROD'},
#    {'Key': 'region', 'Value': 'govcloud'},
#    {'Key': 'suboffice', 'Value': 'cto'},
#    {'Key': 'ProjectShort', 'Value': 'Vets.gov'},
#    {'Key': 'dsva_version', 'Value': 'v2'},
#    {'Key': 'group', 'Value': 'dsva'}],
#   'CustomerOwnedIpEnabled': False,
#   'BackupTarget': 'region'},
#  {'DBInstanceIdentifier': 'dsva-cms-test-staging-db',
#   'DBInstanceClass': 'db.m5.4xlarge',
#   'Engine': 'mariadb',
#   'DBInstanceStatus': 'available',
#   'MasterUsername': 'master',
#   'DBName': 'dsva_cms_staging',
#   'Endpoint': {'Address': 'dsva-cms-test-staging-db.cdqbofmbcmtd.us-gov-west-1.rds.amazonaws.com',
#    'Port': 3306,
#    'HostedZoneId': 'Z2YROVNTF0QJSQ'},
#   'AllocatedStorage': 100,
#   'InstanceCreateTime': datetime.datetime(2021, 2, 19, 1, 46, 12, 523000, tzinfo=tzutc()),
#   'PreferredBackupWindow': '07:24-07:54',
#   'BackupRetentionPeriod': 14,
#   'DBSecurityGroups': [],
#   'VpcSecurityGroups': [{'VpcSecurityGroupId': 'sg-aaa501d3',
#     'Status': 'active'}],
#   'DBParameterGroups': [{'DBParameterGroupName': 'cms-test-staging-mariadb-10-5',
#     'ParameterApplyStatus': 'in-sync'}],
#   'AvailabilityZone': 'us-gov-west-1a',
#   'DBSubnetGroup': {'DBSubnetGroupName': 'dsva-vagov-staging-cms-test-rds-sng',
#    'DBSubnetGroupDescription': 'RDS subnet group for cms-test',
#    'VpcId': 'vpc-840147e1',
#    'SubnetGroupStatus': 'Complete',
#    'Subnets': [{'SubnetIdentifier': 'subnet-70f51206',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1a'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'},
#     {'SubnetIdentifier': 'subnet-b84e17fe',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1c'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'},
#     {'SubnetIdentifier': 'subnet-cc3cd7a8',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1b'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'}]},
#   'PreferredMaintenanceWindow': 'wed:10:00-wed:10:30',
#   'PendingModifiedValues': {},
#   'LatestRestorableTime': datetime.datetime(2022, 5, 18, 2, 55, tzinfo=tzutc()),
#   'MultiAZ': True,
#   'EngineVersion': '10.5.13',
#   'AutoMinorVersionUpgrade': True,
#   'ReadReplicaDBInstanceIdentifiers': [],
#   'LicenseModel': 'general-public-license',
#   'OptionGroupMemberships': [{'OptionGroupName': 'default:mariadb-10-5',
#     'Status': 'in-sync'}],
#   'SecondaryAvailabilityZone': 'us-gov-west-1c',
#   'PubliclyAccessible': False,
#   'StorageType': 'gp2',
#   'DbInstancePort': 0,
#   'StorageEncrypted': True,
#   'KmsKeyId': 'arn:aws-us-gov:kms:us-gov-west-1:008577686731:key/da52fa14-0ee7-4e02-bc43-e09d2e0638c9',
#   'DbiResourceId': 'db-SVOKAMUNH6P2L6GIJEGRIFAXKE',
#   'CACertificateIdentifier': 'rds-ca-2017',
#   'DomainMemberships': [],
#   'CopyTagsToSnapshot': True,
#   'MonitoringInterval': 1,
#   'EnhancedMonitoringResourceArn': 'arn:aws-us-gov:logs:us-gov-west-1:008577686731:log-group:RDSOSMetrics:log-stream:db-SVOKAMUNH6P2L6GIJEGRIFAXKE',
#   'MonitoringRoleArn': 'arn:aws-us-gov:iam::008577686731:role/rds-monitoring-role',
#   'DBInstanceArn': 'arn:aws-us-gov:rds:us-gov-west-1:008577686731:db:dsva-cms-test-staging-db',
#   'IAMDatabaseAuthenticationEnabled': False,
#   'PerformanceInsightsEnabled': False,
#   'DeletionProtection': True,
#   'AssociatedRoles': [],
#   'TagList': [{'Key': 'Office', 'Value': 'tbd'},
#    {'Key': 'ProjectName', 'Value': 'vagov'},
#    {'Key': 'ResTag', 'Value': 'shared'},
#    {'Key': 'project', 'Value': 'vagov'},
#    {'Key': 'office', 'Value': 'osva'},
#    {'Key': 'Name', 'Value': 'dsva-vagov-staging-cms-test-rds'},
#    {'Key': 'Role', 'Value': 'tbd'},
#    {'Key': 'VAECID', 'Value': 'AWG20180517003'},
#    {'Key': 'environment', 'Value': 'staging'},
#    {'Key': 'Adminstration', 'Value': 'VBA'},
#    {'Key': 'application', 'Value': 'cms-test'},
#    {'Key': 'provider', 'Value': 'aws'},
#    {'Key': 'managed', 'Value': 'terraform'},
#    {'Key': 'Environment', 'Value': 'STAGING'},
#    {'Key': 'region', 'Value': 'govcloud'},
#    {'Key': 'suboffice', 'Value': 'cto'},
#    {'Key': 'ProjectShort', 'Value': 'Vets.gov'},
#    {'Key': 'dsva_version', 'Value': 'v2'},
#    {'Key': 'group', 'Value': 'dsva'}],
#   'CustomerOwnedIpEnabled': False,
#   'BackupTarget': 'region'},
#  {'DBInstanceIdentifier': 'dsva-gi-bill-data-service-dev',
#   'DBInstanceClass': 'db.t2.small',
#   'Engine': 'postgres',
#   'DBInstanceStatus': 'available',
#   'MasterUsername': 'gids',
#   'DBName': 'dsva_gids_dev',
#   'Endpoint': {'Address': 'dsva-gi-bill-data-service-dev.cdqbofmbcmtd.us-gov-west-1.rds.amazonaws.com',
#    'Port': 5432,
#    'HostedZoneId': 'Z2YROVNTF0QJSQ'},
#   'AllocatedStorage': 32,
#   'InstanceCreateTime': datetime.datetime(2016, 9, 8, 13, 34, 5, 981000, tzinfo=tzutc()),
#   'PreferredBackupWindow': '12:28-12:58',
#   'BackupRetentionPeriod': 7,
#   'DBSecurityGroups': [],
#   'VpcSecurityGroups': [{'VpcSecurityGroupId': 'sg-bd2702db',
#     'Status': 'active'}],
#   'DBParameterGroups': [{'DBParameterGroupName': 'gi-bill-data-service-dev-param-grp',
#     'ParameterApplyStatus': 'in-sync'}],
#   'AvailabilityZone': 'us-gov-west-1b',
#   'DBSubnetGroup': {'DBSubnetGroupName': 'dsva-vagov-dev-gids-db-sng',
#    'DBSubnetGroupDescription': 'gids dsva-vagov-dev rds db subnet group',
#    'VpcId': 'vpc-b50046d0',
#    'SubnetGroupStatus': 'Complete',
#    'Subnets': [{'SubnetIdentifier': 'subnet-8d3dd6e9',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1b'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'},
#     {'SubnetIdentifier': 'subnet-d6f512a0',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1a'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'},
#     {'SubnetIdentifier': 'subnet-2c4e176a',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1c'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'}]},
#   'PreferredMaintenanceWindow': 'tue:10:01-tue:10:31',
#   'PendingModifiedValues': {},
#   'LatestRestorableTime': datetime.datetime(2022, 5, 18, 2, 54, 51, tzinfo=tzutc()),
#   'MultiAZ': True,
#   'EngineVersion': '11.8',
#   'AutoMinorVersionUpgrade': False,
#   'ReadReplicaDBInstanceIdentifiers': [],
#   'LicenseModel': 'postgresql-license',
#   'OptionGroupMemberships': [{'OptionGroupName': 'default:postgres-11',
#     'Status': 'in-sync'}],
#   'SecondaryAvailabilityZone': 'us-gov-west-1c',
#   'PubliclyAccessible': False,
#   'StorageType': 'standard',
#   'DbInstancePort': 0,
#   'StorageEncrypted': False,
#   'DbiResourceId': 'db-J7W5VPIKIDWKJ27DRZZB5L6KAM',
#   'CACertificateIdentifier': 'rds-ca-2017',
#   'DomainMemberships': [],
#   'CopyTagsToSnapshot': True,
#   'MonitoringInterval': 60,
#   'EnhancedMonitoringResourceArn': 'arn:aws-us-gov:logs:us-gov-west-1:008577686731:log-group:RDSOSMetrics:log-stream:db-J7W5VPIKIDWKJ27DRZZB5L6KAM',
#   'MonitoringRoleArn': 'arn:aws-us-gov:iam::008577686731:role/rds-monitoring-role',
#   'DBInstanceArn': 'arn:aws-us-gov:rds:us-gov-west-1:008577686731:db:dsva-gi-bill-data-service-dev',
#   'IAMDatabaseAuthenticationEnabled': False,
#   'EnabledCloudwatchLogsExports': ['upgrade'],
#   'DeletionProtection': True,
#   'AssociatedRoles': [],
#   'TagList': [{'Key': 'Office', 'Value': 'tbd'},
#    {'Key': 'ProjectName', 'Value': 'VA Vets.gov'},
#    {'Key': 'ResTag', 'Value': 'shared'},
#    {'Key': 'project', 'Value': 'vagov'},
#    {'Key': 'office', 'Value': 'osva'},
#    {'Key': 'Name', 'Value': 'dsva-vagov-dev-gids-db'},
#    {'Key': 'Role', 'Value': 'tbd'},
#    {'Key': 'VAECID', 'Value': 'AWG20180517003'},
#    {'Key': 'environment', 'Value': 'dev'},
#    {'Key': 'Adminstration', 'Value': 'TBD'},
#    {'Key': 'application', 'Value': 'gi-bill-data-service'},
#    {'Key': 'provider', 'Value': 'aws'},
#    {'Key': 'managed', 'Value': 'terraform'},
#    {'Key': 'Environment', 'Value': 'DEV'},
#    {'Key': 'region', 'Value': 'govcloud'},
#    {'Key': 'suboffice', 'Value': 'cto'},
#    {'Key': 'ProjectShort', 'Value': 'Vets.gov'},
#    {'Key': 'dsva_version', 'Value': 'v2'},
#    {'Key': 'group', 'Value': 'dsva'}],
#   'CustomerOwnedIpEnabled': False,
#   'BackupTarget': 'region'},
#  {'DBInstanceIdentifier': 'dsva-gi-bill-data-service-prod',
#   'DBInstanceClass': 'db.m4.xlarge',
#   'Engine': 'postgres',
#   'DBInstanceStatus': 'available',
#   'MasterUsername': 'gids',
#   'DBName': 'dsva_gids_prod',
#   'Endpoint': {'Address': 'dsva-gi-bill-data-service-prod.cdqbofmbcmtd.us-gov-west-1.rds.amazonaws.com',
#    'Port': 5432,
#    'HostedZoneId': 'Z2YROVNTF0QJSQ'},
#   'AllocatedStorage': 100,
#   'InstanceCreateTime': datetime.datetime(2016, 9, 1, 23, 25, 50, 299000, tzinfo=tzutc()),
#   'PreferredBackupWindow': '06:43-07:13',
#   'BackupRetentionPeriod': 7,
#   'DBSecurityGroups': [],
#   'VpcSecurityGroups': [{'VpcSecurityGroupId': 'sg-df7c5db9',
#     'Status': 'active'}],
#   'DBParameterGroups': [{'DBParameterGroupName': 'gi-bill-data-service-prod-param-grp',
#     'ParameterApplyStatus': 'in-sync'}],
#   'AvailabilityZone': 'us-gov-west-1a',
#   'DBSubnetGroup': {'DBSubnetGroupName': 'dsva-vagov-prod-gids-db-sng',
#    'DBSubnetGroupDescription': 'gids dsva-vagov-prod rds db subnet group',
#    'VpcId': 'vpc-d50f49b0',
#    'SubnetGroupStatus': 'Complete',
#    'Subnets': [{'SubnetIdentifier': 'subnet-a433d8c0',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1b'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'},
#     {'SubnetIdentifier': 'subnet-66411820',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1c'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'},
#     {'SubnetIdentifier': 'subnet-f3f31485',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1a'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'}]},
#   'PreferredMaintenanceWindow': 'fri:11:42-fri:12:12',
#   'PendingModifiedValues': {},
#   'LatestRestorableTime': datetime.datetime(2022, 5, 18, 2, 54, 44, tzinfo=tzutc()),
#   'MultiAZ': True,
#   'EngineVersion': '11.8',
#   'AutoMinorVersionUpgrade': False,
#   'ReadReplicaDBInstanceIdentifiers': [],
#   'LicenseModel': 'postgresql-license',
#   'OptionGroupMemberships': [{'OptionGroupName': 'default:postgres-11',
#     'Status': 'in-sync'}],
#   'SecondaryAvailabilityZone': 'us-gov-west-1c',
#   'PubliclyAccessible': False,
#   'StorageType': 'standard',
#   'DbInstancePort': 0,
#   'StorageEncrypted': False,
#   'DbiResourceId': 'db-6VGKWPB4WMWGFXYN6VPAOQALQE',
#   'CACertificateIdentifier': 'rds-ca-2017',
#   'DomainMemberships': [],
#   'CopyTagsToSnapshot': True,
#   'MonitoringInterval': 60,
#   'EnhancedMonitoringResourceArn': 'arn:aws-us-gov:logs:us-gov-west-1:008577686731:log-group:RDSOSMetrics:log-stream:db-6VGKWPB4WMWGFXYN6VPAOQALQE',
#   'MonitoringRoleArn': 'arn:aws-us-gov:iam::008577686731:role/rds-monitoring-role',
#   'DBInstanceArn': 'arn:aws-us-gov:rds:us-gov-west-1:008577686731:db:dsva-gi-bill-data-service-prod',
#   'IAMDatabaseAuthenticationEnabled': False,
#   'EnabledCloudwatchLogsExports': ['upgrade'],
#   'DeletionProtection': True,
#   'AssociatedRoles': [],
#   'TagList': [{'Key': 'Office', 'Value': 'tbd'},
#    {'Key': 'ProjectName', 'Value': 'VA Vets.gov'},
#    {'Key': 'ResTag', 'Value': 'shared'},
#    {'Key': 'project', 'Value': 'vagov'},
#    {'Key': 'office', 'Value': 'osva'},
#    {'Key': 'Name', 'Value': 'dsva-vagov-prod-gids-db'},
#    {'Key': 'Role', 'Value': 'tbd'},
#    {'Key': 'VAECID', 'Value': 'AWG20180517003'},
#    {'Key': 'environment', 'Value': 'prod'},
#    {'Key': 'Adminstration', 'Value': 'TBD'},
#    {'Key': 'application', 'Value': 'gi-bill-data-service'},
#    {'Key': 'provider', 'Value': 'aws'},
#    {'Key': 'managed', 'Value': 'terraform'},
#    {'Key': 'Environment', 'Value': 'PROD'},
#    {'Key': 'region', 'Value': 'govcloud'},
#    {'Key': 'suboffice', 'Value': 'cto'},
#    {'Key': 'ProjectShort', 'Value': 'Vets.gov'},
#    {'Key': 'dsva_version', 'Value': 'v2'},
#    {'Key': 'group', 'Value': 'dsva'}],
#   'CustomerOwnedIpEnabled': False,
#   'BackupTarget': 'region'},
#  {'DBInstanceIdentifier': 'dsva-gi-bill-data-service-staging',
#   'DBInstanceClass': 'db.m4.xlarge',
#   'Engine': 'postgres',
#   'DBInstanceStatus': 'available',
#   'MasterUsername': 'gids',
#   'DBName': 'dsva_gids_staging',
#   'Endpoint': {'Address': 'dsva-gi-bill-data-service-staging.cdqbofmbcmtd.us-gov-west-1.rds.amazonaws.com',
#    'Port': 5432,
#    'HostedZoneId': 'Z2YROVNTF0QJSQ'},
#   'AllocatedStorage': 100,
#   'InstanceCreateTime': datetime.datetime(2017, 2, 22, 0, 23, 36, 741000, tzinfo=tzutc()),
#   'PreferredBackupWindow': '12:41-13:11',
#   'BackupRetentionPeriod': 7,
#   'DBSecurityGroups': [],
#   'VpcSecurityGroups': [{'VpcSecurityGroupId': 'sg-ba2b0edc',
#     'Status': 'active'}],
#   'DBParameterGroups': [{'DBParameterGroupName': 'gi-bill-data-service-staging-param-grp',
#     'ParameterApplyStatus': 'in-sync'}],
#   'AvailabilityZone': 'us-gov-west-1a',
#   'DBSubnetGroup': {'DBSubnetGroupName': 'dsva-vagov-staging-gids-db-sng',
#    'DBSubnetGroupDescription': 'gids dsva-vagov-staging rds db subnet group',
#    'VpcId': 'vpc-840147e1',
#    'SubnetGroupStatus': 'Complete',
#    'Subnets': [{'SubnetIdentifier': 'subnet-70f51206',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1a'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'},
#     {'SubnetIdentifier': 'subnet-b84e17fe',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1c'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'},
#     {'SubnetIdentifier': 'subnet-cc3cd7a8',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1b'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'}]},
#   'PreferredMaintenanceWindow': 'thu:08:44-thu:09:14',
#   'PendingModifiedValues': {},
#   'LatestRestorableTime': datetime.datetime(2022, 5, 18, 2, 54, 41, tzinfo=tzutc()),
#   'MultiAZ': True,
#   'EngineVersion': '11.8',
#   'AutoMinorVersionUpgrade': False,
#   'ReadReplicaDBInstanceIdentifiers': [],
#   'LicenseModel': 'postgresql-license',
#   'OptionGroupMemberships': [{'OptionGroupName': 'default:postgres-11',
#     'Status': 'in-sync'}],
#   'SecondaryAvailabilityZone': 'us-gov-west-1b',
#   'PubliclyAccessible': False,
#   'StorageType': 'standard',
#   'DbInstancePort': 0,
#   'StorageEncrypted': False,
#   'DbiResourceId': 'db-2SFQYSYKNIS5WQ7HFIS5XMQOIY',
#   'CACertificateIdentifier': 'rds-ca-2017',
#   'DomainMemberships': [],
#   'CopyTagsToSnapshot': True,
#   'MonitoringInterval': 60,
#   'EnhancedMonitoringResourceArn': 'arn:aws-us-gov:logs:us-gov-west-1:008577686731:log-group:RDSOSMetrics:log-stream:db-2SFQYSYKNIS5WQ7HFIS5XMQOIY',
#   'MonitoringRoleArn': 'arn:aws-us-gov:iam::008577686731:role/rds-monitoring-role',
#   'DBInstanceArn': 'arn:aws-us-gov:rds:us-gov-west-1:008577686731:db:dsva-gi-bill-data-service-staging',
#   'IAMDatabaseAuthenticationEnabled': False,
#   'PerformanceInsightsEnabled': False,
#   'EnabledCloudwatchLogsExports': ['upgrade'],
#   'DeletionProtection': True,
#   'AssociatedRoles': [],
#   'TagList': [{'Key': 'Office', 'Value': 'tbd'},
#    {'Key': 'ProjectName', 'Value': 'vagov'},
#    {'Key': 'ResTag', 'Value': 'shared'},
#    {'Key': 'project', 'Value': 'vagov'},
#    {'Key': 'office', 'Value': 'osva'},
#    {'Key': 'Name', 'Value': 'dsva-vagov-staging-gids-db'},
#    {'Key': 'Role', 'Value': 'tbd'},
#    {'Key': 'VAECID', 'Value': 'AWG20180517003'},
#    {'Key': 'environment', 'Value': 'staging'},
#    {'Key': 'Adminstration', 'Value': 'VBA'},
#    {'Key': 'application', 'Value': 'gi-bill-data-service'},
#    {'Key': 'provider', 'Value': 'aws'},
#    {'Key': 'managed', 'Value': 'terraform'},
#    {'Key': 'Environment', 'Value': 'STAGING'},
#    {'Key': 'region', 'Value': 'govcloud'},
#    {'Key': 'suboffice', 'Value': 'cto'},
#    {'Key': 'ProjectShort', 'Value': 'Vets.gov'},
#    {'Key': 'dsva_version', 'Value': 'v2'},
#    {'Key': 'group', 'Value': 'dsva'}],
#   'CustomerOwnedIpEnabled': False,
#   'BackupTarget': 'region'},
#  {'DBInstanceIdentifier': 'dsva-lighthouse-ux-toolkit-db',
#   'DBInstanceClass': 'db.m5.large',
#   'Engine': 'postgres',
#   'DBInstanceStatus': 'available',
#   'MasterUsername': 'ux_toolkit',
#   'DBName': 'ux_toolkit',
#   'Endpoint': {'Address': 'dsva-lighthouse-ux-toolkit-db.cdqbofmbcmtd.us-gov-west-1.rds.amazonaws.com',
#    'Port': 5432,
#    'HostedZoneId': 'Z2YROVNTF0QJSQ'},
#   'AllocatedStorage': 100,
#   'InstanceCreateTime': datetime.datetime(2021, 6, 8, 21, 14, 46, 859000, tzinfo=tzutc()),
#   'PreferredBackupWindow': '07:54-08:24',
#   'BackupRetentionPeriod': 7,
#   'DBSecurityGroups': [],
#   'VpcSecurityGroups': [{'VpcSecurityGroupId': 'sg-04921927dc74e3cb6',
#     'Status': 'active'}],
#   'DBParameterGroups': [{'DBParameterGroupName': 'default.postgres12',
#     'ParameterApplyStatus': 'in-sync'}],
#   'AvailabilityZone': 'us-gov-west-1a',
#   'DBSubnetGroup': {'DBSubnetGroupName': 'dsva-vagov-dev-lut-rds-sng',
#    'DBSubnetGroupDescription': 'Lighthouse UX Toolkit RDS Subnet group',
#    'VpcId': 'vpc-b50046d0',
#    'SubnetGroupStatus': 'Complete',
#    'Subnets': [{'SubnetIdentifier': 'subnet-8d3dd6e9',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1b'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'},
#     {'SubnetIdentifier': 'subnet-d6f512a0',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1a'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'},
#     {'SubnetIdentifier': 'subnet-2c4e176a',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1c'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'}]},
#   'PreferredMaintenanceWindow': 'thu:08:52-thu:09:22',
#   'PendingModifiedValues': {},
#   'LatestRestorableTime': datetime.datetime(2022, 5, 18, 2, 54, 35, tzinfo=tzutc()),
#   'MultiAZ': False,
#   'EngineVersion': '12.4',
#   'AutoMinorVersionUpgrade': False,
#   'ReadReplicaDBInstanceIdentifiers': [],
#   'LicenseModel': 'postgresql-license',
#   'OptionGroupMemberships': [{'OptionGroupName': 'default:postgres-12',
#     'Status': 'in-sync'}],
#   'PubliclyAccessible': False,
#   'StorageType': 'gp2',
#   'DbInstancePort': 0,
#   'StorageEncrypted': True,
#   'KmsKeyId': 'arn:aws-us-gov:kms:us-gov-west-1:008577686731:key/da52fa14-0ee7-4e02-bc43-e09d2e0638c9',
#   'DbiResourceId': 'db-3DRUUQ2PX5PVL5ODOSBX7C43NE',
#   'CACertificateIdentifier': 'rds-ca-2017',
#   'DomainMemberships': [],
#   'CopyTagsToSnapshot': True,
#   'MonitoringInterval': 60,
#   'EnhancedMonitoringResourceArn': 'arn:aws-us-gov:logs:us-gov-west-1:008577686731:log-group:RDSOSMetrics:log-stream:db-3DRUUQ2PX5PVL5ODOSBX7C43NE',
#   'MonitoringRoleArn': 'arn:aws-us-gov:iam::008577686731:role/rds-monitoring-role',
#   'DBInstanceArn': 'arn:aws-us-gov:rds:us-gov-west-1:008577686731:db:dsva-lighthouse-ux-toolkit-db',
#   'IAMDatabaseAuthenticationEnabled': False,
#   'PerformanceInsightsEnabled': False,
#   'DeletionProtection': False,
#   'AssociatedRoles': [],
#   'MaxAllocatedStorage': 1000,
#   'TagList': [{'Key': 'Office', 'Value': 'tbd'},
#    {'Key': 'ProjectName', 'Value': 'VA Vets.gov'},
#    {'Key': 'ResTag', 'Value': 'shared'},
#    {'Key': 'project', 'Value': 'vagov'},
#    {'Key': 'office', 'Value': 'osva'},
#    {'Key': 'Name', 'Value': 'dsva-lighthouse-ux-toolkit-db'},
#    {'Key': 'Role', 'Value': 'tbd'},
#    {'Key': 'VAECID', 'Value': 'AWG20180517003'},
#    {'Key': 'environment', 'Value': 'dev'},
#    {'Key': 'Adminstration', 'Value': 'TBD'},
#    {'Key': 'application', 'Value': 'lighthouse-ux-toolkit'},
#    {'Key': 'provider', 'Value': 'aws'},
#    {'Key': 'managed', 'Value': 'terraform'},
#    {'Key': 'Environment', 'Value': 'DEV'},
#    {'Key': 'region', 'Value': 'govcloud'},
#    {'Key': 'suboffice', 'Value': 'cto'},
#    {'Key': 'ProjectShort', 'Value': 'Vets.gov'},
#    {'Key': 'dsva_version', 'Value': 'v2'},
#    {'Key': 'group', 'Value': 'dsva'}],
#   'CustomerOwnedIpEnabled': False,
#   'BackupTarget': 'region'},
#  {'DBInstanceIdentifier': 'dsva-vagov-dev-platform-console-ui',
#   'DBInstanceClass': 'db.m5.large',
#   'Engine': 'postgres',
#   'DBInstanceStatus': 'available',
#   'MasterUsername': 'platform_console_ui',
#   'DBName': 'platform_console_ui',
#   'Endpoint': {'Address': 'dsva-vagov-dev-platform-console-ui.cdqbofmbcmtd.us-gov-west-1.rds.amazonaws.com',
#    'Port': 5432,
#    'HostedZoneId': 'Z2YROVNTF0QJSQ'},
#   'AllocatedStorage': 100,
#   'InstanceCreateTime': datetime.datetime(2022, 2, 22, 17, 55, 57, 379000, tzinfo=tzutc()),
#   'PreferredBackupWindow': '07:54-08:24',
#   'BackupRetentionPeriod': 7,
#   'DBSecurityGroups': [],
#   'VpcSecurityGroups': [{'VpcSecurityGroupId': 'sg-03627397dd3ecb4de',
#     'Status': 'active'}],
#   'DBParameterGroups': [{'DBParameterGroupName': 'default.postgres13',
#     'ParameterApplyStatus': 'in-sync'}],
#   'AvailabilityZone': 'us-gov-west-1b',
#   'DBSubnetGroup': {'DBSubnetGroupName': 'dsva-vagov-dev-platform-console-ui-rds-sng',
#    'DBSubnetGroupDescription': 'platform-console-ui RDS Subnet group',
#    'VpcId': 'vpc-b50046d0',
#    'SubnetGroupStatus': 'Complete',
#    'Subnets': [{'SubnetIdentifier': 'subnet-8d3dd6e9',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1b'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'},
#     {'SubnetIdentifier': 'subnet-d6f512a0',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1a'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'},
#     {'SubnetIdentifier': 'subnet-2c4e176a',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1c'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'}]},
#   'PreferredMaintenanceWindow': 'thu:08:52-thu:09:22',
#   'PendingModifiedValues': {},
#   'LatestRestorableTime': datetime.datetime(2022, 5, 18, 2, 54, 35, tzinfo=tzutc()),
#   'MultiAZ': False,
#   'EngineVersion': '13.5',
#   'AutoMinorVersionUpgrade': False,
#   'ReadReplicaDBInstanceIdentifiers': [],
#   'LicenseModel': 'postgresql-license',
#   'OptionGroupMemberships': [{'OptionGroupName': 'default:postgres-13',
#     'Status': 'in-sync'}],
#   'PubliclyAccessible': False,
#   'StorageType': 'gp2',
#   'DbInstancePort': 0,
#   'StorageEncrypted': True,
#   'KmsKeyId': 'arn:aws-us-gov:kms:us-gov-west-1:008577686731:key/da52fa14-0ee7-4e02-bc43-e09d2e0638c9',
#   'DbiResourceId': 'db-HVENMNXGHZQWG5LX2IZIIBWPCU',
#   'CACertificateIdentifier': 'rds-ca-2017',
#   'DomainMemberships': [],
#   'CopyTagsToSnapshot': True,
#   'MonitoringInterval': 60,
#   'EnhancedMonitoringResourceArn': 'arn:aws-us-gov:logs:us-gov-west-1:008577686731:log-group:RDSOSMetrics:log-stream:db-HVENMNXGHZQWG5LX2IZIIBWPCU',
#   'MonitoringRoleArn': 'arn:aws-us-gov:iam::008577686731:role/rds-monitoring-role',
#   'DBInstanceArn': 'arn:aws-us-gov:rds:us-gov-west-1:008577686731:db:dsva-vagov-dev-platform-console-ui',
#   'IAMDatabaseAuthenticationEnabled': False,
#   'PerformanceInsightsEnabled': False,
#   'DeletionProtection': False,
#   'AssociatedRoles': [],
#   'MaxAllocatedStorage': 1000,
#   'TagList': [{'Key': 'Office', 'Value': 'tbd'},
#    {'Key': 'ProjectName', 'Value': 'VA Vets.gov'},
#    {'Key': 'ResTag', 'Value': 'shared'},
#    {'Key': 'project', 'Value': 'vagov'},
#    {'Key': 'office', 'Value': 'osva'},
#    {'Key': 'Name', 'Value': 'dsva-vagov-dev-platform-console-ui'},
#    {'Key': 'Role', 'Value': 'tbd'},
#    {'Key': 'VAECID', 'Value': 'AWG20180517003'},
#    {'Key': 'environment', 'Value': 'dev'},
#    {'Key': 'Adminstration', 'Value': 'TBD'},
#    {'Key': 'application', 'Value': 'platform-console-ui'},
#    {'Key': 'provider', 'Value': 'aws'},
#    {'Key': 'managed', 'Value': 'terraform'},
#    {'Key': 'Environment', 'Value': 'DEV'},
#    {'Key': 'region', 'Value': 'govcloud'},
#    {'Key': 'suboffice', 'Value': 'cto'},
#    {'Key': 'ProjectShort', 'Value': 'Vets.gov'},
#    {'Key': 'dsva_version', 'Value': 'v2'},
#    {'Key': 'group', 'Value': 'dsva'}],
#   'CustomerOwnedIpEnabled': False,
#   'BackupTarget': 'region'},
#  {'DBInstanceIdentifier': 'dsva-vagov-grafana-utility',
#   'DBInstanceClass': 'db.t2.small',
#   'Engine': 'postgres',
#   'DBInstanceStatus': 'available',
#   'MasterUsername': 'grafana',
#   'DBName': 'dsva_grafana_utility',
#   'Endpoint': {'Address': 'dsva-vagov-grafana-utility.cdqbofmbcmtd.us-gov-west-1.rds.amazonaws.com',
#    'Port': 5432,
#    'HostedZoneId': 'Z2YROVNTF0QJSQ'},
#   'AllocatedStorage': 10,
#   'InstanceCreateTime': datetime.datetime(2019, 2, 1, 21, 14, 58, 638000, tzinfo=tzutc()),
#   'PreferredBackupWindow': '09:23-09:53',
#   'BackupRetentionPeriod': 7,
#   'DBSecurityGroups': [],
#   'VpcSecurityGroups': [{'VpcSecurityGroupId': 'sg-1a06ef7d',
#     'Status': 'active'}],
#   'DBParameterGroups': [{'DBParameterGroupName': 'default.postgres11',
#     'ParameterApplyStatus': 'in-sync'}],
#   'AvailabilityZone': 'us-gov-west-1b',
#   'DBSubnetGroup': {'DBSubnetGroupName': 'dsva-vagov-utility-grafana-rds-sng',
#    'DBSubnetGroupDescription': 'grafana utility rds subnet group',
#    'VpcId': 'vpc-84a444e0',
#    'SubnetGroupStatus': 'Complete',
#    'Subnets': [{'SubnetIdentifier': 'subnet-e0229496',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1a'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'},
#     {'SubnetIdentifier': 'subnet-7201bd16',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1b'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'}]},
#   'PreferredMaintenanceWindow': 'tue:07:44-tue:08:14',
#   'PendingModifiedValues': {},
#   'LatestRestorableTime': datetime.datetime(2022, 5, 18, 2, 54, 45, tzinfo=tzutc()),
#   'MultiAZ': True,
#   'EngineVersion': '11.13',
#   'AutoMinorVersionUpgrade': True,
#   'ReadReplicaDBInstanceIdentifiers': [],
#   'LicenseModel': 'postgresql-license',
#   'OptionGroupMemberships': [{'OptionGroupName': 'default:postgres-11',
#     'Status': 'in-sync'}],
#   'SecondaryAvailabilityZone': 'us-gov-west-1a',
#   'PubliclyAccessible': False,
#   'StorageType': 'gp2',
#   'DbInstancePort': 0,
#   'StorageEncrypted': False,
#   'DbiResourceId': 'db-XPI4RKLMQBGWO7ZVYSWXZUV3BE',
#   'CACertificateIdentifier': 'rds-ca-2017',
#   'DomainMemberships': [],
#   'CopyTagsToSnapshot': True,
#   'MonitoringInterval': 60,
#   'EnhancedMonitoringResourceArn': 'arn:aws-us-gov:logs:us-gov-west-1:008577686731:log-group:RDSOSMetrics:log-stream:db-XPI4RKLMQBGWO7ZVYSWXZUV3BE',
#   'MonitoringRoleArn': 'arn:aws-us-gov:iam::008577686731:role/rds-monitoring-role',
#   'DBInstanceArn': 'arn:aws-us-gov:rds:us-gov-west-1:008577686731:db:dsva-vagov-grafana-utility',
#   'IAMDatabaseAuthenticationEnabled': False,
#   'PerformanceInsightsEnabled': False,
#   'DeletionProtection': True,
#   'AssociatedRoles': [],
#   'TagList': [{'Key': 'Office', 'Value': 'tbd'},
#    {'Key': 'ProjectName', 'Value': 'VA Vets.gov'},
#    {'Key': 'ResTag', 'Value': 'shared'},
#    {'Key': 'project', 'Value': 'vagov'},
#    {'Key': 'office', 'Value': 'osva'},
#    {'Key': 'Name', 'Value': 'dsva-vagov-grafana-utility'},
#    {'Key': 'Role', 'Value': 'tbd'},
#    {'Key': 'VAECID', 'Value': 'AWG20180517003'},
#    {'Key': 'environment', 'Value': 'utility'},
#    {'Key': 'Adminstration', 'Value': 'TBD'},
#    {'Key': 'application', 'Value': 'grafana'},
#    {'Key': 'provider', 'Value': 'aws'},
#    {'Key': 'managed', 'Value': 'terraform'},
#    {'Key': 'Environment', 'Value': 'DEV'},
#    {'Key': 'region', 'Value': 'govcloud'},
#    {'Key': 'suboffice', 'Value': 'cto'},
#    {'Key': 'ProjectShort', 'Value': 'Vets.gov'},
#    {'Key': 'dsva_version', 'Value': 'v2'},
#    {'Key': 'group', 'Value': 'dsva'}],
#   'CustomerOwnedIpEnabled': False,
#   'BackupTarget': 'region'},
#  {'DBInstanceIdentifier': 'dsva-vagov-keycloak-dev',
#   'DBInstanceClass': 'db.m5.large',
#   'Engine': 'postgres',
#   'DBInstanceStatus': 'available',
#   'MasterUsername': 'keycloak',
#   'DBName': 'keycloak',
#   'Endpoint': {'Address': 'dsva-vagov-keycloak-dev.cdqbofmbcmtd.us-gov-west-1.rds.amazonaws.com',
#    'Port': 5432,
#    'HostedZoneId': 'Z2YROVNTF0QJSQ'},
#   'AllocatedStorage': 100,
#   'InstanceCreateTime': datetime.datetime(2021, 11, 30, 15, 27, 35, 618000, tzinfo=tzutc()),
#   'PreferredBackupWindow': '07:54-08:24',
#   'BackupRetentionPeriod': 7,
#   'DBSecurityGroups': [],
#   'VpcSecurityGroups': [{'VpcSecurityGroupId': 'sg-00734f4482cb11ceb',
#     'Status': 'active'}],
#   'DBParameterGroups': [{'DBParameterGroupName': 'default.postgres12',
#     'ParameterApplyStatus': 'in-sync'}],
#   'AvailabilityZone': 'us-gov-west-1c',
#   'DBSubnetGroup': {'DBSubnetGroupName': 'dsva-vagov-dev-keycloak-rds-sng',
#    'DBSubnetGroupDescription': 'keycloak RDS Subnet group',
#    'VpcId': 'vpc-b50046d0',
#    'SubnetGroupStatus': 'Complete',
#    'Subnets': [{'SubnetIdentifier': 'subnet-8d3dd6e9',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1b'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'},
#     {'SubnetIdentifier': 'subnet-d6f512a0',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1a'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'},
#     {'SubnetIdentifier': 'subnet-2c4e176a',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1c'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'}]},
#   'PreferredMaintenanceWindow': 'thu:08:52-thu:09:22',
#   'PendingModifiedValues': {},
#   'LatestRestorableTime': datetime.datetime(2022, 5, 18, 2, 54, 35, tzinfo=tzutc()),
#   'MultiAZ': False,
#   'EngineVersion': '12.4',
#   'AutoMinorVersionUpgrade': False,
#   'ReadReplicaDBInstanceIdentifiers': [],
#   'LicenseModel': 'postgresql-license',
#   'OptionGroupMemberships': [{'OptionGroupName': 'default:postgres-12',
#     'Status': 'in-sync'}],
#   'PubliclyAccessible': False,
#   'StorageType': 'gp2',
#   'DbInstancePort': 0,
#   'StorageEncrypted': True,
#   'KmsKeyId': 'arn:aws-us-gov:kms:us-gov-west-1:008577686731:key/da52fa14-0ee7-4e02-bc43-e09d2e0638c9',
#   'DbiResourceId': 'db-5FA23NTYFDKSR2G3RTOZ3V3KP4',
#   'CACertificateIdentifier': 'rds-ca-2017',
#   'DomainMemberships': [],
#   'CopyTagsToSnapshot': True,
#   'MonitoringInterval': 60,
#   'EnhancedMonitoringResourceArn': 'arn:aws-us-gov:logs:us-gov-west-1:008577686731:log-group:RDSOSMetrics:log-stream:db-5FA23NTYFDKSR2G3RTOZ3V3KP4',
#   'MonitoringRoleArn': 'arn:aws-us-gov:iam::008577686731:role/rds-monitoring-role',
#   'DBInstanceArn': 'arn:aws-us-gov:rds:us-gov-west-1:008577686731:db:dsva-vagov-keycloak-dev',
#   'IAMDatabaseAuthenticationEnabled': False,
#   'PerformanceInsightsEnabled': False,
#   'DeletionProtection': False,
#   'AssociatedRoles': [],
#   'MaxAllocatedStorage': 1000,
#   'TagList': [{'Key': 'Office', 'Value': 'tbd'},
#    {'Key': 'ProjectName', 'Value': 'VA Vets.gov'},
#    {'Key': 'ResTag', 'Value': 'shared'},
# ...
#   'CopyTagsToSnapshot': True,
#   'MonitoringInterval': 60,
#   'EnhancedMonitoringResourceArn': 'arn:aws-us-gov:logs:us-gov-west-1:008577686731:log-group:RDSOSMetrics:log-stream:db-TZDKP2LGT735YNWTY62CD2TEDQ',
#   'MonitoringRoleArn': 'arn:aws-us-gov:iam::008577686731:role/rds-monitoring-role',
#   'DBInstanceArn': 'arn:aws-us-gov:rds:us-gov-west-1:008577686731:db:dsva-vets-api-dev',
#   'IAMDatabaseAuthenticationEnabled': False,
#   'DeletionProtection': True,
#   'AssociatedRoles': [],
#   'TagList': [{'Key': 'Office', 'Value': 'tbd'},
#    {'Key': 'ProjectName', 'Value': 'VA Vets.gov'},
#    {'Key': 'ResTag', 'Value': 'shared'},
#    {'Key': 'project', 'Value': 'vagov'},
#    {'Key': 'office', 'Value': 'osva'},
#    {'Key': 'Name', 'Value': 'dsva-vagov-dev-vets-api-db'},
#    {'Key': 'Role', 'Value': 'tbd'},
#    {'Key': 'VAECID', 'Value': 'AWG20180517003'},
#    {'Key': 'environment', 'Value': 'dev'},
#    {'Key': 'Adminstration', 'Value': 'TBD'},
#    {'Key': 'application', 'Value': 'vets-api'},
#    {'Key': 'provider', 'Value': 'aws'},
#    {'Key': 'managed', 'Value': 'terraform'},
#    {'Key': 'Environment', 'Value': 'DEV'},
#    {'Key': 'region', 'Value': 'govcloud'},
#    {'Key': 'suboffice', 'Value': 'cto'},
#    {'Key': 'ProjectShort', 'Value': 'Vets.gov'},
#    {'Key': 'dsva_version', 'Value': 'v2'},
#    {'Key': 'group', 'Value': 'dsva'}],
#   'CustomerOwnedIpEnabled': False,
#   'BackupTarget': 'region'},
#  {'DBInstanceIdentifier': 'dsva-vets-api-dev-sample',
#   'DBInstanceClass': 'db.m4.xlarge',
#   'Engine': 'postgres',
#   'DBInstanceStatus': 'available',
#   'MasterUsername': 'vets_api',
#   'DBName': 'dsva_vets_api_dev',
#   'Endpoint': {'Address': 'dsva-vets-api-dev-sample.cdqbofmbcmtd.us-gov-west-1.rds.amazonaws.com',
#    'Port': 5432,
#    'HostedZoneId': 'Z2YROVNTF0QJSQ'},
#   'AllocatedStorage': 10,
#   'InstanceCreateTime': datetime.datetime(2021, 12, 21, 16, 28, 57, 285000, tzinfo=tzutc()),
#   'PreferredBackupWindow': '08:45-09:15',
#   'BackupRetentionPeriod': 7,
#   'DBSecurityGroups': [],
#   'VpcSecurityGroups': [{'VpcSecurityGroupId': 'sg-d33fe7b7',
#     'Status': 'active'},
#    {'VpcSecurityGroupId': 'sg-0aba386d', 'Status': 'active'}],
#   'DBParameterGroups': [{'DBParameterGroupName': 'default.postgres11',
#     'ParameterApplyStatus': 'in-sync'}],
#   'AvailabilityZone': 'us-gov-west-1b',
#   'DBSubnetGroup': {'DBSubnetGroupName': 'dsva-vagov-dev-vets-api-db-sng',
#    'DBSubnetGroupDescription': 'vets-api-worker dsva-vagov-dev rds db subnet group',
#    'VpcId': 'vpc-b50046d0',
#    'SubnetGroupStatus': 'Complete',
#    'Subnets': [{'SubnetIdentifier': 'subnet-8d3dd6e9',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1b'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'},
#     {'SubnetIdentifier': 'subnet-d6f512a0',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1a'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'},
#     {'SubnetIdentifier': 'subnet-2c4e176a',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1c'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'}]},
#   'PreferredMaintenanceWindow': 'thu:10:21-thu:10:51',
#   'PendingModifiedValues': {},
#   'LatestRestorableTime': datetime.datetime(2022, 5, 18, 2, 54, 40, tzinfo=tzutc()),
#   'MultiAZ': False,
#   'EngineVersion': '11.8',
#   'AutoMinorVersionUpgrade': False,
#   'ReadReplicaDBInstanceIdentifiers': [],
#   'LicenseModel': 'postgresql-license',
#   'OptionGroupMemberships': [{'OptionGroupName': 'default:postgres-11',
#     'Status': 'in-sync'}],
#   'PubliclyAccessible': False,
#   'StorageType': 'standard',
#   'DbInstancePort': 0,
#   'StorageEncrypted': False,
#   'DbiResourceId': 'db-NRTCFX7OTMQRZHVAJFFKN3H74Q',
#   'CACertificateIdentifier': 'rds-ca-2017',
#   'DomainMemberships': [],
#   'CopyTagsToSnapshot': True,
#   'MonitoringInterval': 0,
#   'DBInstanceArn': 'arn:aws-us-gov:rds:us-gov-west-1:008577686731:db:dsva-vets-api-dev-sample',
#   'IAMDatabaseAuthenticationEnabled': False,
#   'PerformanceInsightsEnabled': False,
#   'EnabledCloudwatchLogsExports': ['postgresql'],
#   'DeletionProtection': False,
#   'AssociatedRoles': [],
#   'TagList': [{'Key': 'Office', 'Value': 'tbd'},
#    {'Key': 'ProjectName', 'Value': 'VA Vets.gov'},
#    {'Key': 'ResTag', 'Value': 'shared'},
#    {'Key': 'project', 'Value': 'vagov'},
#    {'Key': 'office', 'Value': 'osva'},
#    {'Key': 'Name', 'Value': 'dsva-vagov-dev-vets-api-db'},
#    {'Key': 'Role', 'Value': 'tbd'},
#    {'Key': 'VAECID', 'Value': 'AWG20180517003'},
#    {'Key': 'environment', 'Value': 'dev'},
#    {'Key': 'Adminstration', 'Value': 'TBD'},
#    {'Key': 'application', 'Value': 'vets-api'},
#    {'Key': 'provider', 'Value': 'aws'},
#    {'Key': 'managed', 'Value': 'terraform'},
#    {'Key': 'Environment', 'Value': 'DEV'},
#    {'Key': 'region', 'Value': 'govcloud'},
#    {'Key': 'suboffice', 'Value': 'cto'},
#    {'Key': 'ProjectShort', 'Value': 'Vets.gov'},
#    {'Key': 'dsva_version', 'Value': 'v2'},
#    {'Key': 'group', 'Value': 'dsva'}],
#   'CustomerOwnedIpEnabled': False,
#   'BackupTarget': 'region'},
#  {'DBInstanceIdentifier': 'dsva-vets-api-prod-2',
#   'DBInstanceClass': 'db.m5.xlarge',
#   'Engine': 'postgres',
#   'DBInstanceStatus': 'available',
#   'MasterUsername': 'vets_api',
#   'DBName': 'dsva_vets_api_prod',
#   'Endpoint': {'Address': 'dsva-vets-api-prod-2.cdqbofmbcmtd.us-gov-west-1.rds.amazonaws.com',
#    'Port': 5432,
#    'HostedZoneId': 'Z2YROVNTF0QJSQ'},
#   'AllocatedStorage': 200,
#   'InstanceCreateTime': datetime.datetime(2021, 1, 13, 20, 45, 8, 619000, tzinfo=tzutc()),
#   'PreferredBackupWindow': '10:11-10:41',
#   'BackupRetentionPeriod': 7,
#   'DBSecurityGroups': [],
#   'VpcSecurityGroups': [{'VpcSecurityGroupId': 'sg-d37c5db5',
#     'Status': 'active'}],
#   'DBParameterGroups': [{'DBParameterGroupName': 'vets-api-prod-param-grp',
#     'ParameterApplyStatus': 'in-sync'}],
#   'AvailabilityZone': 'us-gov-west-1b',
#   'DBSubnetGroup': {'DBSubnetGroupName': 'dsva-vagov-prod-vets-api-db-sng',
#    'DBSubnetGroupDescription': 'vets-api-worker dsva-vagov-prod rds db subnet group',
#    'VpcId': 'vpc-d50f49b0',
#    'SubnetGroupStatus': 'Complete',
#    'Subnets': [{'SubnetIdentifier': 'subnet-a433d8c0',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1b'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'},
#     {'SubnetIdentifier': 'subnet-66411820',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1c'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'},
#     {'SubnetIdentifier': 'subnet-f3f31485',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1a'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'}]},
#   'PreferredMaintenanceWindow': 'mon:06:49-mon:07:19',
#   'PendingModifiedValues': {},
#   'LatestRestorableTime': datetime.datetime(2022, 5, 18, 2, 57, 34, tzinfo=tzutc()),
#   'MultiAZ': True,
#   'EngineVersion': '11.8',
#   'AutoMinorVersionUpgrade': False,
#   'ReadReplicaDBInstanceIdentifiers': [],
#   'LicenseModel': 'postgresql-license',
#   'Iops': 1000,
#   'OptionGroupMemberships': [{'OptionGroupName': 'default:postgres-11',
#     'Status': 'in-sync'}],
#   'SecondaryAvailabilityZone': 'us-gov-west-1c',
#   'PubliclyAccessible': False,
#   'StorageType': 'io1',
#   'DbInstancePort': 0,
#   'StorageEncrypted': True,
#   'KmsKeyId': 'arn:aws-us-gov:kms:us-gov-west-1:008577686731:key/e1c06d52-10b8-419c-985c-e4d61c940289',
#   'DbiResourceId': 'db-5UUFXLN7375L2NG7PKSU5N3STY',
#   'CACertificateIdentifier': 'rds-ca-2017',
#   'DomainMemberships': [],
#   'CopyTagsToSnapshot': True,
#   'MonitoringInterval': 60,
#   'EnhancedMonitoringResourceArn': 'arn:aws-us-gov:logs:us-gov-west-1:008577686731:log-group:RDSOSMetrics:log-stream:db-5UUFXLN7375L2NG7PKSU5N3STY',
#   'MonitoringRoleArn': 'arn:aws-us-gov:iam::008577686731:role/rds-monitoring-role',
#   'DBInstanceArn': 'arn:aws-us-gov:rds:us-gov-west-1:008577686731:db:dsva-vets-api-prod-2',
#   'IAMDatabaseAuthenticationEnabled': False,
#   'PerformanceInsightsEnabled': False,
#   'DeletionProtection': True,
#   'AssociatedRoles': [],
#   'TagList': [{'Key': 'Office', 'Value': 'tbd'},
#    {'Key': 'ProjectName', 'Value': 'VA Vets.gov'},
#    {'Key': 'ResTag', 'Value': 'shared'},
#    {'Key': 'project', 'Value': 'vagov'},
#    {'Key': 'office', 'Value': 'osva'},
#    {'Key': 'Name', 'Value': 'dsva-vagov-prod-vets-api-db'},
#    {'Key': 'Role', 'Value': 'tbd'},
#    {'Key': 'VAECID', 'Value': 'AWG20180517003'},
#    {'Key': 'environment', 'Value': 'prod'},
#    {'Key': 'Adminstration', 'Value': 'TBD'},
#    {'Key': 'application', 'Value': 'vets-api'},
#    {'Key': 'provider', 'Value': 'aws'},
#    {'Key': 'managed', 'Value': 'terraform'},
#    {'Key': 'Environment', 'Value': 'PROD'},
#    {'Key': 'region', 'Value': 'govcloud'},
#    {'Key': 'suboffice', 'Value': 'cto'},
#    {'Key': 'ProjectShort', 'Value': 'Vets.gov'},
#    {'Key': 'dsva_version', 'Value': 'v2'},
#    {'Key': 'group', 'Value': 'dsva'}],
#   'CustomerOwnedIpEnabled': False,
#   'BackupTarget': 'region'},
#  {'DBInstanceIdentifier': 'dsva-vets-api-sandbox',
#   'DBInstanceClass': 'db.m3.large',
#   'Engine': 'postgres',
#   'DBInstanceStatus': 'available',
#   'MasterUsername': 'vets_api',
#   'DBName': 'dsva_vets_api_sandbox',
#   'Endpoint': {'Address': 'dsva-vets-api-sandbox.cdqbofmbcmtd.us-gov-west-1.rds.amazonaws.com',
#    'Port': 5432,
#    'HostedZoneId': 'Z2YROVNTF0QJSQ'},
#   'AllocatedStorage': 10,
#   'InstanceCreateTime': datetime.datetime(2019, 9, 6, 19, 43, 36, 338000, tzinfo=tzutc()),
#   'PreferredBackupWindow': '08:45-09:15',
#   'BackupRetentionPeriod': 7,
#   'DBSecurityGroups': [],
#   'VpcSecurityGroups': [{'VpcSecurityGroupId': 'sg-4122d127',
#     'Status': 'active'}],
#   'DBParameterGroups': [{'DBParameterGroupName': 'vets-api-sandbox-param-grp',
#     'ParameterApplyStatus': 'in-sync'}],
#   'AvailabilityZone': 'us-gov-west-1b',
#   'DBSubnetGroup': {'DBSubnetGroupName': 'dsva-vagov-sandbox-vets-api-db-sng',
#    'DBSubnetGroupDescription': 'vets-api-worker dsva-vagov-sandbox rds db subnet group',
#    'VpcId': 'vpc-959d26f1',
#    'SubnetGroupStatus': 'Complete',
#    'Subnets': [{'SubnetIdentifier': 'subnet-fcdb9f8a',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1a'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'},
#     {'SubnetIdentifier': 'subnet-982b6cfc',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1b'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'}]},
#   'PreferredMaintenanceWindow': 'thu:10:21-thu:10:51',
#   'PendingModifiedValues': {},
#   'LatestRestorableTime': datetime.datetime(2022, 5, 18, 2, 55, 11, tzinfo=tzutc()),
#   'MultiAZ': True,
#   'EngineVersion': '11.8',
#   'AutoMinorVersionUpgrade': False,
#   'ReadReplicaDBInstanceIdentifiers': [],
#   'LicenseModel': 'postgresql-license',
#   'OptionGroupMemberships': [{'OptionGroupName': 'default:postgres-11',
#     'Status': 'in-sync'}],
#   'SecondaryAvailabilityZone': 'us-gov-west-1a',
#   'PubliclyAccessible': False,
#   'StorageType': 'standard',
#   'DbInstancePort': 0,
#   'StorageEncrypted': False,
#   'DbiResourceId': 'db-V3Z2AJADUTKCJTPM66B2ZDZGQU',
#   'CACertificateIdentifier': 'rds-ca-2017',
#   'DomainMemberships': [],
#   'CopyTagsToSnapshot': True,
#   'MonitoringInterval': 60,
#   'EnhancedMonitoringResourceArn': 'arn:aws-us-gov:logs:us-gov-west-1:008577686731:log-group:RDSOSMetrics:log-stream:db-V3Z2AJADUTKCJTPM66B2ZDZGQU',
#   'MonitoringRoleArn': 'arn:aws-us-gov:iam::008577686731:role/rds-monitoring-role',
#   'DBInstanceArn': 'arn:aws-us-gov:rds:us-gov-west-1:008577686731:db:dsva-vets-api-sandbox',
#   'IAMDatabaseAuthenticationEnabled': False,
#   'PerformanceInsightsEnabled': False,
#   'DeletionProtection': True,
#   'AssociatedRoles': [],
#   'TagList': [{'Key': 'Office', 'Value': 'tbd'},
#    {'Key': 'ProjectName', 'Value': 'VA Vets.gov'},
#    {'Key': 'ResTag', 'Value': 'shared'},
#    {'Key': 'project', 'Value': 'vagov'},
#    {'Key': 'office', 'Value': 'osva'},
#    {'Key': 'Name', 'Value': 'dsva-vagov-sandbox-vets-api-db'},
#    {'Key': 'Role', 'Value': 'tbd'},
#    {'Key': 'VAECID', 'Value': 'AWG20180517003'},
#    {'Key': 'environment', 'Value': 'sandbox'},
#    {'Key': 'Adminstration', 'Value': 'TBD'},
#    {'Key': 'application', 'Value': 'vets-api'},
#    {'Key': 'provider', 'Value': 'aws'},
#    {'Key': 'managed', 'Value': 'terraform'},
#    {'Key': 'Environment', 'Value': 'SANDBOX'},
#    {'Key': 'region', 'Value': 'govcloud'},
#    {'Key': 'suboffice', 'Value': 'cto'},
#    {'Key': 'ProjectShort', 'Value': 'Vets.gov'},
#    {'Key': 'dsva_version', 'Value': 'v2'},
#    {'Key': 'group', 'Value': 'dsva'}],
#   'CustomerOwnedIpEnabled': False,
#   'BackupTarget': 'region'},
#  {'DBInstanceIdentifier': 'dsva-vets-api-staging',
#   'DBInstanceClass': 'db.m3.large',
#   'Engine': 'postgres',
#   'DBInstanceStatus': 'available',
#   'MasterUsername': 'vets_api',
#   'DBName': 'dsva_vets_api_staging',
#   'Endpoint': {'Address': 'dsva-vets-api-staging.cdqbofmbcmtd.us-gov-west-1.rds.amazonaws.com',
#    'Port': 5432,
#    'HostedZoneId': 'Z2YROVNTF0QJSQ'},
#   'AllocatedStorage': 10,
#   'InstanceCreateTime': datetime.datetime(2017, 8, 16, 2, 1, 7, 791000, tzinfo=tzutc()),
#   'PreferredBackupWindow': '10:41-11:11',
#   'BackupRetentionPeriod': 7,
#   'DBSecurityGroups': [],
#   'VpcSecurityGroups': [{'VpcSecurityGroupId': 'sg-32aef654',
#     'Status': 'active'}],
#   'DBParameterGroups': [{'DBParameterGroupName': 'vets-api-staging-param-grp',
#     'ParameterApplyStatus': 'in-sync'}],
#   'AvailabilityZone': 'us-gov-west-1b',
#   'DBSubnetGroup': {'DBSubnetGroupName': 'dsva-vagov-staging-vets-api-db-sng',
#    'DBSubnetGroupDescription': 'vets-api-worker dsva-vagov-staging rds db subnet group',
#    'VpcId': 'vpc-840147e1',
#    'SubnetGroupStatus': 'Complete',
#    'Subnets': [{'SubnetIdentifier': 'subnet-70f51206',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1a'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'},
#     {'SubnetIdentifier': 'subnet-b84e17fe',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1c'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'},
#     {'SubnetIdentifier': 'subnet-cc3cd7a8',
#      'SubnetAvailabilityZone': {'Name': 'us-gov-west-1b'},
#      'SubnetOutpost': {},
#      'SubnetStatus': 'Active'}]},
#   'PreferredMaintenanceWindow': 'tue:12:46-tue:13:16',
#   'PendingModifiedValues': {},
#   'LatestRestorableTime': datetime.datetime(2022, 5, 18, 2, 55, 9, tzinfo=tzutc()),
#   'MultiAZ': True,
#   'EngineVersion': '11.8',
#   'AutoMinorVersionUpgrade': False,
#   'ReadReplicaDBInstanceIdentifiers': [],
#   'LicenseModel': 'postgresql-license',
#   'OptionGroupMemberships': [{'OptionGroupName': 'default:postgres-11',
#     'Status': 'in-sync'}],
#   'SecondaryAvailabilityZone': 'us-gov-west-1a',
#   'PubliclyAccessible': False,
#   'StorageType': 'standard',
#   'DbInstancePort': 0,
#   'StorageEncrypted': False,
#   'DbiResourceId': 'db-NS3DFURQPAF5A5BPNAHO2S3GRY',
#   'CACertificateIdentifier': 'rds-ca-2017',
#   'DomainMemberships': [],
#   'CopyTagsToSnapshot': True,
#   'MonitoringInterval': 60,
#   'EnhancedMonitoringResourceArn': 'arn:aws-us-gov:logs:us-gov-west-1:008577686731:log-group:RDSOSMetrics:log-stream:db-NS3DFURQPAF5A5BPNAHO2S3GRY',
#   'MonitoringRoleArn': 'arn:aws-us-gov:iam::008577686731:role/rds-monitoring-role',
#   'DBInstanceArn': 'arn:aws-us-gov:rds:us-gov-west-1:008577686731:db:dsva-vets-api-staging',
#   'IAMDatabaseAuthenticationEnabled': False,
#   'PerformanceInsightsEnabled': False,
#   'DeletionProtection': True,
#   'AssociatedRoles': [],
#   'TagList': [{'Key': 'Office', 'Value': 'tbd'},
#    {'Key': 'ProjectName', 'Value': 'vagov'},
#    {'Key': 'ResTag', 'Value': 'shared'},
#    {'Key': 'project', 'Value': 'vagov'},
#    {'Key': 'office', 'Value': 'osva'},
#    {'Key': 'Name', 'Value': 'dsva-vagov-staging-vets-api-db'},
#    {'Key': 'Role', 'Value': 'tbd'},
#    {'Key': 'VAECID', 'Value': 'AWG20180517003'},
#    {'Key': 'environment', 'Value': 'staging'},
#    {'Key': 'Adminstration', 'Value': 'VBA'},
#    {'Key': 'application', 'Value': 'vets-api'},
#    {'Key': 'provider', 'Value': 'aws'},
#    {'Key': 'managed', 'Value': 'terraform'},
#    {'Key': 'Environment', 'Value': 'STAGING'},
#    {'Key': 'region', 'Value': 'govcloud'},
#    {'Key': 'suboffice', 'Value': 'cto'},
#    {'Key': 'ProjectShort', 'Value': 'Vets.gov'},
#    {'Key': 'dsva_version', 'Value': 'v2'},
#    {'Key': 'group', 'Value': 'dsva'}],
#   'CustomerOwnedIpEnabled': False,
#   'BackupTarget': 'region'}]

# %%
get_rds_info = []

for item in get_only_the_vpc_in_vpc_list:
    db_instance_identifier = item.get("DBInstanceIdentifier")
    engine = item.get("Engine")
    db_name = item.get("DBName")
    port = item.get("Endpoint").get("Port")
    vpc_id = item.get("DBSubnetGroup").get("VpcId")
    rds_sg = item.get("VpcSecurityGroups")

    rds_sg_id = []

    for row in rds_sg:
        rds_sg_id.append(row.get("VpcSecurityGroupId"))

    get_rds_info.append([db_instance_identifier, engine, db_name, port, vpc_id, rds_sg_id])

# %%
len(get_rds_info)
# Out:
# 26

# %%
get_rds_info
# Out:
# [['dsva-cms-dev-db',
#   'mariadb',
#   'dsva_cms_dev',
#   3306,
#   'vpc-b50046d0',
#   ['sg-4b466d2c']],
#  ['dsva-cms-prod-db',
#   'mariadb',
#   'dsva_cms_prod',
#   3306,
#   'vpc-d50f49b0',
#   ['sg-b38bb3d4']],
#  ['dsva-cms-staging-db',
#   'mariadb',
#   'dsva_cms_staging',
#   3306,
#   'vpc-840147e1',
#   ['sg-d690a8b1']],
#  ['dsva-cms-test-dev-db',
#   'mariadb',
#   'dsva_cms_dev',
#   3306,
#   'vpc-b50046d0',
#   ['sg-e8df7b91']],
#  ['dsva-cms-test-prod-db',
#   'mariadb',
#   'dsva_cms_prod',
#   3306,
#   'vpc-d50f49b0',
#   ['sg-64db7f1d']],
#  ['dsva-cms-test-staging-db',
#   'mariadb',
#   'dsva_cms_staging',
#   3306,
#   'vpc-840147e1',
#   ['sg-aaa501d3']],
#  ['dsva-gi-bill-data-service-dev',
#   'postgres',
#   'dsva_gids_dev',
#   5432,
#   'vpc-b50046d0',
#   ['sg-bd2702db']],
#  ['dsva-gi-bill-data-service-prod',
#   'postgres',
#   'dsva_gids_prod',
#   5432,
#   'vpc-d50f49b0',
#   ['sg-df7c5db9']],
#  ['dsva-gi-bill-data-service-staging',
#   'postgres',
#   'dsva_gids_staging',
#   5432,
#   'vpc-840147e1',
#   ['sg-ba2b0edc']],
#  ['dsva-lighthouse-ux-toolkit-db',
#   'postgres',
#   'ux_toolkit',
#   5432,
#   'vpc-b50046d0',
#   ['sg-04921927dc74e3cb6']],
#  ['dsva-vagov-dev-platform-console-ui',
#   'postgres',
#   'platform_console_ui',
#   5432,
#   'vpc-b50046d0',
#   ['sg-03627397dd3ecb4de']],
#  ['dsva-vagov-grafana-utility',
#   'postgres',
#   'dsva_grafana_utility',
#   5432,
#   'vpc-84a444e0',
#   ['sg-1a06ef7d']],
#  ['dsva-vagov-keycloak-dev',
#   'postgres',
#   'keycloak',
#   5432,
#   'vpc-b50046d0',
#   ['sg-00734f4482cb11ceb']],
#  ['dsva-vagov-keycloak-next-dev',
#   'postgres',
#   'keycloak',
#   5432,
#   'vpc-b50046d0',
#   ['sg-00734f4482cb11ceb']],
#  ['dsva-vagov-keycloak-utility',
#   'postgres',
#   'keycloak',
#   5432,
#   'vpc-84a444e0',
#   ['sg-0376c9d13bf948630']],
#  ['dsva-vagov-sentry',
#   'postgres',
#   'sentry',
#   5432,
#   'vpc-84a444e0',
#   ['sg-04f859724325f1f78']],
#  ['dsva-vagov-sentry-test',
#   'postgres',
#   'sentry',
#   5432,
#   'vpc-84a444e0',
#   ['sg-04f859724325f1f78']],
#  ['dsva-vagov-staging-platform-console-ui',
#   'postgres',
#   'platform_console_ui',
#   5432,
#   'vpc-840147e1',
#   ['sg-03ca43c3cab84a3c4']],
#  ['dsva-vagov-utility-pact-broker',
#   'postgres',
#   'pactdb',
#   5432,
#   'vpc-84a444e0',
#   ['sg-0953fde0772143261']],
#  ['dsva-vagov-utility-platform-console-api',
#   'postgres',
#   'platform_console_api',
#   5432,
#   'vpc-84a444e0',
#   ['sg-09f3d24216bba51c9']],
#  ['dsva-vagov-utility-platform-console-ui',
#   'postgres',
#   'platform_console_ui',
#   5432,
#   'vpc-84a444e0',
#   ['sg-0f447c3dfa1127aa3']],
#  ['dsva-vets-api-dev',
#   'postgres',
#   'dsva_vets_api_dev',
#   5432,
#   'vpc-b50046d0',
#   ['sg-7aaef61c']],
#  ['dsva-vets-api-dev-sample',
#   'postgres',
#   'dsva_vets_api_dev',
#   5432,
#   'vpc-b50046d0',
#   ['sg-d33fe7b7', 'sg-0aba386d']],
#  ['dsva-vets-api-prod-2',
#   'postgres',
#   'dsva_vets_api_prod',
#   5432,
#   'vpc-d50f49b0',
#   ['sg-d37c5db5']],
#  ['dsva-vets-api-sandbox',
#   'postgres',
#   'dsva_vets_api_sandbox',
#   5432,
#   'vpc-959d26f1',
#   ['sg-4122d127']],
#  ['dsva-vets-api-staging',
#   'postgres',
#   'dsva_vets_api_staging',
#   5432,
#   'vpc-840147e1',
#   ['sg-32aef654']]]

# %%
security_group_list = []

for item in get_rds_info:
    security_group_of_the_item = item[5]

    # append() adds one element to the list at a time
    # extend() method is used to append one list to another list
    # extend() adds multiple items to the list at a time
    security_group_list.extend(security_group_of_the_item)

# %%
security_group_list
# Out:
# ['sg-4b466d2c',
#  'sg-b38bb3d4',
#  'sg-d690a8b1',
#  'sg-e8df7b91',
#  'sg-64db7f1d',
#  'sg-aaa501d3',
#  'sg-bd2702db',
#  'sg-df7c5db9',
#  'sg-ba2b0edc',
#  'sg-04921927dc74e3cb6',
#  'sg-03627397dd3ecb4de',
#  'sg-1a06ef7d',
#  'sg-00734f4482cb11ceb',
#  'sg-00734f4482cb11ceb',
#  'sg-0376c9d13bf948630',
#  'sg-04f859724325f1f78',
#  'sg-04f859724325f1f78',
#  'sg-03ca43c3cab84a3c4',
#  'sg-0953fde0772143261',
#  'sg-09f3d24216bba51c9',
#  'sg-0f447c3dfa1127aa3',
#  'sg-7aaef61c',
#  'sg-d33fe7b7',
#  'sg-0aba386d',
#  'sg-d37c5db5',
#  'sg-4122d127',
#  'sg-32aef654']

# %%
# remove_duplicate_rds_sg_id = []

# for item in security_group_list:
#     if item not in remove_duplicate_rds_sg_id:
#         remove_duplicate_rds_sg_id.append(item)

# %%
describe_security_groups_response = ec2_client.describe_security_groups(
    Filters=[
        {
            "Name": "group-id",
            "Values": security_group_list,
        }
    ]
)

# %%
get_security_groups = describe_security_groups_response.get("SecurityGroups")

# %%
get_security_groups
# Out:
# [{'Description': 'Security group that controls access to the Keycloak RDS Database',
#   'GroupName': 'dsva-vagov-dev-keycloak-db-sg',
#   'IpPermissions': [{'FromPort': 5432,
#     'IpProtocol': 'tcp',
#     'IpRanges': [],
#     'Ipv6Ranges': [],
#     'PrefixListIds': [],
#     'ToPort': 5432,
#     'UserIdGroupPairs': [{'Description': 'Ingress to DB',
#       'GroupId': 'sg-0a313736ce4b5605b',
#       'UserId': '008577686731'}]}],
#   'OwnerId': '008577686731',
#   'GroupId': 'sg-00734f4482cb11ceb',
#   'IpPermissionsEgress': [{'IpProtocol': '-1',
#     'IpRanges': [{'CidrIp': '10.0.0.0/8'}],
#     'Ipv6Ranges': [],
#     'PrefixListIds': [],
#     'UserIdGroupPairs': []}],
#   'VpcId': 'vpc-b50046d0'},
#  {'Description': 'Security group that controls access to the platform-console-ui dev database',
#   'GroupName': 'dsva-vagov-dev-platform-console-ui-db-sg',
#   'IpPermissions': [{'FromPort': 5432,
#     'IpProtocol': 'tcp',
#     'IpRanges': [],
#     'Ipv6Ranges': [],
#     'PrefixListIds': [],
#     'ToPort': 5432,
#     'UserIdGroupPairs': [{'Description': 'Ingress to DB',
#       'GroupId': 'sg-0a313736ce4b5605b',
#       'UserId': '008577686731'}]}],
#   'OwnerId': '008577686731',
#   'GroupId': 'sg-03627397dd3ecb4de',
#   'IpPermissionsEgress': [{'IpProtocol': '-1',
#     'IpRanges': [{'CidrIp': '10.0.0.0/8'}],
#     'Ipv6Ranges': [],
#     'PrefixListIds': [],
#     'UserIdGroupPairs': []}],
#   'VpcId': 'vpc-b50046d0'},
#  {'Description': 'Security group that controls access to the Keycloak RDS Database',
#   'GroupName': 'dsva-vagov-utility-keycloak-db-sg',
#   'IpPermissions': [{'FromPort': 5432,
#     'IpProtocol': 'tcp',
#     'IpRanges': [],
#     'Ipv6Ranges': [],
#     'PrefixListIds': [],
#     'ToPort': 5432,
#     'UserIdGroupPairs': [{'Description': 'Ingress to DB',
#       'GroupId': 'sg-00796fb1ab3c050d9',
#       'UserId': '008577686731'}]}],
#   'OwnerId': '008577686731',
#   'GroupId': 'sg-0376c9d13bf948630',
#   'IpPermissionsEgress': [{'IpProtocol': '-1',
#     'IpRanges': [{'CidrIp': '10.0.0.0/8'}],
#     'Ipv6Ranges': [],
#     'PrefixListIds': [],
#     'UserIdGroupPairs': []}],
#   'VpcId': 'vpc-84a444e0'},
#  {'Description': 'Security group that controls access to the platform-console-ui staging database',
#   'GroupName': 'dsva-vagov-staging-platform-console-ui-db-sg',
#   'IpPermissions': [{'FromPort': 5432,
#     'IpProtocol': 'tcp',
#     'IpRanges': [],
#     'Ipv6Ranges': [],
#     'PrefixListIds': [],
#     'ToPort': 5432,
#     'UserIdGroupPairs': [{'Description': 'Ingress to DB',
#       'GroupId': 'sg-0445bbedb795a237d',
#       'UserId': '008577686731'}]}],
#   'OwnerId': '008577686731',
#   'GroupId': 'sg-03ca43c3cab84a3c4',
#   'IpPermissionsEgress': [{'IpProtocol': '-1',
#     'IpRanges': [{'CidrIp': '10.0.0.0/8'}],
#     'Ipv6Ranges': [],
#     'PrefixListIds': [],
#     'UserIdGroupPairs': []}],
#   'VpcId': 'vpc-840147e1'},
#  {'Description': 'Security group that controls access to the Lighthouse UX Toolkit RDS Database',
#   'GroupName': 'dsva-vagov-dev-lut-db-sg',
#   'IpPermissions': [{'FromPort': 5432,
#     'IpProtocol': 'tcp',
#     'IpRanges': [],
#     'Ipv6Ranges': [],
#     'PrefixListIds': [],
#     'ToPort': 5432,
#     'UserIdGroupPairs': [{'Description': 'Ingress to DB',
#       'GroupId': 'sg-0a313736ce4b5605b',
#       'UserId': '008577686731'}]},
#    {'FromPort': 6379,
#     'IpProtocol': 'tcp',
#     'IpRanges': [],
#     'Ipv6Ranges': [],
#     'PrefixListIds': [],
#     'ToPort': 6379,
#     'UserIdGroupPairs': [{'Description': 'Ingress to redis',
#       'GroupId': 'sg-0a313736ce4b5605b',
#       'UserId': '008577686731'}]}],
#   'OwnerId': '008577686731',
#   'GroupId': 'sg-04921927dc74e3cb6',
#   'IpPermissionsEgress': [{'IpProtocol': '-1',
#     'IpRanges': [{'CidrIp': '10.0.0.0/8'}],
#     'Ipv6Ranges': [],
#     'PrefixListIds': [],
#     'UserIdGroupPairs': []}],
#   'VpcId': 'vpc-b50046d0'},
#  {'Description': 'Managed by Terraform',
#   'GroupName': 'dsva-vagov-sentry-rds-sg',
#   'IpPermissions': [{'FromPort': 5432,
#     'IpProtocol': 'tcp',
#     'IpRanges': [],
#     'Ipv6Ranges': [],
#     'PrefixListIds': [],
#     'ToPort': 5432,
#     'UserIdGroupPairs': [{'GroupId': 'sg-00796fb1ab3c050d9',
#       'UserId': '008577686731'}]}],
#   'OwnerId': '008577686731',
#   'GroupId': 'sg-04f859724325f1f78',
#   'IpPermissionsEgress': [{'IpProtocol': '-1',
#     'IpRanges': [{'CidrIp': '0.0.0.0/0'}],
#     'Ipv6Ranges': [],
#     'PrefixListIds': [],
#     'UserIdGroupPairs': []}],
#   'Tags': [{'Key': 'project', 'Value': 'vagov'},
#    {'Key': 'suboffice', 'Value': 'cto'},
#    {'Key': 'dsva_version', 'Value': 'v2'},
#    {'Key': 'ProjectName', 'Value': 'VA Vets.gov'},
#    {'Key': 'application', 'Value': 'sentry'},
#    {'Key': 'environment', 'Value': 'utility'},
#    {'Key': 'ProjectShort', 'Value': 'Vets.gov'},
#    {'Key': 'Name', 'Value': 'dsva-vagov-sentry-rds-sg'},
#    {'Key': 'ResTag', 'Value': 'shared'},
#    {'Key': 'Role', 'Value': 'tbd'},
#    {'Key': 'region', 'Value': 'govcloud'},
#    {'Key': 'managed', 'Value': 'terraform'},
#    {'Key': 'group', 'Value': 'dsva'},
#    {'Key': 'provider', 'Value': 'aws'},
#    {'Key': 'Environment', 'Value': 'UTILITY'},
#    {'Key': 'VAECID', 'Value': 'AWG20180517003'},
#    {'Key': 'office', 'Value': 'osva'},
#    {'Key': 'Adminstration', 'Value': 'TBD'},
#    {'Key': 'Office', 'Value': 'tbd'}],
#   'VpcId': 'vpc-84a444e0'},
#  {'Description': 'Managed by Terraform',
#   'GroupName': 'dsva-vagov-utility-pact-broker',
#   'IpPermissions': [{'FromPort': 5432,
#     'IpProtocol': 'tcp',
#     'IpRanges': [{'CidrIp': '10.0.0.0/8'}],
#     'Ipv6Ranges': [],
#     'PrefixListIds': [],
#     'ToPort': 5432,
#     'UserIdGroupPairs': [{'GroupId': 'sg-07098e8a86c4c4d43',
#       'UserId': '008577686731'}]}],
#   'OwnerId': '008577686731',
#   'GroupId': 'sg-0953fde0772143261',
#   'IpPermissionsEgress': [{'IpProtocol': '-1',
#     'IpRanges': [{'CidrIp': '10.0.0.0/8'}],
#     'Ipv6Ranges': [],
#     'PrefixListIds': [],
#     'UserIdGroupPairs': []}],
#   'Tags': [{'Key': 'VAECID', 'Value': 'AWG20180517003'},
#    {'Key': 'office', 'Value': 'osva'},
#    {'Key': 'ResTag', 'Value': 'shared'},
#    {'Key': 'group', 'Value': 'dsva'},
#    {'Key': 'provider', 'Value': 'aws'},
#    {'Key': 'project', 'Value': 'vagov'},
#    {'Key': 'Environment', 'Value': 'DEV'},
#    {'Key': 'Role', 'Value': 'tbd'},
#    {'Key': 'region', 'Value': 'govcloud'},
#    {'Key': 'suboffice', 'Value': 'cto'},
#    {'Key': 'dsva_version', 'Value': 'v2'},
#    {'Key': 'environment', 'Value': 'utility'},
#    {'Key': 'managed', 'Value': 'terraform'},
#    {'Key': 'ProjectShort', 'Value': 'Vets.gov'},
#    {'Key': 'Adminstration', 'Value': 'TBD'},
#    {'Key': 'Office', 'Value': 'tbd'},
#    {'Key': 'ProjectName', 'Value': 'VA Vets.gov'}],
#   'VpcId': 'vpc-84a444e0'},
#  {'Description': 'Security group that controls access to the platform-console-api utility database',
#   'GroupName': 'dsva-vagov-utility-platform-console-api-db-sg',
#   'IpPermissions': [{'FromPort': 5432,
#     'IpProtocol': 'tcp',
#     'IpRanges': [],
#     'Ipv6Ranges': [],
#     'PrefixListIds': [],
#     'ToPort': 5432,
#     'UserIdGroupPairs': [{'Description': 'Ingress to DB',
#       'GroupId': 'sg-00796fb1ab3c050d9',
#       'UserId': '008577686731'}]}],
#   'OwnerId': '008577686731',
#   'GroupId': 'sg-09f3d24216bba51c9',
#   'IpPermissionsEgress': [{'IpProtocol': '-1',
#     'IpRanges': [{'CidrIp': '10.0.0.0/8'}],
#     'Ipv6Ranges': [],
#     'PrefixListIds': [],
#     'UserIdGroupPairs': []}],
#   'VpcId': 'vpc-84a444e0'},
#  {'Description': 'allow http traffic from ELB in dev',
#   'GroupName': 'dsva-vagov-dev-vets-api-server-sg',
#   'IpPermissions': [{'FromPort': 3004,
#     'IpProtocol': 'tcp',
#     'IpRanges': [],
#     'Ipv6Ranges': [],
#     'PrefixListIds': [],
#     'ToPort': 3004,
#     'UserIdGroupPairs': [{'GroupId': 'sg-9eaa28f9',
#       'UserId': '008577686731'}]}],
#   'OwnerId': '008577686731',
#   'GroupId': 'sg-0aba386d',
#   'IpPermissionsEgress': [{'IpProtocol': '-1',
#     'IpRanges': [{'CidrIp': '0.0.0.0/0'}],
#     'Ipv6Ranges': [],
#     'PrefixListIds': [],
#     'UserIdGroupPairs': []}],
#   'Tags': [{'Key': 'environment', 'Value': 'dev'},
#    {'Key': 'VAECID', 'Value': 'AWG20180517003'},
#    {'Key': 'Adminstration', 'Value': 'TBD'},
#    {'Key': 'Name', 'Value': 'dsva-vagov-dev-vets-api-server-sg'},
#    {'Key': 'ProjectShort', 'Value': 'Vets.gov'},
#    {'Key': 'Office', 'Value': 'tbd'},
#    {'Key': 'dsva_version', 'Value': 'v2'},
#    {'Key': 'suboffice', 'Value': 'cto'},
#    {'Key': 'project', 'Value': 'vagov'},
#    {'Key': 'ProjectName', 'Value': 'VA Vets.gov'},
#    {'Key': 'region', 'Value': 'govcloud'},
#    {'Key': 'ResTag', 'Value': 'shared'},
#    {'Key': 'Role', 'Value': 'tbd'},
#    {'Key': 'managed', 'Value': 'terraform'},
#    {'Key': 'Environment', 'Value': 'DEV'},
#    {'Key': 'office', 'Value': 'osva'},
#    {'Key': 'group', 'Value': 'dsva'},
#    {'Key': 'provider', 'Value': 'aws'}],
#   'VpcId': 'vpc-b50046d0'},
#  {'Description': 'Security group that controls access to the platform-console-ui utility database',
#   'GroupName': 'dsva-vagov-utility-platform-console-ui-db-sg',
#   'IpPermissions': [{'FromPort': 5432,
#     'IpProtocol': 'tcp',
#     'IpRanges': [],
#     'Ipv6Ranges': [],
#     'PrefixListIds': [],
#     'ToPort': 5432,
#     'UserIdGroupPairs': [{'Description': 'Ingress to DB',
#       'GroupId': 'sg-00796fb1ab3c050d9',
#       'UserId': '008577686731'}]}],
#   'OwnerId': '008577686731',
#   'GroupId': 'sg-0f447c3dfa1127aa3',
#   'IpPermissionsEgress': [{'IpProtocol': '-1',
#     'IpRanges': [{'CidrIp': '10.0.0.0/8'}],
#     'Ipv6Ranges': [],
#     'PrefixListIds': [],
#     'UserIdGroupPairs': []}],
#   'VpcId': 'vpc-84a444e0'},
#  {'Description': 'Managed by Terraform',
#   'GroupName': 'dsva-vagov-utility-grafana-rds-sg',
#   'IpPermissions': [{'FromPort': 5432,
#     'IpProtocol': 'tcp',
#     'IpRanges': [],
#     'Ipv6Ranges': [],
#     'PrefixListIds': [],
#     'ToPort': 5432,
#     'UserIdGroupPairs': [{'GroupId': 'sg-4e1ff629', 'UserId': '008577686731'},
#      {'GroupId': 'sg-0e5fb169f8783e50c', 'UserId': '008577686731'},
#      {'GroupId': 'sg-00796fb1ab3c050d9', 'UserId': '008577686731'}]}],
#   'OwnerId': '008577686731',
#   'GroupId': 'sg-1a06ef7d',
#   'IpPermissionsEgress': [{'IpProtocol': '-1',
#     'IpRanges': [{'CidrIp': '0.0.0.0/0'}],
#     'Ipv6Ranges': [],
#     'PrefixListIds': [],
#     'UserIdGroupPairs': []}],
#   'Tags': [{'Key': 'region', 'Value': 'govcloud'},
#    {'Key': 'Office', 'Value': 'tbd'},
#    {'Key': 'application', 'Value': 'grafana'},
#    {'Key': 'managed', 'Value': 'terraform'},
#    {'Key': 'Adminstration', 'Value': 'TBD'},
#    {'Key': 'office', 'Value': 'osva'},
#    {'Key': 'VAECID', 'Value': 'AWG20180517003'},
#    {'Key': 'environment', 'Value': 'utility'},
#    {'Key': 'dsva_version', 'Value': 'v2'},
#    {'Key': 'suboffice', 'Value': 'cto'},
#    {'Key': 'ResTag', 'Value': 'shared'},
#    {'Key': 'ProjectShort', 'Value': 'Vets.gov'},
#    {'Key': 'Environment', 'Value': 'DEV'},
#    {'Key': 'Name', 'Value': 'dsva-vagov-utility-grafana-rds-sg'},
#    {'Key': 'Role', 'Value': 'tbd'},
#    {'Key': 'project', 'Value': 'vagov'},
#    {'Key': 'group', 'Value': 'dsva'},
#    {'Key': 'provider', 'Value': 'aws'},
#    {'Key': 'ProjectName', 'Value': 'VA Vets.gov'}],
#   'VpcId': 'vpc-84a444e0'},
#  {'Description': 'vets-api dsva-vagov-staging rds db security group',
#   'GroupName': 'dsva-vagov-staging-vets-api-db-sg',
#   'IpPermissions': [{'FromPort': 0,
#     'IpProtocol': 'tcp',
#     'IpRanges': [],
#     'Ipv6Ranges': [],
#     'PrefixListIds': [],
#     'ToPort': 65535,
#     'UserIdGroupPairs': [{'Description': 'Self-Referencing SG Rule for AWS Glue',
#       'GroupId': 'sg-32aef654',
#       'UserId': '008577686731'}]},
#    {'FromPort': 5432,
#     'IpProtocol': 'tcp',
#     'IpRanges': [],
#     'Ipv6Ranges': [],
#     'PrefixListIds': [],
#     'ToPort': 5432,
#     'UserIdGroupPairs': [{'GroupId': 'sg-4c5bd12b', 'UserId': '008577686731'},
#      {'GroupId': 'sg-c648c2a1', 'UserId': '008577686731'},
#      {'GroupId': 'sg-0445bbedb795a237d', 'UserId': '008577686731'}]}],
#   'OwnerId': '008577686731',
#   'GroupId': 'sg-32aef654',
#   'IpPermissionsEgress': [{'IpProtocol': '-1',
#     'IpRanges': [{'CidrIp': '0.0.0.0/0'}],
#     'Ipv6Ranges': [],
#     'PrefixListIds': [],
#     'UserIdGroupPairs': []}],
#   'Tags': [{'Key': 'project', 'Value': 'vagov'},
#    {'Key': 'suboffice', 'Value': 'cto'},
#    {'Key': 'Environment', 'Value': 'STAGING'},
#    {'Key': 'Office', 'Value': 'tbd'},
#    {'Key': 'ProjectShort', 'Value': 'Vets.gov'},
#    {'Key': 'dsva_version', 'Value': 'v2'},
#    {'Key': 'Adminstration', 'Value': 'VBA'},
#    {'Key': 'environment', 'Value': 'staging'},
#    {'Key': 'Name', 'Value': 'dsva-vagov-staging-vets-api-db-sg'},
#    {'Key': 'ProjectName', 'Value': 'vagov'},
#    {'Key': 'VAECID', 'Value': 'AWG20180517003'},
#    {'Key': 'application', 'Value': 'vets-api-worker'},
#    {'Key': 'ResTag', 'Value': 'shared'},
#    {'Key': 'managed', 'Value': 'terraform'},
#    {'Key': 'group', 'Value': 'dsva'},
#    {'Key': 'Role', 'Value': 'tbd'},
#    {'Key': 'region', 'Value': 'govcloud'},
#    {'Key': 'provider', 'Value': 'aws'},
#    {'Key': 'office', 'Value': 'osva'}],
#   'VpcId': 'vpc-840147e1'},
#  {'Description': 'vets-api dsva-vagov-sandbox rds db security group',
#   'GroupName': 'dsva-vagov-sandbox-vets-api-db-sg',
#   'IpPermissions': [{'FromPort': 0,
#     'IpProtocol': 'tcp',
#     'IpRanges': [],
#     'Ipv6Ranges': [],
#     'PrefixListIds': [],
#     'ToPort': 65535,
#     'UserIdGroupPairs': [{'Description': 'Self-Referencing SG Rule for AWS Glue',
#       'GroupId': 'sg-4122d127',
#       'UserId': '008577686731'}]},
#    {'FromPort': 5432,
#     'IpProtocol': 'tcp',
#     'IpRanges': [],
#     'Ipv6Ranges': [],
#     'PrefixListIds': [],
#     'ToPort': 5432,
#     'UserIdGroupPairs': [{'GroupId': 'sg-ab7869cc', 'UserId': '008577686731'},
#      {'GroupId': 'sg-e3677684', 'UserId': '008577686731'},
#      {'GroupId': 'sg-0662bdce806b3ce2a', 'UserId': '008577686731'}]}],
#   'OwnerId': '008577686731',
#   'GroupId': 'sg-4122d127',
#   'IpPermissionsEgress': [{'IpProtocol': '-1',
#     'IpRanges': [{'CidrIp': '0.0.0.0/0'}],
#     'Ipv6Ranges': [],
#     'PrefixListIds': [],
#     'UserIdGroupPairs': []}],
#   'Tags': [{'Key': 'project', 'Value': 'vagov'},
#    {'Key': 'suboffice', 'Value': 'cto'},
#    {'Key': 'Environment', 'Value': 'SANDBOX'},
#    {'Key': 'ProjectName', 'Value': 'VA Vets.gov'},
#    {'Key': 'dsva_version', 'Value': 'v2'},
#    {'Key': 'provider', 'Value': 'aws'},
#    {'Key': 'Name', 'Value': 'dsva-vagov-sandbox-vets-api-db-sg'},
#    {'Key': 'ResTag', 'Value': 'shared'},
#    {'Key': 'managed', 'Value': 'terraform'},
#    {'Key': 'application', 'Value': 'vets-api-worker'},
#    {'Key': 'VAECID', 'Value': 'AWG20180517003'},
#    {'Key': 'environment', 'Value': 'sandbox'},
#    {'Key': 'office', 'Value': 'osva'},
#    {'Key': 'Office', 'Value': 'tbd'},
#    {'Key': 'group', 'Value': 'dsva'},
#    {'Key': 'region', 'Value': 'govcloud'},
#    {'Key': 'Role', 'Value': 'tbd'},
#    {'Key': 'Adminstration', 'Value': 'TBD'},
#    {'Key': 'ProjectShort', 'Value': 'Vets.gov'}],
#   'VpcId': 'vpc-959d26f1'},
#  {'Description': 'cms rds security group in dev',
#   'GroupName': 'dsva-vagov-dev-cms-rds-sg',
#   'IpPermissions': [{'FromPort': 3306,
#     'IpProtocol': 'tcp',
#     'IpRanges': [],
#     'Ipv6Ranges': [],
#     'PrefixListIds': [],
#     'ToPort': 3306,
#     'UserIdGroupPairs': [{'GroupId': 'sg-fcb69f9b', 'UserId': '008577686731'},
#      {'GroupId': 'sg-7068ee15',
#       'PeeringStatus': 'active',
#       'UserId': '008577686731',
#       'VpcId': 'vpc-0978b06c',
#       'VpcPeeringConnectionId': 'pcx-3a2d5053'},
#      {'GroupId': 'sg-2e91e648',
#       'PeeringStatus': 'active',
#       'UserId': '008577686731',
#       'VpcId': 'vpc-0978b06c',
#       'VpcPeeringConnectionId': 'pcx-3a2d5053'}]}],
#   'OwnerId': '008577686731',
#   'GroupId': 'sg-4b466d2c',
#   'IpPermissionsEgress': [],
#   'Tags': [{'Key': 'office', 'Value': 'osva'},
#    {'Key': 'group', 'Value': 'dsva'},
#    {'Key': 'region', 'Value': 'govcloud'},
#    {'Key': 'Adminstration', 'Value': 'TBD'},
#    {'Key': 'Environment', 'Value': 'DEV'},
#    {'Key': 'Role', 'Value': 'tbd'},
#    {'Key': 'ProjectShort', 'Value': 'Vets.gov'},
#    {'Key': 'Name', 'Value': 'dsva-vagov-dev-cms-rds-sg'},
#    {'Key': 'VAECID', 'Value': 'AWG20180517003'},
#    {'Key': 'environment', 'Value': 'dev'},
#    {'Key': 'project', 'Value': 'vagov'},
#    {'Key': 'suboffice', 'Value': 'cto'},
#    {'Key': 'provider', 'Value': 'aws'},
#    {'Key': 'dsva_version', 'Value': 'v2'},
#    {'Key': 'managed', 'Value': 'terraform'},
#    {'Key': 'Office', 'Value': 'tbd'},
#    {'Key': 'ResTag', 'Value': 'shared'},
#    {'Key': 'application', 'Value': 'cms'},
#    {'Key': 'ProjectName', 'Value': 'VA Vets.gov'}],
#   'VpcId': 'vpc-b50046d0'},
#  {'Description': 'cms-test rds security group in prod',
#   'GroupName': 'dsva-vagov-prod-cms-test-rds-sg',
#   'IpPermissions': [{'FromPort': 3306,
#     'IpProtocol': 'tcp',
#     'IpRanges': [],
#     'Ipv6Ranges': [],
#     'PrefixListIds': [],
#     'ToPort': 3306,
#     'UserIdGroupPairs': [{'GroupId': 'sg-084ee9269b2d6065c',
#       'UserId': '008577686731'},
#      {'GroupId': 'sg-2e91e648',
#       'PeeringStatus': 'active',
#       'UserId': '008577686731',
#       'VpcId': 'vpc-0978b06c',
#       'VpcPeeringConnectionId': 'pcx-2382fd4a'},
#      {'GroupId': 'sg-7068ee15',
#       'PeeringStatus': 'active',
#       'UserId': '008577686731',
#       'VpcId': 'vpc-0978b06c',
#       'VpcPeeringConnectionId': 'pcx-2382fd4a'}]}],
#   'OwnerId': '008577686731',
#   'GroupId': 'sg-64db7f1d',
#   'IpPermissionsEgress': [],
#   'Tags': [{'Key': 'office', 'Value': 'osva'},
#    {'Key': 'VAECID', 'Value': 'AWG20180517003'},
#    {'Key': 'application', 'Value': 'cms-test'},
#    {'Key': 'Adminstration', 'Value': 'TBD'},
#    {'Key': 'Office', 'Value': 'tbd'},
#    {'Key': 'region', 'Value': 'govcloud'},
#    {'Key': 'Name', 'Value': 'dsva-vagov-prod-cms-test-rds-sg'},
#    {'Key': 'ResTag', 'Value': 'shared'},
#    {'Key': 'Environment', 'Value': 'PROD'},
#    {'Key': 'managed', 'Value': 'terraform'},
#    {'Key': 'dsva_version', 'Value': 'v2'},
#    {'Key': 'ProjectShort', 'Value': 'Vets.gov'},
#    {'Key': 'suboffice', 'Value': 'cto'},
#    {'Key': 'ProjectName', 'Value': 'VA Vets.gov'},
#    {'Key': 'environment', 'Value': 'prod'},
#    {'Key': 'project', 'Value': 'vagov'},
#    {'Key': 'provider', 'Value': 'aws'},
#    {'Key': 'group', 'Value': 'dsva'},
#    {'Key': 'Role', 'Value': 'tbd'}],
#   'VpcId': 'vpc-d50f49b0'},
#  {'Description': 'vets-api dsva-vagov-dev rds db security group',
#   'GroupName': 'dsva-vagov-dev-vets-api-db-sg',
#   'IpPermissions': [{'FromPort': 0,
#     'IpProtocol': 'tcp',
#     'IpRanges': [],
#     'Ipv6Ranges': [],
#     'PrefixListIds': [],
#     'ToPort': 65535,
#     'UserIdGroupPairs': [{'Description': 'Self-Referencing SG Rule for AWS Glue',
#       'GroupId': 'sg-7aaef61c',
#       'UserId': '008577686731'}]},
#    {'FromPort': 5432,
#     'IpProtocol': 'tcp',
#     'IpRanges': [],
#     'Ipv6Ranges': [],
#     'PrefixListIds': [],
#     'ToPort': 5432,
#     'UserIdGroupPairs': [{'GroupId': 'sg-0aba386d', 'UserId': '008577686731'},
#      {'GroupId': 'sg-f3bc3e94', 'UserId': '008577686731'},
#      {'GroupId': 'sg-0a313736ce4b5605b', 'UserId': '008577686731'}]}],
#   'OwnerId': '008577686731',
#   'GroupId': 'sg-7aaef61c',
#   'IpPermissionsEgress': [{'IpProtocol': '-1',
#     'IpRanges': [{'CidrIp': '0.0.0.0/0'}],
#     'Ipv6Ranges': [],
#     'PrefixListIds': [],
#     'UserIdGroupPairs': []}],
#   'Tags': [{'Key': 'Environment', 'Value': 'DEV'},
#    {'Key': 'Role', 'Value': 'tbd'},
#    {'Key': 'group', 'Value': 'dsva'},
#    {'Key': 'ResTag', 'Value': 'shared'},
#    {'Key': 'office', 'Value': 'osva'},
#    {'Key': 'Office', 'Value': 'tbd'},
#    {'Key': 'ProjectName', 'Value': 'VA Vets.gov'},
#    {'Key': 'application', 'Value': 'vets-api-worker'},
#    {'Key': 'Name', 'Value': 'dsva-vagov-dev-vets-api-db-sg'},
#    {'Key': 'managed', 'Value': 'terraform'},
#    {'Key': 'Adminstration', 'Value': 'TBD'},
#    {'Key': 'dsva_version', 'Value': 'v2'},
#    {'Key': 'suboffice', 'Value': 'cto'},
#    {'Key': 'provider', 'Value': 'aws'},
#    {'Key': 'ProjectShort', 'Value': 'Vets.gov'},
#    {'Key': 'project', 'Value': 'vagov'},
#    {'Key': 'region', 'Value': 'govcloud'},
#    {'Key': 'environment', 'Value': 'dev'},
#    {'Key': 'VAECID', 'Value': 'AWG20180517003'}],
#   'VpcId': 'vpc-b50046d0'},
#  {'Description': 'cms-test rds security group in staging',
#   'GroupName': 'dsva-vagov-staging-cms-test-rds-sg',
#   'IpPermissions': [{'FromPort': 3306,
#     'IpProtocol': 'tcp',
#     'IpRanges': [],
#     'Ipv6Ranges': [],
#     'PrefixListIds': [],
#     'ToPort': 3306,
#     'UserIdGroupPairs': [{'GroupId': 'sg-08514f043cbe92cdd',
#       'UserId': '008577686731'},
#      {'GroupId': 'sg-2e91e648',
#       'PeeringStatus': 'active',
#       'UserId': '008577686731',
#       'VpcId': 'vpc-0978b06c',
#       'VpcPeeringConnectionId': 'pcx-e782fd8e'},
#      {'GroupId': 'sg-7068ee15',
#       'PeeringStatus': 'active',
#       'UserId': '008577686731',
#       'VpcId': 'vpc-0978b06c',
#       'VpcPeeringConnectionId': 'pcx-e782fd8e'}]}],
#   'OwnerId': '008577686731',
#   'GroupId': 'sg-aaa501d3',
#   'IpPermissionsEgress': [],
#   'Tags': [{'Key': 'Adminstration', 'Value': 'VBA'},
#    {'Key': 'region', 'Value': 'govcloud'},
#    {'Key': 'Office', 'Value': 'tbd'},
#    {'Key': 'managed', 'Value': 'terraform'},
#    {'Key': 'environment', 'Value': 'staging'},
#    {'Key': 'office', 'Value': 'osva'},
#    {'Key': 'Environment', 'Value': 'STAGING'},
#    {'Key': 'VAECID', 'Value': 'AWG20180517003'},
#    {'Key': 'application', 'Value': 'cms-test'},
#    {'Key': 'ProjectName', 'Value': 'vagov'},
#    {'Key': 'ProjectShort', 'Value': 'Vets.gov'},
#    {'Key': 'provider', 'Value': 'aws'},
#    {'Key': 'ResTag', 'Value': 'shared'},
#    {'Key': 'Role', 'Value': 'tbd'},
#    {'Key': 'project', 'Value': 'vagov'},
#    {'Key': 'dsva_version', 'Value': 'v2'},
#    {'Key': 'group', 'Value': 'dsva'},
#    {'Key': 'suboffice', 'Value': 'cto'},
#    {'Key': 'Name', 'Value': 'dsva-vagov-staging-cms-test-rds-sg'}],
#   'VpcId': 'vpc-840147e1'},
#  {'Description': 'cms rds security group in prod',
#   'GroupName': 'dsva-vagov-prod-cms-rds-sg',
#   'IpPermissions': [{'FromPort': 3306,
#     'IpProtocol': 'tcp',
#     'IpRanges': [],
#     'Ipv6Ranges': [],
#     'PrefixListIds': [],
#     'ToPort': 3306,
#     'UserIdGroupPairs': [{'GroupId': 'sg-1c8fb77b', 'UserId': '008577686731'},
#      {'GroupId': 'sg-7068ee15',
#       'PeeringStatus': 'active',
#       'UserId': '008577686731',
#       'VpcId': 'vpc-0978b06c',
#       'VpcPeeringConnectionId': 'pcx-2382fd4a'},
#      {'GroupId': 'sg-2e91e648',
#       'PeeringStatus': 'active',
#       'UserId': '008577686731',
#       'VpcId': 'vpc-0978b06c',
#       'VpcPeeringConnectionId': 'pcx-2382fd4a'}]}],
#   'OwnerId': '008577686731',
#   'GroupId': 'sg-b38bb3d4',
#   'IpPermissionsEgress': [],
#   'Tags': [{'Key': 'managed', 'Value': 'terraform'},
#    {'Key': 'environment', 'Value': 'prod'},
#    {'Key': 'region', 'Value': 'govcloud'},
#    {'Key': 'Office', 'Value': 'tbd'},
#    {'Key': 'project', 'Value': 'vagov'},
#    {'Key': 'ProjectName', 'Value': 'VA Vets.gov'},
#    {'Key': 'office', 'Value': 'osva'},
#    {'Key': 'Name', 'Value': 'dsva-vagov-prod-cms-rds-sg'},
#    {'Key': 'Environment', 'Value': 'PROD'},
#    {'Key': 'application', 'Value': 'cms'},
#    {'Key': 'ResTag', 'Value': 'shared'},
#    {'Key': 'Role', 'Value': 'tbd'},
#    {'Key': 'group', 'Value': 'dsva'},
#    {'Key': 'provider', 'Value': 'aws'},
#    {'Key': 'VAECID', 'Value': 'AWG20180517003'},
#    {'Key': 'suboffice', 'Value': 'cto'},
#    {'Key': 'dsva_version', 'Value': 'v2'},
#    {'Key': 'ProjectShort', 'Value': 'Vets.gov'},
#    {'Key': 'Adminstration', 'Value': 'TBD'}],
#   'VpcId': 'vpc-d50f49b0'},
#  {'Description': 'gids dsva-vagov-staging rds db security group',
#   'GroupName': 'dsva-vagov-staging-gids-db-sg',
#   'IpPermissions': [{'FromPort': 0,
#     'IpProtocol': 'tcp',
#     'IpRanges': [],
#     'Ipv6Ranges': [],
#     'PrefixListIds': [],
#     'ToPort': 65535,
#     'UserIdGroupPairs': [{'Description': 'Self-Referencing SG Rule for AWS Glue',
#       'GroupId': 'sg-ba2b0edc',
#       'UserId': '008577686731'}]},
#    {'FromPort': 5432,
#     'IpProtocol': 'tcp',
#     'IpRanges': [],
#     'Ipv6Ranges': [],
#     'PrefixListIds': [],
#     'ToPort': 5432,
#     'UserIdGroupPairs': [{'GroupId': 'sg-75198c12', 'UserId': '008577686731'},
#      {'GroupId': 'sg-0445bbedb795a237d', 'UserId': '008577686731'}]}],
#   'OwnerId': '008577686731',
#   'GroupId': 'sg-ba2b0edc',
#   'IpPermissionsEgress': [{'IpProtocol': '-1',
#     'IpRanges': [{'CidrIp': '0.0.0.0/0'}],
#     'Ipv6Ranges': [],
#     'PrefixListIds': [],
#     'UserIdGroupPairs': []}],
#   'Tags': [{'Key': 'VAECID', 'Value': 'AWG20180517003'},
#    {'Key': 'office', 'Value': 'osva'},
#    {'Key': 'environment', 'Value': 'staging'},
#    {'Key': 'ProjectName', 'Value': 'vagov'},
#    {'Key': 'Name', 'Value': 'dsva-vagov-staging-gids-db-sg'},
#    {'Key': 'Office', 'Value': 'tbd'},
#    {'Key': 'application', 'Value': 'gi-bill-data-service'},
#    {'Key': 'Adminstration', 'Value': 'VBA'},
#    {'Key': 'project', 'Value': 'vagov'},
#    {'Key': 'suboffice', 'Value': 'cto'},
#    {'Key': 'Environment', 'Value': 'STAGING'},
#    {'Key': 'dsva_version', 'Value': 'v2'},
#    {'Key': 'ProjectShort', 'Value': 'Vets.gov'},
#    {'Key': 'ResTag', 'Value': 'shared'},
#    {'Key': 'Role', 'Value': 'tbd'},
#    {'Key': 'region', 'Value': 'govcloud'},
#    {'Key': 'managed', 'Value': 'terraform'},
#    {'Key': 'group', 'Value': 'dsva'},
#    {'Key': 'provider', 'Value': 'aws'}],
#   'VpcId': 'vpc-840147e1'},
#  {'Description': 'gids dsva-vagov-dev rds db security group',
#   'GroupName': 'dsva-vagov-dev-gids-db-sg',
#   'IpPermissions': [{'FromPort': 0,
#     'IpProtocol': 'tcp',
#     'IpRanges': [],
#     'Ipv6Ranges': [],
#     'PrefixListIds': [],
#     'ToPort': 65535,
#     'UserIdGroupPairs': [{'Description': 'Self-Referencing SG Rule for AWS Glue',
#       'GroupId': 'sg-bd2702db',
#       'UserId': '008577686731'}]},
#    {'FromPort': 5432,
#     'IpProtocol': 'tcp',
#     'IpRanges': [],
#     'Ipv6Ranges': [],
#     'PrefixListIds': [],
#     'ToPort': 5432,
#     'UserIdGroupPairs': [{'GroupId': 'sg-c85bd1af', 'UserId': '008577686731'},
#      {'GroupId': 'sg-0a313736ce4b5605b', 'UserId': '008577686731'}]}],
#   'OwnerId': '008577686731',
#   'GroupId': 'sg-bd2702db',
#   'IpPermissionsEgress': [{'IpProtocol': '-1',
#     'IpRanges': [{'CidrIp': '0.0.0.0/0'}],
#     'Ipv6Ranges': [],
#     'PrefixListIds': [],
#     'UserIdGroupPairs': []}],
#   'Tags': [{'Key': 'project', 'Value': 'vagov'},
#    {'Key': 'dsva_version', 'Value': 'v2'},
#    {'Key': 'provider', 'Value': 'aws'},
#    {'Key': 'suboffice', 'Value': 'cto'},
#    {'Key': 'Adminstration', 'Value': 'TBD'},
#    {'Key': 'region', 'Value': 'govcloud'},
#    {'Key': 'ProjectShort', 'Value': 'Vets.gov'},
#    {'Key': 'Role', 'Value': 'tbd'},
#    {'Key': 'Environment', 'Value': 'DEV'},
#    {'Key': 'VAECID', 'Value': 'AWG20180517003'},
#    {'Key': 'environment', 'Value': 'dev'},
#    {'Key': 'application', 'Value': 'gi-bill-data-service'},
#    {'Key': 'group', 'Value': 'dsva'},
#    {'Key': 'office', 'Value': 'osva'},
#    {'Key': 'Name', 'Value': 'dsva-vagov-dev-gids-db-sg'},
#    {'Key': 'Office', 'Value': 'tbd'},
#    {'Key': 'ResTag', 'Value': 'shared'},
#    {'Key': 'managed', 'Value': 'terraform'},
#    {'Key': 'ProjectName', 'Value': 'VA Vets.gov'}],
#   'VpcId': 'vpc-b50046d0'},
#  {'Description': 'default VPC security group',
#   'GroupName': 'default',
#   'IpPermissions': [],
#   'OwnerId': '008577686731',
#   'GroupId': 'sg-d33fe7b7',
#   'IpPermissionsEgress': [],
#   'Tags': [{'Key': 'group', 'Value': 'dsva'},
#    {'Key': 'ResTag', 'Value': 'shared'},
#    {'Key': 'Role', 'Value': 'tbd'},
#    {'Key': 'Environment', 'Value': 'DEV'},
#    {'Key': 'office', 'Value': 'osva'},
#    {'Key': 'ProjectName', 'Value': 'VA Vets.gov'},
#    {'Key': 'Office', 'Value': 'tbd'},
#    {'Key': 'managed', 'Value': 'terraform'},
#    {'Key': 'Adminstration', 'Value': 'TBD'},
#    {'Key': 'region', 'Value': 'govcloud'},
#    {'Key': 'suboffice', 'Value': 'cto'},
#    {'Key': 'dsva_version', 'Value': 'v2'},
#    {'Key': 'provider', 'Value': 'aws'},
#    {'Key': 'ProjectShort', 'Value': 'Vets.gov'},
#    {'Key': 'project', 'Value': 'vagov'},
#    {'Key': 'Name', 'Value': 'dsva-vagov-dev-default'},
#    {'Key': 'environment', 'Value': 'dev'},
#    {'Key': 'VAECID', 'Value': 'AWG20180517003'}],
#   'VpcId': 'vpc-b50046d0'},
#  {'Description': 'vets-api dsva-vagov-prod rds db security group',
#   'GroupName': 'dsva-vagov-prod-vets-api-db-sg',
#   'IpPermissions': [{'FromPort': 0,
#     'IpProtocol': 'tcp',
#     'IpRanges': [],
#     'Ipv6Ranges': [],
#     'PrefixListIds': [],
#     'ToPort': 65535,
#     'UserIdGroupPairs': [{'Description': 'Self-Referencing SG Rule for AWS Glue',
#       'GroupId': 'sg-d37c5db5',
#       'UserId': '008577686731'}]},
#    {'FromPort': 5432,
#     'IpProtocol': 'tcp',
#     'IpRanges': [],
#     'Ipv6Ranges': [],
#     'PrefixListIds': [],
#     'ToPort': 5432,
#     'UserIdGroupPairs': [{'GroupId': 'sg-9964f0fe', 'UserId': '008577686731'},
#      {'GroupId': 'sg-c24bdfa5', 'UserId': '008577686731'},
#      {'GroupId': 'sg-0db0d50ee56222f9f', 'UserId': '008577686731'}]}],
#   'OwnerId': '008577686731',
#   'GroupId': 'sg-d37c5db5',
#   'IpPermissionsEgress': [{'IpProtocol': '-1',
#     'IpRanges': [{'CidrIp': '0.0.0.0/0'}],
#     'Ipv6Ranges': [],
#     'PrefixListIds': [],
#     'UserIdGroupPairs': []}],
#   'Tags': [{'Key': 'ProjectShort', 'Value': 'Vets.gov'},
#    {'Key': 'Environment', 'Value': 'PROD'},
#    {'Key': 'dsva_version', 'Value': 'v2'},
#    {'Key': 'ProjectName', 'Value': 'VA Vets.gov'},
#    {'Key': 'Role', 'Value': 'tbd'},
#    {'Key': 'provider', 'Value': 'aws'},
#    {'Key': 'group', 'Value': 'dsva'},
#    {'Key': 'project', 'Value': 'vagov'},
#    {'Key': 'environment', 'Value': 'prod'},
#    {'Key': 'managed', 'Value': 'terraform'},
#    {'Key': 'ResTag', 'Value': 'shared'},
#    {'Key': 'Name', 'Value': 'dsva-vagov-prod-vets-api-db-sg'},
#    {'Key': 'application', 'Value': 'vets-api-worker'},
#    {'Key': 'Office', 'Value': 'tbd'},
#    {'Key': 'Adminstration', 'Value': 'TBD'},
#    {'Key': 'office', 'Value': 'osva'},
#    {'Key': 'region', 'Value': 'govcloud'},
#    {'Key': 'suboffice', 'Value': 'cto'},
#    {'Key': 'VAECID', 'Value': 'AWG20180517003'}],
#   'VpcId': 'vpc-d50f49b0'},
#  {'Description': 'cms rds security group in staging',
#   'GroupName': 'dsva-vagov-staging-cms-rds-sg',
#   'IpPermissions': [{'FromPort': 3306,
#     'IpProtocol': 'tcp',
#     'IpRanges': [],
#     'Ipv6Ranges': [],
#     'PrefixListIds': [],
#     'ToPort': 3306,
#     'UserIdGroupPairs': [{'GroupId': 'sg-2297af45', 'UserId': '008577686731'},
#      {'GroupId': 'sg-7068ee15',
#       'PeeringStatus': 'active',
#       'UserId': '008577686731',
#       'VpcId': 'vpc-0978b06c',
#       'VpcPeeringConnectionId': 'pcx-e782fd8e'},
#      {'GroupId': 'sg-2e91e648',
#       'PeeringStatus': 'active',
#       'UserId': '008577686731',
#       'VpcId': 'vpc-0978b06c',
#       'VpcPeeringConnectionId': 'pcx-e782fd8e'}]}],
#   'OwnerId': '008577686731',
#   'GroupId': 'sg-d690a8b1',
#   'IpPermissionsEgress': [],
#   'Tags': [{'Key': 'environment', 'Value': 'staging'},
#    {'Key': 'office', 'Value': 'osva'},
#    {'Key': 'group', 'Value': 'dsva'},
#    {'Key': 'Adminstration', 'Value': 'VBA'},
#    {'Key': 'region', 'Value': 'govcloud'},
#    {'Key': 'Name', 'Value': 'dsva-vagov-staging-cms-rds-sg'},
#    {'Key': 'ProjectShort', 'Value': 'Vets.gov'},
#    {'Key': 'Role', 'Value': 'tbd'},
#    {'Key': 'ProjectName', 'Value': 'vagov'},
#    {'Key': 'VAECID', 'Value': 'AWG20180517003'},
#    {'Key': 'Environment', 'Value': 'STAGING'},
#    {'Key': 'suboffice', 'Value': 'cto'},
#    {'Key': 'project', 'Value': 'vagov'},
#    {'Key': 'dsva_version', 'Value': 'v2'},
#    {'Key': 'provider', 'Value': 'aws'},
#    {'Key': 'managed', 'Value': 'terraform'},
#    {'Key': 'Office', 'Value': 'tbd'},
#    {'Key': 'ResTag', 'Value': 'shared'},
#    {'Key': 'application', 'Value': 'cms'}],
#   'VpcId': 'vpc-840147e1'},
#  {'Description': 'gids dsva-vagov-prod rds db security group',
#   'GroupName': 'dsva-vagov-prod-gids-db-sg',
#   'IpPermissions': [{'FromPort': 0,
#     'IpProtocol': 'tcp',
#     'IpRanges': [],
#     'Ipv6Ranges': [],
#     'PrefixListIds': [],
#     'ToPort': 65535,
#     'UserIdGroupPairs': [{'Description': 'Self-Referencing SG Rule for AWS Glue',
#       'GroupId': 'sg-df7c5db9',
#       'UserId': '008577686731'}]},
#    {'FromPort': 5432,
#     'IpProtocol': 'tcp',
#     'IpRanges': [],
#     'Ipv6Ranges': [],
#     'PrefixListIds': [],
#     'ToPort': 5432,
#     'UserIdGroupPairs': [{'GroupId': 'sg-3364f354', 'UserId': '008577686731'},
#      {'GroupId': 'sg-0db0d50ee56222f9f', 'UserId': '008577686731'}]}],
#   'OwnerId': '008577686731',
#   'GroupId': 'sg-df7c5db9',
#   'IpPermissionsEgress': [{'IpProtocol': '-1',
#     'IpRanges': [{'CidrIp': '0.0.0.0/0'}],
#     'Ipv6Ranges': [],
#     'PrefixListIds': [],
#     'UserIdGroupPairs': []}],
#   'Tags': [{'Key': 'ResTag', 'Value': 'shared'},
#    {'Key': 'Role', 'Value': 'tbd'},
#    {'Key': 'group', 'Value': 'dsva'},
#    {'Key': 'application', 'Value': 'gi-bill-data-service'},
#    {'Key': 'provider', 'Value': 'aws'},
#    {'Key': 'project', 'Value': 'vagov'},
#    {'Key': 'ProjectName', 'Value': 'VA Vets.gov'},
#    {'Key': 'office', 'Value': 'osva'},
#    {'Key': 'Environment', 'Value': 'PROD'},
#    {'Key': 'managed', 'Value': 'terraform'},
#    {'Key': 'environment', 'Value': 'prod'},
#    {'Key': 'region', 'Value': 'govcloud'},
#    {'Key': 'Office', 'Value': 'tbd'},
#    {'Key': 'VAECID', 'Value': 'AWG20180517003'},
#    {'Key': 'suboffice', 'Value': 'cto'},
#    {'Key': 'dsva_version', 'Value': 'v2'},
#    {'Key': 'ProjectShort', 'Value': 'Vets.gov'},
#    {'Key': 'Adminstration', 'Value': 'TBD'},
#    {'Key': 'Name', 'Value': 'dsva-vagov-prod-gids-db-sg'}],
#   'VpcId': 'vpc-d50f49b0'},
#  {'Description': 'cms-test rds security group in dev',
#   'GroupName': 'dsva-vagov-dev-cms-test-rds-sg',
#   'IpPermissions': [{'FromPort': 3306,
#     'IpProtocol': 'tcp',
#     'IpRanges': [],
#     'Ipv6Ranges': [],
#     'PrefixListIds': [],
#     'ToPort': 3306,
#     'UserIdGroupPairs': [{'GroupId': 'sg-079448e8251c80820',
#       'UserId': '008577686731'},
#      {'GroupId': 'sg-2e91e648',
#       'PeeringStatus': 'active',
#       'UserId': '008577686731',
#       'VpcId': 'vpc-0978b06c',
#       'VpcPeeringConnectionId': 'pcx-3a2d5053'},
#      {'GroupId': 'sg-7068ee15',
#       'PeeringStatus': 'active',
#       'UserId': '008577686731',
#       'VpcId': 'vpc-0978b06c',
#       'VpcPeeringConnectionId': 'pcx-3a2d5053'}]}],
#   'OwnerId': '008577686731',
#   'GroupId': 'sg-e8df7b91',
#   'IpPermissionsEgress': [],
#   'Tags': [{'Key': 'managed', 'Value': 'terraform'},
#    {'Key': 'Adminstration', 'Value': 'TBD'},
#    {'Key': 'dsva_version', 'Value': 'v2'},
#    {'Key': 'suboffice', 'Value': 'cto'},
#    {'Key': 'Office', 'Value': 'tbd'},
#    {'Key': 'ProjectName', 'Value': 'VA Vets.gov'},
#    {'Key': 'Environment', 'Value': 'DEV'},
#    {'Key': 'Role', 'Value': 'tbd'},
#    {'Key': 'group', 'Value': 'dsva'},
#    {'Key': 'ResTag', 'Value': 'shared'},
#    {'Key': 'Name', 'Value': 'dsva-vagov-dev-cms-test-rds-sg'},
#    {'Key': 'office', 'Value': 'osva'},
#    {'Key': 'provider', 'Value': 'aws'},
#    {'Key': 'ProjectShort', 'Value': 'Vets.gov'},
#    {'Key': 'project', 'Value': 'vagov'},
#    {'Key': 'region', 'Value': 'govcloud'},
#    {'Key': 'environment', 'Value': 'dev'},
#    {'Key': 'VAECID', 'Value': 'AWG20180517003'},
#    {'Key': 'application', 'Value': 'cms-test'}],
#   'VpcId': 'vpc-b50046d0'}]

# %%
get_security_group_name_and_id = []

for item in get_security_groups:
    group_name = item.get("GroupName")
    group_id = item.get("GroupId")

    get_security_group_name_and_id.append([group_name, group_id])

# %%
get_security_group_name_and_id
# Out:
# [['dsva-vagov-dev-keycloak-db-sg', 'sg-00734f4482cb11ceb'],
#  ['dsva-vagov-dev-platform-console-ui-db-sg', 'sg-03627397dd3ecb4de'],
#  ['dsva-vagov-utility-keycloak-db-sg', 'sg-0376c9d13bf948630'],
#  ['dsva-vagov-staging-platform-console-ui-db-sg', 'sg-03ca43c3cab84a3c4'],
#  ['dsva-vagov-dev-lut-db-sg', 'sg-04921927dc74e3cb6'],
#  ['dsva-vagov-sentry-rds-sg', 'sg-04f859724325f1f78'],
#  ['dsva-vagov-utility-pact-broker', 'sg-0953fde0772143261'],
#  ['dsva-vagov-utility-platform-console-api-db-sg', 'sg-09f3d24216bba51c9'],
#  ['dsva-vagov-dev-vets-api-server-sg', 'sg-0aba386d'],
#  ['dsva-vagov-utility-platform-console-ui-db-sg', 'sg-0f447c3dfa1127aa3'],
#  ['dsva-vagov-utility-grafana-rds-sg', 'sg-1a06ef7d'],
#  ['dsva-vagov-staging-vets-api-db-sg', 'sg-32aef654'],
#  ['dsva-vagov-sandbox-vets-api-db-sg', 'sg-4122d127'],
#  ['dsva-vagov-dev-cms-rds-sg', 'sg-4b466d2c'],
#  ['dsva-vagov-prod-cms-test-rds-sg', 'sg-64db7f1d'],
#  ['dsva-vagov-dev-vets-api-db-sg', 'sg-7aaef61c'],
#  ['dsva-vagov-staging-cms-test-rds-sg', 'sg-aaa501d3'],
#  ['dsva-vagov-prod-cms-rds-sg', 'sg-b38bb3d4'],
#  ['dsva-vagov-staging-gids-db-sg', 'sg-ba2b0edc'],
#  ['dsva-vagov-dev-gids-db-sg', 'sg-bd2702db'],
#  ['default', 'sg-d33fe7b7'],
#  ['dsva-vagov-prod-vets-api-db-sg', 'sg-d37c5db5'],
#  ['dsva-vagov-staging-cms-rds-sg', 'sg-d690a8b1'],
#  ['dsva-vagov-prod-gids-db-sg', 'sg-df7c5db9'],
#  ['dsva-vagov-dev-cms-test-rds-sg', 'sg-e8df7b91']]

# %%
for item in get_rds_info:
    # security group ids of the item
    item_sg_ids = item[5]

    # assume security groud id not avialable
    security_group_id_found = False

    for sg_id in item_sg_ids:
        # for each security group id of the item, check if the id found
        # in get_security_group_name_and_id
        # if so, we add security group name besides the id

        for sg_info in get_security_group_name_and_id:
            # check if security group id matches 
            if sg_id == sg_info[1]:
                item.append(sg_info[0]) #add the security group name

                # initial assumption was wrong, we found the security group id
                security_group_id_found = True

                # no need to check the rest
                break

        # after looking through all the get_security_group_name_and_id
        # check if we found security group id or not 
        if security_group_id_found == False:
                item.append('security group id not found')

# %%
get_rds_info
# Out:
# [['dsva-cms-dev-db',
#   'mariadb',
#   'dsva_cms_dev',
#   3306,
#   'vpc-b50046d0',
#   ['sg-4b466d2c'],
#   'dsva-vagov-dev-cms-rds-sg'],
#  ['dsva-cms-prod-db',
#   'mariadb',
#   'dsva_cms_prod',
#   3306,
#   'vpc-d50f49b0',
#   ['sg-b38bb3d4'],
#   'dsva-vagov-prod-cms-rds-sg'],
#  ['dsva-cms-staging-db',
#   'mariadb',
#   'dsva_cms_staging',
#   3306,
#   'vpc-840147e1',
#   ['sg-d690a8b1'],
#   'dsva-vagov-staging-cms-rds-sg'],
#  ['dsva-cms-test-dev-db',
#   'mariadb',
#   'dsva_cms_dev',
#   3306,
#   'vpc-b50046d0',
#   ['sg-e8df7b91'],
#   'dsva-vagov-dev-cms-test-rds-sg'],
#  ['dsva-cms-test-prod-db',
#   'mariadb',
#   'dsva_cms_prod',
#   3306,
#   'vpc-d50f49b0',
#   ['sg-64db7f1d'],
#   'dsva-vagov-prod-cms-test-rds-sg'],
#  ['dsva-cms-test-staging-db',
#   'mariadb',
#   'dsva_cms_staging',
#   3306,
#   'vpc-840147e1',
#   ['sg-aaa501d3'],
#   'dsva-vagov-staging-cms-test-rds-sg'],
#  ['dsva-gi-bill-data-service-dev',
#   'postgres',
#   'dsva_gids_dev',
#   5432,
#   'vpc-b50046d0',
#   ['sg-bd2702db'],
#   'dsva-vagov-dev-gids-db-sg'],
#  ['dsva-gi-bill-data-service-prod',
#   'postgres',
#   'dsva_gids_prod',
#   5432,
#   'vpc-d50f49b0',
#   ['sg-df7c5db9'],
#   'dsva-vagov-prod-gids-db-sg'],
#  ['dsva-gi-bill-data-service-staging',
#   'postgres',
#   'dsva_gids_staging',
#   5432,
#   'vpc-840147e1',
#   ['sg-ba2b0edc'],
#   'dsva-vagov-staging-gids-db-sg'],
#  ['dsva-lighthouse-ux-toolkit-db',
#   'postgres',
#   'ux_toolkit',
#   5432,
#   'vpc-b50046d0',
#   ['sg-04921927dc74e3cb6'],
#   'dsva-vagov-dev-lut-db-sg'],
#  ['dsva-vagov-dev-platform-console-ui',
#   'postgres',
#   'platform_console_ui',
#   5432,
#   'vpc-b50046d0',
#   ['sg-03627397dd3ecb4de'],
#   'dsva-vagov-dev-platform-console-ui-db-sg'],
#  ['dsva-vagov-grafana-utility',
#   'postgres',
#   'dsva_grafana_utility',
#   5432,
#   'vpc-84a444e0',
#   ['sg-1a06ef7d'],
#   'dsva-vagov-utility-grafana-rds-sg'],
#  ['dsva-vagov-keycloak-dev',
#   'postgres',
#   'keycloak',
#   5432,
#   'vpc-b50046d0',
#   ['sg-00734f4482cb11ceb'],
#   'dsva-vagov-dev-keycloak-db-sg'],
#  ['dsva-vagov-keycloak-next-dev',
#   'postgres',
#   'keycloak',
#   5432,
#   'vpc-b50046d0',
#   ['sg-00734f4482cb11ceb'],
#   'dsva-vagov-dev-keycloak-db-sg'],
#  ['dsva-vagov-keycloak-utility',
#   'postgres',
#   'keycloak',
#   5432,
#   'vpc-84a444e0',
#   ['sg-0376c9d13bf948630'],
#   'dsva-vagov-utility-keycloak-db-sg'],
#  ['dsva-vagov-sentry',
#   'postgres',
#   'sentry',
#   5432,
#   'vpc-84a444e0',
#   ['sg-04f859724325f1f78'],
#   'dsva-vagov-sentry-rds-sg'],
#  ['dsva-vagov-sentry-test',
#   'postgres',
#   'sentry',
#   5432,
#   'vpc-84a444e0',
#   ['sg-04f859724325f1f78'],
#   'dsva-vagov-sentry-rds-sg'],
#  ['dsva-vagov-staging-platform-console-ui',
#   'postgres',
#   'platform_console_ui',
#   5432,
#   'vpc-840147e1',
#   ['sg-03ca43c3cab84a3c4'],
#   'dsva-vagov-staging-platform-console-ui-db-sg'],
#  ['dsva-vagov-utility-pact-broker',
#   'postgres',
#   'pactdb',
#   5432,
#   'vpc-84a444e0',
#   ['sg-0953fde0772143261'],
#   'dsva-vagov-utility-pact-broker'],
#  ['dsva-vagov-utility-platform-console-api',
#   'postgres',
#   'platform_console_api',
#   5432,
#   'vpc-84a444e0',
#   ['sg-09f3d24216bba51c9'],
#   'dsva-vagov-utility-platform-console-api-db-sg'],
#  ['dsva-vagov-utility-platform-console-ui',
#   'postgres',
#   'platform_console_ui',
#   5432,
#   'vpc-84a444e0',
#   ['sg-0f447c3dfa1127aa3'],
#   'dsva-vagov-utility-platform-console-ui-db-sg'],
#  ['dsva-vets-api-dev',
#   'postgres',
#   'dsva_vets_api_dev',
#   5432,
#   'vpc-b50046d0',
#   ['sg-7aaef61c'],
#   'dsva-vagov-dev-vets-api-db-sg'],
#  ['dsva-vets-api-dev-sample',
#   'postgres',
#   'dsva_vets_api_dev',
#   5432,
#   'vpc-b50046d0',
#   ['sg-d33fe7b7', 'sg-0aba386d'],
#   'default',
#   'dsva-vagov-dev-vets-api-server-sg'],
#  ['dsva-vets-api-prod-2',
#   'postgres',
#   'dsva_vets_api_prod',
#   5432,
#   'vpc-d50f49b0',
#   ['sg-d37c5db5'],
#   'dsva-vagov-prod-vets-api-db-sg'],
#  ['dsva-vets-api-sandbox',
#   'postgres',
#   'dsva_vets_api_sandbox',
#   5432,
#   'vpc-959d26f1',
#   ['sg-4122d127'],
#   'dsva-vagov-sandbox-vets-api-db-sg'],
#  ['dsva-vets-api-staging',
#   'postgres',
#   'dsva_vets_api_staging',
#   5432,
#   'vpc-840147e1',
#   ['sg-32aef654'],
#   'dsva-vagov-staging-vets-api-db-sg']]

# %%
rds_security_group_list = []
with open("rds_security_group_list.txt", "r") as f:
    rds_security_group_list = [line.strip() for line in f.readlines()]

# %%
def highlight(value):
    """Highlight a cell based on value."""

    if "\t" in value:
        color = "yellow"
    else:
        return

    return f"background-color: {color}"


filename = "rds_scan_coverage.xlsx"

with pd.ExcelWriter(filename, engine="xlsxwriter") as writer:
    all_sheets = {}

    for db_info in get_rds_info:
        rds_instance_identifier = db_info[0]
        rds_engine = db_info[1]
        rds_db_name = db_info[2]
        rds_port = db_info[3]
        rds_vpc_id = db_info[4]
        rds_security_group_ids = db_info[5]

        # nubmber of security groups for the item
        num_of_sg_ids = len(rds_security_group_ids)

        # when the instance has more than one security group
        # each security group is added as a new row in the excel
        rows = {}
        rows[rds_vpc_id] = []

        # if we have one security group id, the last one element is security group name
        # if we have two, the last two elements are security group names
        # if we have n, the last n elements are security group names
        # where n is number of security group ids of the instance
        # in our case n = num_of_sg_ids

        # so db_info[-num_of_sg_ids:] means last n elements (security group names)
        # that are correspondent for each security group id

        for sg_id, sg_name in zip(rds_security_group_ids, db_info[-num_of_sg_ids:]):
            # check if the group name exists in our list of target groups
            if sg_name in rds_security_group_list:
                # mark it to be highlighted (cells with \t added are to be highlighted)
                sg_name = sg_name + "\t"

            # if rows.get(rds_vpc_id):
            #     # a row to be inserted in the excel with group info only
            #     row = ["", "", "", "", sg_id, sg_name]
            #     rows[rds_vpc_id].append(row)

            if rows[rds_vpc_id] != []:
                # a row to be inserted in the excel with group info only
                row = ["", "", "", "", sg_id, sg_name]
                rows[rds_vpc_id].append(row)

            else:
                # a row to be inserted in the excel with full instance info
                row = [
                    rds_instance_identifier,
                    rds_engine,
                    rds_db_name,
                    rds_port,
                    sg_id,
                    sg_name,
                ]
                rows[rds_vpc_id].append(row)

        # organize rows into different sheets
        if all_sheets.get(rds_vpc_id):
            # sheet is aleardy created
            all_sheets[rds_vpc_id].extend(rows[rds_vpc_id])
        else:
            # create a new sheet
            all_sheets[rds_vpc_id] = []
            all_sheets[rds_vpc_id].extend(rows[rds_vpc_id])

    for sheet in all_sheets:
        df = pd.DataFrame(
            all_sheets[sheet],
            columns=[
                "DBInstanceIdentifier",
                "Engine",
                "DBName",
                "Port",
                "SecurityGroups",
                "SecurityName",
            ],
        )

        # Apply style to highlight cells based on value
        df = df.style.applymap(highlight, subset=["SecurityName"])

        df.to_excel(writer, sheet_name=sheet, index=False)
